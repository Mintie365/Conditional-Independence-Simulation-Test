# %%
# ============================================================
# 参数配置
# ============================================================
param = {
    "test": "power",
    "sample_size": 200,
    "batch_size": 128,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 100,
    "eps_std": 1.0,
    "dist_z": 'gaussian',
    "alpha_x": 0.20,
    "m_value": 100,
    "k_value": 8,
    "j_value": 1000,
    "noise_dimension": 5,
    "noise_dimension_type": "normal",
    "noise_dimension_var": 1,
    "hidden_layer_size": 1024,
    "normal_ini": False,
    "preprocess": 'scale',
    "G_lr": 7e-5,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 0,
    "using_orcale": False,
    "lambda_1": 1,
    "lambda_2": 1,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-4,
    "lambda_4": 2e-5,
    "drop_out_p": 0.2,
    "is_sparse": True,
    "sparse_ratio": 0.05,
    "lambda_median": 0.3,
    "median_samples": 30,
    "mix_prob_tail": 0.15,
    "main_loc": 1.0,
    "tail_loc": -7.0,
    "component_std": 0.3
}

import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools
from tqdm import tqdm

# [修改1] 删除全局 device，改为在 mGAN() 内部按 gpu_id 动态创建
# 原代码：
#   enable_cuda = True
#   device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')

def _sample_mixture_noise(num, d, p_tail=0.15, main_loc=1.0, tail_loc=-7.0, component_std=0.3):
    """
    采样
        F = (1-p_tail) * N(main_loc, component_std^2)
          + p_tail      * N(tail_loc, component_std^2)
    """
    comp = torch.bernoulli(torch.full((num, 1), p_tail))
    main_part = main_loc + component_std * torch.randn(num, d)
    tail_part = tail_loc + component_std * torch.randn(num, d)
    return (1.0 - comp) * main_part + comp * tail_part

    
def generate_samples_random(size=1000, sType='H0', dx=1, dy=1, dz=1, nstd=1.0, alpha_x=0.05,
                             preprocess="None", dist_z='gaussian',
                             mix_prob_tail=0.15, main_loc=1.0, tail_loc=-7.0, component_std=0.3):
    num = size

    if dist_z == 'gaussian':
        z_generator = TD.MultivariateNormal(torch.zeros(dz), torch.eye(dz))
        Z = z_generator.sample((num,))
    elif dist_z == 'laplace':
        z_generator = TD.MultivariateNormal(torch.zeros(dz), torch.eye(dz))
        Z = z_generator.sample((num,))
    else:
        raise ValueError("dist_z must be 'gaussian' or 'laplace'.")

    m = TD.Bernoulli(torch.tensor([alpha_x]))

    if sType == 'H0':
        error_x = _sample_mixture_noise(
            num, dx,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        error_y = _sample_mixture_noise(
            num, dy,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        X = Z + error_x
        Y = Z + error_y
    else:
        error_x = _sample_mixture_noise(
            num, dx,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        error_y = _sample_mixture_noise(
            num, dy,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        delta = m.sample((num,))
        X = Z + (1 - delta) * error_x + delta * error_y
        Y = Z + error_y

    return X, Y, Z


def generate_samples_from_fixed_Z_random(Z, size=1000, sType='H0', dx=1, dy=1, dz=1, nstd=1.0,
                                          alpha_x=0.05, normalize=True, seed=None, dist_z='gaussian',
                                          mix_prob_tail=0.15, main_loc=1.0, tail_loc=-7.0, component_std=0.3):
    num = size
    m = TD.Bernoulli(torch.tensor([alpha_x]))

    if sType == 'H0':
        error_x = _sample_mixture_noise(
            num, dx,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        error_y = _sample_mixture_noise(
            num, dy,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        X = Z + error_x
        Y = Z + error_y
    else:
        error_x = _sample_mixture_noise(
            num, dx,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        error_y = _sample_mixture_noise(
            num, dy,
            p_tail=mix_prob_tail,
            main_loc=main_loc,
            tail_loc=tail_loc,
            component_std=component_std
        )
        delta = m.sample((num,))
        X = Z + (1 - delta) * error_x + delta * error_y
        Y = Z + error_y

    return X, Y

    
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch, x_torch, y_torch, z_torch,
                        sigma_w, sigma_u=1, sigma_v=1, boor_rv_type="gaussian",
                        device=None):  # [修改2] 新增 device 参数
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    w_mx = torch.exp(-w_mx / sigma_w)
    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u),
        dim=2)
    u_mx_3 = u_mx_2.T
    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v),
        dim=2)
    v_mx_3 = v_mx_2.T
    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
        sum_mx = sum_mx + temp_add_mx
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
        sum2_mx = sum2_mx + temp2_add_mx
    u_mx_4 = 1 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4
    v_mx_4 = 1 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4
    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n).to(device))  # [修改2]
    stat = 1 / (n - 1) * torch.sum(FF_mx).item()
    boottemp = np.array([])
    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num)).to(device)  # [修改2]
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num).to(device)              # [修改2]
    for bb in range(boot_num):
        random_mx = torch.matmul(eboot[:, bb].reshape(-1, 1), eboot[:, bb].reshape(-1, 1).T)
        bootmatrix = FF_mx * random_mx
        stat_boot = 1 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)
    return stat, boottemp


class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index], \
               self.Z_real[(self.batch_size + index) % self.sample_size]


class DatasetSelect_GAN_ver2(torch.utils.data.Dataset):
    def __init__(self, Y, Z, batch_size):
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = Z.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.Y_real[index], self.Z_real[index]


def sample_noise(sample_size, noise_dimension, noise_type, input_var=1,
                 device=None):  # [修改3] 新增 device 参数
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),           # [修改3]
            input_var * torch.eye(noise_dimension).to(device)) # [修改3]
        Z = noise_generator.sample((sample_size,))
    if noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension)
    if noise_type == "Cauchy":
        Z = TD.Cauchy(torch.tensor([0.0]), torch.tensor([1.0])).sample(
            (sample_size, noise_dimension)).squeeze(2)
    return Z


class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, drop_out_p, drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN3 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc3 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)
        self.sigmoid = torch.nn.Sigmoid()
        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out3 = torch.nn.Dropout(p=drop_out_p)
        self.drop_input = drop_input

    def forward(self, x):
        if self.BN_type:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
            x = self.fc_last(x)
        else:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))
            x = self.fc_last(x)
        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        # [修改3] 不在构造函数中 .to(device)，由外层统一 .to(device)
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias)
        self.mask = functools.reduce(
            torch.block_diag, [torch.ones(size_out, size_in) for i in range(m)])

    def forward(self, x):
        # [修改3] mask 动态跟随模型所在设备
        self.linear.weight.data *= self.mask.to(self.linear.weight.device)
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)
        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0])
        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for i in range(len(self.hidden_layer_sizes))
        ])
        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)
        return self.linear8(output)


def find_loss(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-torch.abs(Y.repeat(1, n) - Y.repeat(1, n).T) / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    mx_1_2 = torch.exp(-mx_1_2 / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-torch.abs(Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-torch.abs(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def find_loss_2(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-(Y.repeat(1, n) - Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=2, dim=2)
    mx_1_2 = torch.exp(-(mx_1_2 ** 2) / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-(Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def pinball_loss(y_true, y_pred, tau=0.5):
    diff = y_true - y_pred
    loss = torch.where(diff >= 0,
                       tau * diff,
                       (1.0 - tau) * (-diff))
    return loss.mean()


def train_ver3(
        G_zx, G_zy,
        X, Y, Z, X_test, Y_test, Z_test, M,
        noise_dimension, noise_type, G_lr, hidden_layer_size,
        DataLoader, BN_type, ReLU_coef,
        lambda_median=0.5, median_samples=20,
        epochs_num=50,
        patience=5, min_delta=1e-5,
        sigma_z=1, sigma_x=1, sigma_y=1,
        normal_ini=False,
        lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
        lambda_3=0, drop_out_p=0.2, noise_dimension_var=1,
        lambda_4=0,
        device=None):  # [修改3] 新增 device 参数

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if G_zy is None or G_zx is None:
        if using_Gen == '1':
            G_zy = Generator(input_dimension, output_dimension_y, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
            G_zx = Generator(input_dimension, output_dimension_x, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
        elif using_Gen == '2':
            G_zy = Generator_2(input_dimension, output_dimension_y, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]
            G_zx = Generator_2(input_dimension, output_dimension_x, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]

    G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    iter_count = 0
    G_zy = G_zy.train()
    G_zx = G_zx.train()

    best_loss = float('inf')
    counter = 0

    for epoch in range(epochs_num):
        batch_count = 0
        G_zy = G_zy.train()
        G_zx = G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)   # [修改3]
            Y_real = Y_real.to(device)   # [修改3]
            Z_real = Z_real.to(device)   # [修改3]
            Z_fake = Z_fake.to(device)   # [修改3]

            batch_size = Z_real.shape[0]
            Z_repeated = Z_real.repeat_interleave(median_samples, dim=0)

            Noise_for_median = sample_noise(
                Z_repeated.shape[0], noise_dimension, noise_type,
                input_var=noise_dimension_var, device=device).to(device)  # [修改3]

            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            Y_fake = G_zy(torch.cat((Z_real, Noise_fake), dim=1)).to(device)
            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            X_fake = G_zx(torch.cat((Z_real, Noise_fake), dim=1)).to(device)

            Y_generated_group = G_zy(torch.cat((Z_repeated, Noise_for_median), dim=1))
            Y_generated_reshaped = Y_generated_group.reshape(batch_size, median_samples, -1)
            Y_median_pred = torch.median(Y_generated_reshaped, dim=1).values
            loss_median_y = pinball_loss(Y_real, Y_median_pred, tau=0.5)

            X_generated_group = G_zx(torch.cat((Z_repeated, Noise_for_median), dim=1))
            X_generated_reshaped = X_generated_group.reshape(batch_size, median_samples, -1)
            X_median_pred = torch.median(X_generated_reshaped, dim=1).values
            loss_median_x = pinball_loss(X_real, X_median_pred, tau=0.5)

            g_zy_error = None
            G_zy_solver.zero_grad()
            g_zx_error = None
            G_zx_solver.zero_grad()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zy.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_y = (lambda_1 * find_loss(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_2 * find_loss_2(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zy_error = mmd_loss_y + lambda_median * loss_median_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zx.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_x = (lambda_1 * find_loss(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_2 * find_loss_2(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zx_error = mmd_loss_x + lambda_median * loss_median_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

            iter_count += 1
            batch_count += 1

        current_loss = g_zx_error + g_zy_error
        if current_loss < best_loss - min_delta:
            best_loss = current_loss
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            break

    return G_zy, G_zx


def mGAN(n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_orcale=False, lambda_1=1, lambda_2=1,
         lambda_median=0.3, median_samples=20,
         using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2,
         noise_dimension_var=1, noise_dimension_type="normal", lambda_4=1,
         gpu_id=0):  # [修改4] 新增 gpu_id 参数

    # [修改4] 在函数内部根据 gpu_id 创建局部 device
    enable_cuda = True
    if torch.cuda.is_available() and enable_cuda:
        device = torch.device(f'cuda:{gpu_id}')
    else:
        device = torch.device('cpu')

    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
        size=n, sType='H0', dx=x_dims, dy=y_dims, dz=z_dim,
        nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess,
        mix_prob_tail=param["mix_prob_tail"],
        main_loc=param["main_loc"],
        tail_loc=param["tail_loc"],
        component_std=param["component_std"]
    )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
        size=n, sType='H1', dx=x_dims, dy=y_dims, dz=z_dim,
        nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess,
        mix_prob_tail=param["mix_prob_tail"],
        main_loc=param["main_loc"],
        tail_loc=param["tail_loc"],
        component_std=param["component_std"]
    )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x.to(device), sim_y.to(device), sim_z.to(device)

    w_mx = torch.linalg.vector_norm(
        z.repeat(n, 1, 1) - torch.swapaxes(z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    sigma_w = torch.median(w_mx).item()
    u_mx = torch.exp(-torch.abs(y.repeat(1, n) - y.repeat(1, n).T))
    sigma_u = torch.median(u_mx).item()
    v_mx = torch.exp(-torch.abs(x.repeat(1, n) - x.repeat(1, n).T))
    sigma_v = torch.median(v_mx).item()

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    if not using_orcale:
        G_zy = Generator(z_dim, y_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)
        G_zx = Generator(z_dim, x_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))
        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]
        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))
        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_orcale:
            current_epochs = epochs_num if k_fold == 0 else max(10, epochs_num // 5)
            G_zy, G_zx = train_ver3(
                G_zx=G_zx, G_zy=G_zy,
                X=X_train, Y=Y_train, Z=Z_train, M=M,
                X_test=X_test, Y_test=Y_test, Z_test=Z_test,
                noise_dimension=noise_dimension, noise_type=noise_dimension_type,
                G_lr=G_lr, hidden_layer_size=hidden_layer_size,
                DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
                lambda_median=lambda_median, median_samples=median_samples,
                epochs_num=epochs_num,
                sigma_z=sigma_w, sigma_x=sigma_v, sigma_y=sigma_u,
                normal_ini=normal_ini, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, wgt_decay=wgt_decay, lambda_3=lambda_3,
                drop_out_p=drop_out_p, noise_dimension_var=noise_dimension_var,
                lambda_4=lambda_4,
                device=device)  # [修改4] 传入局部 device

        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M, device=device)   # [修改4]
        gen_y_all = torch.zeros(test_size, M, device=device)   # [修改4]
        z_all = torch.zeros(test_size, z_dim, device=device)   # [修改4]
        x_all = torch.zeros(test_size, x_dims, device=device)  # [修改4]
        y_all = torch.zeros(test_size, y_dims, device=device)  # [修改4]
        cur_itr = 0

        if not using_orcale:
            G_zx = G_zx.eval()
            G_zy = G_zy.eval()

        for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
            z_test_temp = z_test.repeat(M, 1)
            if not using_orcale:
                z_test_temp = z_test_temp.to(device)                                      # [修改4]
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_x = G_zx(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_y = G_zy(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
            elif using_orcale:
                if simulation == 'type1error':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                    z_test_temp, size=M, sType='H0', dx=x_dims, dy=y_dims,
                    dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist,
                    mix_prob_tail=param["mix_prob_tail"],
                    main_loc=param["main_loc"],
                    tail_loc=param["tail_loc"],
                    component_std=param["component_std"]
                        )
                elif simulation == 'power':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                    z_test_temp, size=M, sType='H1', dx=x_dims, dy=y_dims,
                    dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist,
                    mix_prob_tail=param["mix_prob_tail"],
                    main_loc=param["main_loc"],
                    tail_loc=param["tail_loc"],
                    component_std=param["component_std"]
                        )

            gen_x_all[cur_itr, :] = fake_x.detach().reshape(-1)
            gen_y_all[cur_itr, :] = fake_y.detach().reshape(-1)
            x_all[cur_itr, :] = x_test
            y_all[cur_itr, :] = y_test
            z_all[cur_itr, :] = z_test
            cur_itr = cur_itr + 1

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type,
            device=device)  # [修改4] 传入局部 device
        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp)
        cur_k = cur_k + 1

    if using_orcale:
        gen_x_median = torch.median(gen_x_all, dim=1).values.reshape(-1, 1)
        gen_y_median = torch.median(gen_y_all, dim=1).values.reshape(-1, 1)
        mse_x = torch.mean((gen_x_median - x_all) ** 2).item()
        mse_y = torch.mean((gen_y_median - y_all) ** 2).item()
        print(f'Test MSE x (median diff) [{mse_x}], MSE y (median diff) [{mse_y}]')

    return np.mean(torch.mean(boot_temp_all, dim=0).numpy() > torch.mean(stat_all).item())


# ============================================================
# 并行部分
# ============================================================
from joblib import Parallel, delayed
import multiprocessing

def run_experiment(params):
    test                 = params["test"]
    sample_size          = params["sample_size"]
    batch_size           = params["batch_size"]
    z_dim                = params["z_dim"]
    dx                   = params["dx"]
    dy                   = params["dy"]
    n_test               = params["n_test"]
    epochs_num           = params["epochs_num"]
    eps_std              = params["eps_std"]
    dist_z               = params["dist_z"]
    alpha_x              = params["alpha_x"]
    m_value              = params["m_value"]
    k_value              = params["k_value"]
    j_value              = params["j_value"]
    noise_dimension      = params["noise_dimension"]
    noise_dimension_type = params["noise_dimension_type"]
    noise_dimension_var  = params["noise_dimension_var"]
    hidden_layer_size    = params["hidden_layer_size"]
    normal_ini           = params["normal_ini"]
    preprocess           = params["preprocess"]
    G_lr                 = params["G_lr"]
    alpha                = params["alpha"]
    alpha1               = params["alpha1"]
    set_seeds            = params["set_seeds"]
    using_orcale         = params["using_orcale"]
    lambda_1             = params["lambda_1"]
    lambda_2             = params["lambda_2"]
    using_Gen            = params["using_Gen"]
    boor_rv_type         = params["boor_rv_type"]
    wgt_decay            = params["wgt_decay"]
    lambda_3             = params["lambda_3"]
    lambda_4             = params["lambda_4"]
    drop_out_p           = params["drop_out_p"]
    lambda_median        = params["lambda_median"]
    median_samples       = params["median_samples"]

    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    # [修改4] 获取可用 GPU 数量，控制并发数，轮询分配 GPU
    num_gpus = torch.cuda.device_count() if torch.cuda.is_available() else 1
    num_cores = min(16, n_test)
    if num_cores < 1:
        num_cores = 1

    print(f"[{datetime.now().strftime('%H:%M:%S')}] 开始并行实验...")
    print(f"模式: {test}, 样本量: {sample_size}, 交叉验证折数: {k_value}, "
          f"模型中位数对齐超参数(pinball): {lambda_median}, 实验次数: {n_test}, "
          f"并行核数: {num_cores}, 可用GPU数: {num_gpus}")
    if test == 'power':
        print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")

    # [修改4] 按 job_index % num_gpus 轮询分配 GPU
    p_values = Parallel(n_jobs=num_cores)(
        delayed(mGAN)(
            n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
            epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
            a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
            noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
            normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
            using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
            lambda_median=lambda_median, median_samples=median_samples,
            using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
            lambda_3=lambda_3, drop_out_p=drop_out_p,
            noise_dimension_var=noise_dimension_var,
            noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
            gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
        )
        for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
    )

    p_values = np.array(p_values)
    fp = [pval < alpha for pval in p_values]
    final_result = np.mean(fp)
    fp1 = [pval < alpha1 for pval in p_values]
    final_result1 = np.mean(fp1)

    print(f"\n" + "=" * 50)
    print(f"实验类型: {test.upper()}")
    print(f"Z Dimension: {z_dim}")
    print(f"Emp Rej Rate: {final_result:.4f} (at significance level {alpha})")
    print(f"Emp Rej Rate: {final_result1:.4f} (at significance level {alpha1})")
    print("=" * 50 + "\n")

    return p_values

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.05, 0.10, 0.15, 0.20, 0.25]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [10:57:37] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# /home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.3250 (at significance level 0.1)
# Emp Rej Rate: 0.2000 (at significance level 0.05)
# ==================================================
#
# [11:02:40] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2900 (at significance level 0.02360000000000001)
# Emp Rej Rate: 0.1400 (at significance level 0.008900000000000002)
# ==================================================
#
# [11:07:36] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 490, in _process_worker
#     r = call_item()
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/tmp/ipykernel_261617/4038534934.py", line 625, in mGAN
#   File "/tmp/ipykernel_261617/4038534934.py", line 487, in train_ver3
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_261617/4038534934.py", line 317, in forward
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/torch/nn/modules/activation.py", line 832, in forward
#     return F.leaky_relu(input, self.negative_slope, self.inplace)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/torch/nn/functional.py", line 1899, in leaky_relu
#     result = torch._C._nn.leaky_relu(input, negative_slope)
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 16.00 MiB. GPU 0 has a total capacity of 39.49 GiB of which 6.31 MiB is free. Process 274238 has 908.00 MiB memory in use. Process 274533 has 908.00 MiB memory in use. Process 274869 has 908.00 MiB memory in use. Process 274930 has 908.00 MiB memory in use. Process 275394 has 884.00 MiB memory in use. Process 275471 has 884.00 MiB memory in use. Process 275036 has 28.41 GiB memory in use. Process 275603 has 884.00 MiB memory in use. Process 275873 has 884.00 MiB memory in use. Including non-PyTorch memory, this process has 602.00 MiB memory in use. Process 276178 has 836.00 MiB memory in use. Process 276273 has 836.00 MiB memory in use. Process 276299 has 884.00 MiB memory in use. Process 276361 has 884.00 MiB memory in use. Of the allocated memory 47.76 MiB is allocated by PyTorch, and 18.24 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# """
#
# The above exception was the direct cause of the following exception:
#
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 22
#      20 for alpha_x in [0.05, 0.10, 0.15, 0.20, 0.25]:
#      21         param["alpha_x"] = alpha_x
# ---> 22         p_val_list_h1 = run_experiment(param)
#
# Cell In[7], line 776, in run_experiment(params)
#     773     print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")
#     775 # [修改4] 按 job_index % num_gpus 轮询分配 GPU
# --> 776 p_values = Parallel(n_jobs=num_cores)(
#     777     delayed(mGAN)(
#     778         n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
#     779         epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
#     780         a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
#     781         noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
#     782         normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
#     783         using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
#     784         lambda_median=lambda_median, median_samples=median_samples,
#     785         using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
#     786         lambda_3=lambda_3, drop_out_p=drop_out_p,
#     787         noise_dimension_var=noise_dimension_var,
#     788         noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
#     789         gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
#     790     )
#     791     for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
#     792 )
#     794 p_values = np.array(p_values)
#     795 fp = [pval < alpha for pval in p_values]
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 16.00 MiB. GPU 0 has a total capacity of 39.49 GiB of which 6.31 MiB is free. Process 274238 has 908.00 MiB memory in use. Process 274533 has 908.00 MiB memory in use. Process 274869 has 908.00 MiB memory in use. Process 274930 has 908.00 MiB memory in use. Process 275394 has 884.00 MiB memory in use. Process 275471 has 884.00 MiB memory in use. Process 275036 has 28.41 GiB memory in use. Process 275603 has 884.00 MiB memory in use. Process 275873 has 884.00 MiB memory in use. Including non-PyTorch memory, this process has 602.00 MiB memory in use. Process 276178 has 836.00 MiB memory in use. Process 276273 has 836.00 MiB memory in use. Process 276299 has 884.00 MiB memory in use. Process 276361 has 884.00 MiB memory in use. Of the allocated memory 47.76 MiB is allocated by PyTorch, and 18.24 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.05, 0.10, 0.15, 0.20, 0.25]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [11:13:08] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2700 (at significance level 0.1)
# Emp Rej Rate: 0.1550 (at significance level 0.05)
# ==================================================
#
# [11:19:07] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3150 (at significance level 0.023)
# Emp Rej Rate: 0.2750 (at significance level 0.016850000000000004)
# ==================================================
#
# [11:26:09] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.6350 (at significance level 0.023)
# Emp Rej Rate: 0.6050 (at significance level 0.016850000000000004)
# ==================================================
#
# [11:31:18] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9100 (at significance level 0.023)
# Emp Rej Rate: 0.9050 (at significance level 0.016850000000000004)
# ==================================================
#
# [11:39:24] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.023)
# Emp Rej Rate: 1.0000 (at significance level 0.016850000000000004)
# ==================================================
#
# [11:44:29] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.25
# Process LokyProcess-426:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-458:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-456:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1797 if (nb_jobs == 0) or (
#    1798     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799 ):
# -> 1800     time.sleep(0.01)
#    1801     continue
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 22
#      20 for alpha_x in [0.05, 0.10, 0.15, 0.20, 0.25]:
#      21         param["alpha_x"] = alpha_x
# ---> 22         p_val_list_h1 = run_experiment(param)
#
# Cell In[9], line 776, in run_experiment(params)
#     773     print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")
#     775 # [修改4] 按 job_index % num_gpus 轮询分配 GPU
# --> 776 p_values = Parallel(n_jobs=num_cores)(
#     777     delayed(mGAN)(
#     778         n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
#     779         epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
#     780         a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
#     781         noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
#     782         normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
#     783         using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
#     784         lambda_median=lambda_median, median_samples=median_samples,
#     785         using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
#     786         lambda_3=lambda_3, drop_out_p=drop_out_p,
#     787         noise_dimension_var=noise_dimension_var,
#     788         noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
#     789         gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
#     790     )
#     791     for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
#     792 )
#     794 p_values = np.array(p_values)
#     795 fp = [pval < alpha for pval in p_values]
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1732, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1730 except BaseException:
#    1731     self._exception = True
# -> 1732     self._abort()
#    1733     raise
#    1734 finally:
#    1735     # Store the unconsumed tasks and terminate the workers if necessary
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1646, in Parallel._abort(self)
#    1641 if not self._aborted and hasattr(backend, "abort_everything"):
#    1642     # If the backend is managed externally we need to make sure
#    1643     # to leave it in a working state to allow for future jobs
#    1644     # scheduling.
#    1645     ensure_ready = self._managed_backend
# -> 1646     backend.abort_everything(ensure_ready=ensure_ready)
#    1647 self._aborted = True
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/_parallel_backends.py:725, in LokyBackend.abort_everything(self, ensure_ready)
#     723 def abort_everything(self, ensure_ready=True):
#     724     """Shutdown the workers and restart a new one with the same parameters"""
# --> 725     self._workers.terminate(kill_workers=True)
#     726     self._workers = None
#     728     if ensure_ready:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/executor.py:86, in MemmappingExecutor.terminate(self, kill_workers)
#      85 def terminate(self, kill_workers=False):
# ---> 86     self.shutdown(kill_workers=kill_workers)
#      88     # When workers are killed in a brutal manner, they cannot execute the
#      89     # finalizer of their shared memmaps. The refcount of those memmaps may
#      90     # be off by an unknown number, so instead of decref'ing them, we force
#    (...)
#      95     # with allow_non_empty=True but if we can't, it will be clean up later
#      96     # on by the resource_tracker.
#      97     with self._submit_resize_lock:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1333, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1329 if executor_manager_thread is not None and wait:
#    1330     # This locks avoids concurrent join if the interpreter
#    1331     # is shutting down.
#    1332     with _global_shutdown_lock:
# -> 1333         executor_manager_thread.join()
#    1334         _threads_wakeups.pop(executor_manager_thread, None)
#    1336 # To reduce the risk of opening too many files, remove references to
#    1337 # objects that use file descriptors.
#
# File /opt/anaconda3/lib/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/anaconda3/lib/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0.5
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [11:50:05] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.3500 (at significance level 0.1)
# Emp Rej Rate: 0.1950 (at significance level 0.05)
# ==================================================
#
# [11:56:03] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1250 (at significance level 0.024)
# Emp Rej Rate: 0.0550 (at significance level 0.007)
# ==================================================
#
# [12:02:13] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1850 (at significance level 0.024)
# Emp Rej Rate: 0.0950 (at significance level 0.007)
# ==================================================
#
# [12:06:07] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3150 (at significance level 0.024)
# Emp Rej Rate: 0.1800 (at significance level 0.007)
# ==================================================
#
# [12:09:48] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3650 (at significance level 0.024)
# Emp Rej Rate: 0.2350 (at significance level 0.007)
# ==================================================
#
# [12:13:29] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4700 (at significance level 0.024)
# Emp Rej Rate: 0.3250 (at significance level 0.007)
# ==================================================
#
# [12:17:10] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7300 (at significance level 0.024)
# Emp Rej Rate: 0.5200 (at significance level 0.007)
# ==================================================
#
# [12:20:52] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8000 (at significance level 0.024)
# Emp Rej Rate: 0.6400 (at significance level 0.007)
# ==================================================
#
# [12:24:29] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 16, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9600 (at significance level 0.024)
# Emp Rej Rate: 0.8600 (at significance level 0.007)
# ==================================================

# %%
# ============================================================
# 参数配置
# ============================================================
param = {
    "test": "power",
    "sample_size": 200,
    "batch_size": 128,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 100,
    "eps_std": 1.0,
    "dist_z": 'gaussian',
    "alpha_x": 0.20,
    "m_value": 100,
    "k_value": 8,
    "j_value": 1000,
    "noise_dimension": 5,
    "noise_dimension_type": "normal",
    "noise_dimension_var": 1,
    "hidden_layer_size": 1024,
    "normal_ini": False,
    "preprocess": 'scale',
    "G_lr": 7e-5,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 0,
    "using_orcale": False,
    "lambda_1": 1,
    "lambda_2": 1,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-4,
    "lambda_4": 2e-5,
    "drop_out_p": 0.2,
    "is_sparse": True,
    "sparse_ratio": 0.05,
    "lambda_median": 0.3,
    "median_samples": 30
}

import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools
from tqdm import tqdm

# [修改1] 删除全局 device，改为在 mGAN() 内部按 gpu_id 动态创建
# 原代码：
#   enable_cuda = True
#   device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


def generate_samples_random(size=1000, sType='H0', dx=1, dy=1, dz=1,
                            nstd=1.0, alpha_x=0.05,
                            preprocess="None", dist_z='student_t_heavy',
                            t_df=3.0):
    """
    Student-t heavy-tailed conditional dependence DGP.

    H0:
        X = Z + s(Z) * eps_x
        Y = Z + s(Z) * eps_y

    H1:
        X = Z + s(Z) * eps_x
        Y = Z + s(Z) * [Delta * eps_x + (1 - Delta) * eps_y]

    where eps_x, eps_y are standardized Student-t noises.
    """

    num = size

    # Z distribution
    if dist_z in ['student_t_heavy', 'uniform']:
        Z = 2.0 * torch.rand(num, dz) - 1.0
    elif dist_z == 'gaussian':
        z_generator = TD.MultivariateNormal(torch.zeros(dz), torch.eye(dz))
        Z = z_generator.sample((num,))
    elif dist_z == 'laplace':
        laplace = TD.Laplace(torch.zeros(dz), torch.ones(dz))
        Z = laplace.sample((num,))
    else:
        raise ValueError(f"Unsupported dist_z: {dist_z}")

    z1 = Z[:, 0:1]

    # conditional location
    mX = z1
    mY = z1

    # conditional scale: heteroskedastic but smooth
    sX = 0.5 + torch.abs(z1)
    sY = 0.5 + torch.abs(z1)

    # Student-t heavy-tailed noise
    t_dist = TD.StudentT(df=torch.tensor(t_df))

    eps_x = t_dist.sample((num, 1))
    eps_y = t_dist.sample((num, 1))

    # standardize variance when df > 2
    if t_df > 2:
        scale = np.sqrt(t_df / (t_df - 2.0))
        eps_x = eps_x / scale
        eps_y = eps_y / scale

    if sType == 'H0':
        eps_y_star = eps_y

    elif sType == 'H1':
        delta = torch.bernoulli(torch.ones(num, 1) * alpha_x)
        eps_y_star = delta * eps_x + (1.0 - delta) * eps_y

    else:
        raise ValueError("sType must be 'H0' or 'H1'.")

    X = mX + sX * nstd * eps_x
    Y = mY + sY * nstd * eps_y_star

    if dx > 1:
        X = X.repeat(1, dx)
    if dy > 1:
        Y = Y.repeat(1, dy)

    return X.float(), Y.float(), Z.float()
    
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch, x_torch, y_torch, z_torch,
                        sigma_w, sigma_u=1, sigma_v=1, boor_rv_type="gaussian",
                        device=None):  # [修改2] 新增 device 参数
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    w_mx = torch.exp(-w_mx / sigma_w)
    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u),
        dim=2)
    u_mx_3 = u_mx_2.T
    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v),
        dim=2)
    v_mx_3 = v_mx_2.T
    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
        sum_mx = sum_mx + temp_add_mx
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
        sum2_mx = sum2_mx + temp2_add_mx
    u_mx_4 = 1 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4
    v_mx_4 = 1 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4
    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n).to(device))  # [修改2]
    stat = 1 / (n - 1) * torch.sum(FF_mx).item()
    boottemp = np.array([])
    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num)).to(device)  # [修改2]
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num).to(device)              # [修改2]
    for bb in range(boot_num):
        random_mx = torch.matmul(eboot[:, bb].reshape(-1, 1), eboot[:, bb].reshape(-1, 1).T)
        bootmatrix = FF_mx * random_mx
        stat_boot = 1 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)
    return stat, boottemp


class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index], \
               self.Z_real[(self.batch_size + index) % self.sample_size]


class DatasetSelect_GAN_ver2(torch.utils.data.Dataset):
    def __init__(self, Y, Z, batch_size):
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = Z.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.Y_real[index], self.Z_real[index]


def sample_noise(sample_size, noise_dimension, noise_type, input_var=1,
                 device=None):  # [修改3] 新增 device 参数
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),           # [修改3]
            input_var * torch.eye(noise_dimension).to(device)) # [修改3]
        Z = noise_generator.sample((sample_size,))
    if noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension)
    if noise_type == "Cauchy":
        Z = TD.Cauchy(torch.tensor([0.0]), torch.tensor([1.0])).sample(
            (sample_size, noise_dimension)).squeeze(2)
    return Z


class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, drop_out_p, drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN3 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc3 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)
        self.sigmoid = torch.nn.Sigmoid()
        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out3 = torch.nn.Dropout(p=drop_out_p)
        self.drop_input = drop_input

    def forward(self, x):
        if self.BN_type:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
            x = self.fc_last(x)
        else:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))
            x = self.fc_last(x)
        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        # [修改3] 不在构造函数中 .to(device)，由外层统一 .to(device)
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias)
        self.mask = functools.reduce(
            torch.block_diag, [torch.ones(size_out, size_in) for i in range(m)])

    def forward(self, x):
        # [修改3] mask 动态跟随模型所在设备
        self.linear.weight.data *= self.mask.to(self.linear.weight.device)
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)
        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0])
        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for i in range(len(self.hidden_layer_sizes))
        ])
        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)
        return self.linear8(output)


def find_loss(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-torch.abs(Y.repeat(1, n) - Y.repeat(1, n).T) / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    mx_1_2 = torch.exp(-mx_1_2 / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-torch.abs(Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-torch.abs(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def find_loss_2(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-(Y.repeat(1, n) - Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=2, dim=2)
    mx_1_2 = torch.exp(-(mx_1_2 ** 2) / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-(Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def pinball_loss(y_true, y_pred, tau=0.5):
    diff = y_true - y_pred
    loss = torch.where(diff >= 0,
                       tau * diff,
                       (1.0 - tau) * (-diff))
    return loss.mean()


def train_ver3(
        G_zx, G_zy,
        X, Y, Z, X_test, Y_test, Z_test, M,
        noise_dimension, noise_type, G_lr, hidden_layer_size,
        DataLoader, BN_type, ReLU_coef,
        lambda_median=0.5, median_samples=20,
        epochs_num=50,
        patience=5, min_delta=1e-5,
        sigma_z=1, sigma_x=1, sigma_y=1,
        normal_ini=False,
        lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
        lambda_3=0, drop_out_p=0.2, noise_dimension_var=1,
        lambda_4=0,
        device=None):  # [修改3] 新增 device 参数

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if G_zy is None or G_zx is None:
        if using_Gen == '1':
            G_zy = Generator(input_dimension, output_dimension_y, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
            G_zx = Generator(input_dimension, output_dimension_x, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
        elif using_Gen == '2':
            G_zy = Generator_2(input_dimension, output_dimension_y, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]
            G_zx = Generator_2(input_dimension, output_dimension_x, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]

    G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    iter_count = 0
    G_zy = G_zy.train()
    G_zx = G_zx.train()

    best_loss = float('inf')
    counter = 0

    for epoch in range(epochs_num):
        batch_count = 0
        G_zy = G_zy.train()
        G_zx = G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)   # [修改3]
            Y_real = Y_real.to(device)   # [修改3]
            Z_real = Z_real.to(device)   # [修改3]
            Z_fake = Z_fake.to(device)   # [修改3]

            batch_size = Z_real.shape[0]
            Z_repeated = Z_real.repeat_interleave(median_samples, dim=0)

            Noise_for_median = sample_noise(
                Z_repeated.shape[0], noise_dimension, noise_type,
                input_var=noise_dimension_var, device=device).to(device)  # [修改3]

            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            Y_fake = G_zy(torch.cat((Z_real, Noise_fake), dim=1)).to(device)
            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            X_fake = G_zx(torch.cat((Z_real, Noise_fake), dim=1)).to(device)

            Y_generated_group = G_zy(torch.cat((Z_repeated, Noise_for_median), dim=1))
            Y_generated_reshaped = Y_generated_group.reshape(batch_size, median_samples, -1)
            Y_median_pred = torch.median(Y_generated_reshaped, dim=1).values
            loss_median_y = pinball_loss(Y_real, Y_median_pred, tau=0.5)

            X_generated_group = G_zx(torch.cat((Z_repeated, Noise_for_median), dim=1))
            X_generated_reshaped = X_generated_group.reshape(batch_size, median_samples, -1)
            X_median_pred = torch.median(X_generated_reshaped, dim=1).values
            loss_median_x = pinball_loss(X_real, X_median_pred, tau=0.5)

            g_zy_error = None
            G_zy_solver.zero_grad()
            g_zx_error = None
            G_zx_solver.zero_grad()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zy.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_y = (lambda_1 * find_loss(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_2 * find_loss_2(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zy_error = mmd_loss_y + lambda_median * loss_median_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zx.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_x = (lambda_1 * find_loss(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_2 * find_loss_2(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zx_error = mmd_loss_x + lambda_median * loss_median_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

            iter_count += 1
            batch_count += 1

        current_loss = g_zx_error + g_zy_error
        if current_loss < best_loss - min_delta:
            best_loss = current_loss
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            break

    return G_zy, G_zx


def mGAN(n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_orcale=False, lambda_1=1, lambda_2=1,
         lambda_median=0.3, median_samples=20,
         using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2,
         noise_dimension_var=1, noise_dimension_type="normal", lambda_4=1,
         gpu_id=0):  # [修改4] 新增 gpu_id 参数

    # [修改4] 在函数内部根据 gpu_id 创建局部 device
    enable_cuda = True
    if torch.cuda.is_available() and enable_cuda:
        device = torch.device(f'cuda:{gpu_id}')
    else:
        device = torch.device('cpu')

    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H0', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H1', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x.to(device), sim_y.to(device), sim_z.to(device)

    w_mx = torch.linalg.vector_norm(
        z.repeat(n, 1, 1) - torch.swapaxes(z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    sigma_w = torch.median(w_mx).item()
    u_mx = torch.exp(-torch.abs(y.repeat(1, n) - y.repeat(1, n).T))
    sigma_u = torch.median(u_mx).item()
    v_mx = torch.exp(-torch.abs(x.repeat(1, n) - x.repeat(1, n).T))
    sigma_v = torch.median(v_mx).item()

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    if not using_orcale:
        G_zy = Generator(z_dim, y_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)
        G_zx = Generator(z_dim, x_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))
        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]
        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))
        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_orcale:
            current_epochs = epochs_num if k_fold == 0 else max(10, epochs_num // 5)
            G_zy, G_zx = train_ver3(
                G_zx=G_zx, G_zy=G_zy,
                X=X_train, Y=Y_train, Z=Z_train, M=M,
                X_test=X_test, Y_test=Y_test, Z_test=Z_test,
                noise_dimension=noise_dimension, noise_type=noise_dimension_type,
                G_lr=G_lr, hidden_layer_size=hidden_layer_size,
                DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
                lambda_median=lambda_median, median_samples=median_samples,
                epochs_num=epochs_num,
                sigma_z=sigma_w, sigma_x=sigma_v, sigma_y=sigma_u,
                normal_ini=normal_ini, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, wgt_decay=wgt_decay, lambda_3=lambda_3,
                drop_out_p=drop_out_p, noise_dimension_var=noise_dimension_var,
                lambda_4=lambda_4,
                device=device)  # [修改4] 传入局部 device

        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M, device=device)   # [修改4]
        gen_y_all = torch.zeros(test_size, M, device=device)   # [修改4]
        z_all = torch.zeros(test_size, z_dim, device=device)   # [修改4]
        x_all = torch.zeros(test_size, x_dims, device=device)  # [修改4]
        y_all = torch.zeros(test_size, y_dims, device=device)  # [修改4]
        cur_itr = 0

        if not using_orcale:
            G_zx = G_zx.eval()
            G_zy = G_zy.eval()

        for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
            z_test_temp = z_test.repeat(M, 1)
            if not using_orcale:
                z_test_temp = z_test_temp.to(device)                                      # [修改4]
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_x = G_zx(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_y = G_zy(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
            elif using_orcale:
                if simulation == 'type1error':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H0', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)
                elif simulation == 'power':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H1', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)

            gen_x_all[cur_itr, :] = fake_x.detach().reshape(-1)
            gen_y_all[cur_itr, :] = fake_y.detach().reshape(-1)
            x_all[cur_itr, :] = x_test
            y_all[cur_itr, :] = y_test
            z_all[cur_itr, :] = z_test
            cur_itr = cur_itr + 1

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type,
            device=device)  # [修改4] 传入局部 device
        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp)
        cur_k = cur_k + 1

    if using_orcale:
        gen_x_median = torch.median(gen_x_all, dim=1).values.reshape(-1, 1)
        gen_y_median = torch.median(gen_y_all, dim=1).values.reshape(-1, 1)
        mse_x = torch.mean((gen_x_median - x_all) ** 2).item()
        mse_y = torch.mean((gen_y_median - y_all) ** 2).item()
        print(f'Test MSE x (median diff) [{mse_x}], MSE y (median diff) [{mse_y}]')

    return np.mean(torch.mean(boot_temp_all, dim=0).numpy() > torch.mean(stat_all).item())


# ============================================================
# 并行部分
# ============================================================
from joblib import Parallel, delayed
import multiprocessing

def run_experiment(params):
    test                 = params["test"]
    sample_size          = params["sample_size"]
    batch_size           = params["batch_size"]
    z_dim                = params["z_dim"]
    dx                   = params["dx"]
    dy                   = params["dy"]
    n_test               = params["n_test"]
    epochs_num           = params["epochs_num"]
    eps_std              = params["eps_std"]
    dist_z               = params["dist_z"]
    alpha_x              = params["alpha_x"]
    m_value              = params["m_value"]
    k_value              = params["k_value"]
    j_value              = params["j_value"]
    noise_dimension      = params["noise_dimension"]
    noise_dimension_type = params["noise_dimension_type"]
    noise_dimension_var  = params["noise_dimension_var"]
    hidden_layer_size    = params["hidden_layer_size"]
    normal_ini           = params["normal_ini"]
    preprocess           = params["preprocess"]
    G_lr                 = params["G_lr"]
    alpha                = params["alpha"]
    alpha1               = params["alpha1"]
    set_seeds            = params["set_seeds"]
    using_orcale         = params["using_orcale"]
    lambda_1             = params["lambda_1"]
    lambda_2             = params["lambda_2"]
    using_Gen            = params["using_Gen"]
    boor_rv_type         = params["boor_rv_type"]
    wgt_decay            = params["wgt_decay"]
    lambda_3             = params["lambda_3"]
    lambda_4             = params["lambda_4"]
    drop_out_p           = params["drop_out_p"]
    lambda_median        = params["lambda_median"]
    median_samples       = params["median_samples"]

    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    # [修改4] 获取可用 GPU 数量，控制并发数，轮询分配 GPU
    num_gpus = torch.cuda.device_count() if torch.cuda.is_available() else 1
    num_cores = min(20, n_test)
    if num_cores < 1:
        num_cores = 1

    print(f"[{datetime.now().strftime('%H:%M:%S')}] 开始并行实验...")
    print(f"模式: {test}, 样本量: {sample_size}, 交叉验证折数: {k_value}, "
          f"模型中位数对齐超参数(pinball): {lambda_median}, 实验次数: {n_test}, "
          f"并行核数: {num_cores}, 可用GPU数: {num_gpus}")
    if test == 'power':
        print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")

    # [修改4] 按 job_index % num_gpus 轮询分配 GPU
    p_values = Parallel(n_jobs=num_cores)(
        delayed(mGAN)(
            n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
            epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
            a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
            noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
            normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
            using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
            lambda_median=lambda_median, median_samples=median_samples,
            using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
            lambda_3=lambda_3, drop_out_p=drop_out_p,
            noise_dimension_var=noise_dimension_var,
            noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
            gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
        )
        for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
    )

    p_values = np.array(p_values)
    fp = [pval < alpha for pval in p_values]
    final_result = np.mean(fp)
    fp1 = [pval < alpha1 for pval in p_values]
    final_result1 = np.mean(fp1)

    print(f"\n" + "=" * 50)
    print(f"实验类型: {test.upper()}")
    print(f"Z Dimension: {z_dim}")
    print(f"Emp Rej Rate: {final_result:.4f} (at significance level {alpha})")
    print(f"Emp Rej Rate: {final_result1:.4f} (at significance level {alpha1})")
    print("=" * 50 + "\n")

    return p_values

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.06, 0.08, 0.12]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [16:37:51] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2400 (at significance level 0.1)
# Emp Rej Rate: 0.1550 (at significance level 0.05)
# ==================================================
#
# [16:43:47] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1500 (at significance level 0.0199)
# Emp Rej Rate: 0.0900 (at significance level 0.011)
# ==================================================
#
# [16:49:35] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2300 (at significance level 0.0199)
# Emp Rej Rate: 0.1850 (at significance level 0.011)
# ==================================================
#
# [16:54:43] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4200 (at significance level 0.0199)
# Emp Rej Rate: 0.3150 (at significance level 0.011)
# ==================================================
#
# [16:59:35] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5700 (at significance level 0.0199)
# Emp Rej Rate: 0.4700 (at significance level 0.011)
# ==================================================
#
# [17:04:31] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9050 (at significance level 0.0199)
# Emp Rej Rate: 0.8450 (at significance level 0.011)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.05, 0.10, 0.15, 0.20, 0.25]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [15:10:40] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# /home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.3150 (at significance level 0.1)
# Emp Rej Rate: 0.1900 (at significance level 0.05)
# ==================================================
#
# [15:15:46] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3500 (at significance level 0.023700000000000006)
# Emp Rej Rate: 0.2100 (at significance level 0.01095)
# ==================================================
#
# [15:20:41] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7450 (at significance level 0.023700000000000006)
# Emp Rej Rate: 0.6600 (at significance level 0.01095)
# ==================================================
#
# [15:25:36] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9800 (at significance level 0.023700000000000006)
# Emp Rej Rate: 0.9550 (at significance level 0.01095)
# ==================================================
#
# [15:30:30] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.023700000000000006)
# Emp Rej Rate: 1.0000 (at significance level 0.01095)
# ==================================================
#
# [15:35:24] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.25
# Process LokyProcess-272:
# Process LokyProcess-269:
# Process LokyProcess-271:
# Process LokyProcess-267:
# Process LokyProcess-256:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1797 if (nb_jobs == 0) or (
#    1798     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799 ):
# -> 1800     time.sleep(0.01)
#    1801     continue
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 22
#      20 for alpha_x in [0.05, 0.10, 0.15, 0.20, 0.25]:
#      21         param["alpha_x"] = alpha_x
# ---> 22         p_val_list_h1 = run_experiment(param)
#
# Cell In[1], line 715, in run_experiment(params)
#     712     print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")
#     714 # [修改4] 按 job_index % num_gpus 轮询分配 GPU
# --> 715 p_values = Parallel(n_jobs=num_cores)(
#     716     delayed(mGAN)(
#     717         n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
#     718         epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
#     719         a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
#     720         noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
#     721         normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
#     722         using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
#     723         lambda_median=lambda_median, median_samples=median_samples,
#     724         using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
#     725         lambda_3=lambda_3, drop_out_p=drop_out_p,
#     726         noise_dimension_var=noise_dimension_var,
#     727         noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
#     728         gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
#     729     )
#     730     for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
#     731 )
#     733 p_values = np.array(p_values)
#     734 fp = [pval < alpha for pval in p_values]
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1732, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1730 except BaseException:
#    1731     self._exception = True
# -> 1732     self._abort()
#    1733     raise
#    1734 finally:
#    1735     # Store the unconsumed tasks and terminate the workers if necessary
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1646, in Parallel._abort(self)
#    1641 if not self._aborted and hasattr(backend, "abort_everything"):
#    1642     # If the backend is managed externally we need to make sure
#    1643     # to leave it in a working state to allow for future jobs
#    1644     # scheduling.
#    1645     ensure_ready = self._managed_backend
# -> 1646     backend.abort_everything(ensure_ready=ensure_ready)
#    1647 self._aborted = True
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/_parallel_backends.py:725, in LokyBackend.abort_everything(self, ensure_ready)
#     723 def abort_everything(self, ensure_ready=True):
#     724     """Shutdown the workers and restart a new one with the same parameters"""
# --> 725     self._workers.terminate(kill_workers=True)
#     726     self._workers = None
#     728     if ensure_ready:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/executor.py:86, in MemmappingExecutor.terminate(self, kill_workers)
#      85 def terminate(self, kill_workers=False):
# ---> 86     self.shutdown(kill_workers=kill_workers)
#      88     # When workers are killed in a brutal manner, they cannot execute the
#      89     # finalizer of their shared memmaps. The refcount of those memmaps may
#      90     # be off by an unknown number, so instead of decref'ing them, we force
#    (...)
#      95     # with allow_non_empty=True but if we can't, it will be clean up later
#      96     # on by the resource_tracker.
#      97     with self._submit_resize_lock:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1333, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1329 if executor_manager_thread is not None and wait:
#    1330     # This locks avoids concurrent join if the interpreter
#    1331     # is shutting down.
#    1332     with _global_shutdown_lock:
# -> 1333         executor_manager_thread.join()
#    1334         _threads_wakeups.pop(executor_manager_thread, None)
#    1336 # To reduce the risk of opening too many files, remove references to
#    1337 # objects that use file descriptors.
#
# File /opt/anaconda3/lib/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/anaconda3/lib/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0.5
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [15:40:45] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.1900 (at significance level 0.1)
# Emp Rej Rate: 0.1100 (at significance level 0.05)
# ==================================================
#
# [15:45:41] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1200 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.0550 (at significance level 0.017)
# ==================================================
#
# [15:52:24] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2900 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.1600 (at significance level 0.017)
# ==================================================
#
# [15:58:46] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3550 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.2350 (at significance level 0.017)
# ==================================================
#
# [16:04:27] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4000 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.3000 (at significance level 0.017)
# ==================================================
#
# [16:09:34] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.6000 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.5150 (at significance level 0.017)
# ==================================================
#
# [16:14:15] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8050 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.6900 (at significance level 0.017)
# ==================================================
#
# [16:18:59] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8550 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.7900 (at significance level 0.017)
# ==================================================
#
# [16:23:41] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9750 (at significance level 0.037700000000000004)
# Emp Rej Rate: 0.9600 (at significance level 0.017)
# ==================================================
#
# [16:28:26] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.5, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.037700000000000004)
# Emp Rej Rate: 1.0000 (at significance level 0.017)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0.3
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [17:10:13] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2450 (at significance level 0.1)
# Emp Rej Rate: 0.1400 (at significance level 0.05)
# ==================================================
#
# [17:15:05] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.0950 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.0550 (at significance level 0.011)
# ==================================================
#
# [17:19:57] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2650 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.1600 (at significance level 0.011)
# ==================================================
#
# [17:24:53] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2350 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.1300 (at significance level 0.011)
# ==================================================
#
# [17:29:45] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3400 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.2250 (at significance level 0.011)
# ==================================================
#
# [17:34:38] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5150 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.3850 (at significance level 0.011)
# ==================================================
#
# [17:39:30] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7150 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.5900 (at significance level 0.011)
# ==================================================
#
# [17:44:23] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8750 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.8050 (at significance level 0.011)
# ==================================================
#
# [17:49:16] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9550 (at significance level 0.024900000000000002)
# Emp Rej Rate: 0.9300 (at significance level 0.011)
# ==================================================
#
# [17:54:11] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.3, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.024900000000000002)
# Emp Rej Rate: 1.0000 (at significance level 0.011)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 0.8
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [17:59:30] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.1900 (at significance level 0.1)
# Emp Rej Rate: 0.0950 (at significance level 0.05)
# ==================================================
#
# [18:03:43] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1700 (at significance level 0.051)
# Emp Rej Rate: 0.0750 (at significance level 0.01495)
# ==================================================
#
# [18:07:59] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3250 (at significance level 0.051)
# Emp Rej Rate: 0.2000 (at significance level 0.01495)
# ==================================================
#
# [18:12:14] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4250 (at significance level 0.051)
# Emp Rej Rate: 0.2700 (at significance level 0.01495)
# ==================================================
#
# [18:16:29] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5200 (at significance level 0.051)
# Emp Rej Rate: 0.3900 (at significance level 0.01495)
# ==================================================
#
# [18:20:44] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.6950 (at significance level 0.051)
# Emp Rej Rate: 0.5300 (at significance level 0.01495)
# ==================================================
#
# [18:24:56] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8300 (at significance level 0.051)
# Emp Rej Rate: 0.6950 (at significance level 0.01495)
# ==================================================
#
# [18:29:12] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9150 (at significance level 0.051)
# Emp Rej Rate: 0.8150 (at significance level 0.01495)
# ==================================================
#
# [18:33:28] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9750 (at significance level 0.051)
# Emp Rej Rate: 0.9550 (at significance level 0.01495)
# ==================================================
#
# [18:37:45] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 0.8, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.051)
# Emp Rej Rate: 1.0000 (at significance level 0.01495)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_median"] = 1
param["median_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [21:45:22] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2750 (at significance level 0.1)
# Emp Rej Rate: 0.2050 (at significance level 0.05)
# ==================================================
#
# [21:49:26] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.0850 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.0100 (at significance level 0.003)
# ==================================================
#
# [21:54:12] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1850 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.0850 (at significance level 0.003)
# ==================================================
#
# [21:58:56] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2800 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.1500 (at significance level 0.003)
# ==================================================
#
# [22:04:02] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3050 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.1350 (at significance level 0.003)
# ==================================================
#
# [22:09:10] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5200 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.3300 (at significance level 0.003)
# ==================================================
#
# [22:14:01] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.6900 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.4950 (at significance level 0.003)
# ==================================================
#
# [22:19:01] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8350 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.6950 (at significance level 0.003)
# ==================================================
#
# [22:23:29] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9550 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.9200 (at significance level 0.003)
# ==================================================
#
# [22:27:21] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型中位数对齐超参数(pinball): 1, 实验次数: 200, 并行核数: 20, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.012700000000000006)
# Emp Rej Rate: 0.9950 (at significance level 0.003)
# ==================================================

# %%
# ============================================================
# 参数配置
# ============================================================
param = {
    "test": "power",              # ['type1error', 'power']
    "sample_size": 200,           # [200, 400, 600, 800, 1000]
    "batch_size": 128,            # [32, 64, 128, 256]
    "z_dim": 1,                   # [5, 50, 250]
    "dx": 1,
    "dy": 1,
    "n_test": 100,                # [200, 2000] number of trails to run
    "epochs_num": 100,            # [1000, 1500] number of epoch
    "eps_std": 1.0,               # epsilon std
    "dist_z": 'gaussian',         # ['laplace', 'gaussian']
    "alpha_x": 0.20,              # only used under alternative [0.05, 0.10, 0.15, 0.20, 0.25]
    "m_value": 100,               # [100, 200]
    "k_value": 8,                 # [2, 4, 6, 8] fold number
    "j_value": 1000,              # [1000, 2000]
    "noise_dimension": 5,         # [5, 10, 20]
    "noise_dimension_type": "normal",   # ["normal", "unif", "Cauchy"]
    "noise_dimension_var": 1,     # [1, 4, 9, 16]
    "hidden_layer_size": 1024,    # [64, 128, 256, 512, 1024]
    "normal_ini": False,
    "preprocess": 'scale',        # ['normalize', 'scale', 'None']
    "G_lr": 7e-5,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 0,
    "using_orcale": False,
    "lambda_1": 1,
    "lambda_2": 1,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-4,
    "lambda_4": 2e-5,
    "drop_out_p": 0.2,
    "is_sparse": True,
    "sparse_ratio": 0.05,
    "lambda_mean": 0.3,
    "mean_samples": 20
}

import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools
from tqdm import tqdm

# ============================================================
# [修改] 删除全局 device 变量，改为在 mGAN() 内部按 gpu_id 动态创建。
# 原代码：
#   enable_cuda = True
#   device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')
# ============================================================


def generate_samples_random(size=1000, sType='H0', dx=1, dy=1, dz=1,
                            nstd=1.0, alpha_x=0.05,
                            preprocess="None", dist_z='student_t_heavy',
                            t_df=3.0):    
    """    Student-t heavy-tailed conditional dependence DGP.
    H0:        X = Z + s(Z) * eps_x        Y = Z + s(Z) * eps_y
    H1:        X = Z + s(Z) * eps_x        Y = Z + s(Z) * [Delta * eps_x + (1 - Delta) * eps_y]
    where eps_x, eps_y are standardized Student-t noises.    """

    num = size

    # Z distribution
    if dist_z in ['student_t_heavy', 'uniform']:
        Z = 2.0 * torch.rand(num, dz) - 1.0
    elif dist_z == 'gaussian':
        z_generator = TD.MultivariateNormal(torch.zeros(dz), torch.eye(dz))
        Z = z_generator.sample((num,))
    elif dist_z == 'laplace':
        laplace = TD.Laplace(torch.zeros(dz), torch.ones(dz))
        Z = laplace.sample((num,))
    else:
        raise ValueError(f"Unsupported dist_z: {dist_z}")

    z1 = Z[:, 0:1]

    # conditional location
    mX = z1
    mY = z1

    # conditional scale: heteroskedastic but smooth
    sX = 0.5 + torch.abs(z1)
    sY = 0.5 + torch.abs(z1)

    # Student-t heavy-tailed noise
    t_dist = TD.StudentT(df=torch.tensor(t_df))

    eps_x = t_dist.sample((num, 1))
    eps_y = t_dist.sample((num, 1))

    # standardize variance when df > 2
    if t_df > 2:
        scale = np.sqrt(t_df / (t_df - 2.0))
        eps_x = eps_x / scale
        eps_y = eps_y / scale

    if sType == 'H0':
        eps_y_star = eps_y

    elif sType == 'H1':
        delta = torch.bernoulli(torch.ones(num, 1) * alpha_x)
        eps_y_star = delta * eps_x + (1.0 - delta) * eps_y

    else:
        raise ValueError("sType must be 'H0' or 'H1'.")

    X = mX + sX * nstd * eps_x
    Y = mY + sY * nstd * eps_y_star

    if dx > 1:
        X = X.repeat(1, dx)
    if dy > 1:
        Y = Y.repeat(1, dy)

    return X.float(), Y.float(), Z.float()


def generate_samples_from_fixed_Z_random(Z, size=1000, sType='H0', dx=1, dy=1, dz=1,
                                          nstd=1.0, alpha_x=0.05, normalize=True,
                                          seed=None, dist_z='gaussian'):
    num = size
    error_generator_x = TD.MultivariateNormal(torch.zeros(dx), 1 * torch.eye(dx))
    error_generator_y = TD.MultivariateNormal(torch.zeros(dy), 1 * torch.eye(dy))
    Axy = torch.ones((dx, dy)) * alpha_x
    m = TD.Bernoulli(torch.tensor([alpha_x]))
    if sType == 'H0':
        error_x = error_generator_x.sample((num,))
        error_y = error_generator_y.sample((num,))
        X = Z + nstd * error_x
        Y = Z + nstd * error_y
    else:
        error_x = error_generator_x.sample((num,))
        error_y = error_generator_y.sample((num,))
        delta = m.sample((num,))
        X = Z + (1 - delta) * nstd * error_x + delta * nstd * error_y
        Y = Z + nstd * error_y
    return X, Y


def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                        x_torch, y_torch, z_torch, sigma_w,
                        sigma_u=1, sigma_v=1, boor_rv_type="gaussian",
                        device=None):  # [修改] 新增 device 参数
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2)
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(torch.exp(-torch.abs(
        gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u), dim=2)
    u_mx_3 = u_mx_2.T
    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(torch.exp(-torch.abs(
        gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(torch.exp(-torch.abs(
        gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v), dim=2)
    v_mx_3 = v_mx_2.T
    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(torch.exp(-torch.abs(
        gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(torch.exp(-torch.abs(
            gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
        sum_mx = sum_mx + temp_add_mx
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(torch.exp(-torch.abs(
            gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
        sum2_mx = sum2_mx + temp2_add_mx

    u_mx_4 = 1 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4
    v_mx_4 = 1 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n).to(device))  # [修改]
    stat = 1 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])
    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num)).to(device)  # [修改]
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num).to(device)              # [修改]
    for bb in range(boot_num):
        random_mx = torch.matmul(eboot[:, bb].reshape(-1, 1), eboot[:, bb].reshape(-1, 1).T)
        bootmatrix = FF_mx * random_mx
        stat_boot = 1 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)
    return stat, boottemp


class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (self.X_real[index], self.Y_real[index], self.Z_real[index],
                self.Z_real[(self.batch_size + index) % self.sample_size])


class DatasetSelect_GAN_ver2(torch.utils.data.Dataset):
    def __init__(self, Y, Z, batch_size):
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = Z.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.Y_real[index], self.Z_real[index]


##### Auxilliary functions #####

def sample_noise(sample_size, noise_dimension, noise_type, input_var=1,
                 device=None):  # [修改] 新增 device 参数
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),          # [修改]
            input_var * torch.eye(noise_dimension).to(device) # [修改]
        )
        Z = noise_generator.sample((sample_size,))
    if noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension)
    if noise_type == "Cauchy":
        Z = TD.Cauchy(torch.tensor([0.0]), torch.tensor([1.0])).sample(
            (sample_size, noise_dimension)).squeeze(2)
    return Z


##### GAN architecture #####

class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p, drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN3 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc3 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)
        self.sigmoid = torch.nn.Sigmoid()
        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out3 = torch.nn.Dropout(p=drop_out_p)
        self.drop_input = drop_input

    def forward(self, x):
        if self.BN_type:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
            # x = self.drop_out3(self.leakyReLU1(self.BN3(self.fc3(x))))
            x = self.fc_last(x)
        else:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))
            # x = self.drop_out3(self.leakyReLU1(self.fc3(x)))
            x = self.fc_last(x)
        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        # [修改] 不在此处 .to(device)，由外层调用者统一 .to(device)
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for i in range(m)])

    def forward(self, x):
        # [修改] mask 动态跟随模型所在设备
        self.linear.weight.data *= self.mask.to(self.linear.weight.device)
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)
        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0])
        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for i in range(len(self.hidden_layer_sizes))
        ])
        self.linear8 = torch.nn.Linear(
            self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)
        return self.linear8(output)


##### Training procedures #####

def find_loss(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-torch.abs(Y.repeat(1, n) - Y.repeat(1, n).T) / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    mx_1_2 = torch.exp(-mx_1_2 / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-torch.abs(Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-torch.abs(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def find_loss_2(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-(Y.repeat(1, n) - Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=2, dim=2)
    mx_1_2 = torch.exp(-(mx_1_2 ** 2) / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-(Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def train_ver3(
        G_zx, G_zy,
        X, Y, Z, X_test, Y_test, Z_test, M,
        noise_dimension, noise_type, G_lr, hidden_layer_size,
        DataLoader, BN_type, ReLU_coef,
        lambda_mean=0.5, mean_samples=20,
        epochs_num=50, patience=5, min_delta=1e-5,
        sigma_z=1, sigma_x=1, sigma_y=1, normal_ini=False,
        lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
        lambda_3=0, drop_out_p=0.2, noise_dimension_var=1, lambda_4=0,
        device=None):  # [修改] 新增 device 参数
    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if G_zy is None or G_zx is None:
        if using_Gen == '1':
            G_zy = Generator(input_dimension, output_dimension_y, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改]
            G_zx = Generator(input_dimension, output_dimension_x, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改]
        elif using_Gen == '2':
            G_zy = Generator_2(input_dimension, output_dimension_y, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改]
            G_zx = Generator_2(input_dimension, output_dimension_x, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改]
        if normal_ini:
            for p in G_zy.parameters():
                p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改]
            for p in G_zx.parameters():
                p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改]

    # 无论是否是新模型，每一折都重新定义优化器以清空动量状态
    G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    iter_count = 0
    G_zy = G_zy.train()
    G_zx = G_zx.train()

    best_loss = float('inf')
    counter = 0

    for epoch in range(epochs_num):
        batch_count = 0
        G_zy = G_zy.train()
        G_zx = G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)   # [修改]
            Y_real = Y_real.to(device)   # [修改]
            Z_real = Z_real.to(device)   # [修改]
            Z_fake = Z_fake.to(device)   # [修改]

            batch_size = Z_real.shape[0]
            Z_repeated = Z_real.repeat_interleave(mean_samples, dim=0)

            Noise_for_mean = sample_noise(Z_repeated.shape[0], noise_dimension, noise_type,
                                          input_var=noise_dimension_var, device=device).to(device)  # [修改]

            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)       # [修改]
            Y_fake = G_zy(torch.cat((Z_real, Noise_fake), dim=1)).to(device)
            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)       # [修改]
            X_fake = G_zx(torch.cat((Z_real, Noise_fake), dim=1)).to(device)

            Y_generated_group = G_zy(torch.cat((Z_repeated, Noise_for_mean), dim=1))
            Y_generated_reshaped = Y_generated_group.reshape(batch_size, mean_samples, -1)
            Y_mean_pred = torch.mean(Y_generated_reshaped, dim=1)
            loss_mean_y = torch.nn.functional.mse_loss(Y_mean_pred, Y_real)

            X_generated_group = G_zx(torch.cat((Z_repeated, Noise_for_mean), dim=1))
            X_mean_pred = torch.mean(X_generated_group.reshape(batch_size, mean_samples, -1), dim=1)
            loss_mean_x = torch.nn.functional.mse_loss(X_mean_pred, X_real)

            g_zy_error = None
            G_zy_solver.zero_grad()
            g_zx_error = None
            G_zx_solver.zero_grad()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param in G_zy.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = (lambda_1 * find_loss(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_2 * find_loss_2(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zy_error = mmd_loss_y + lambda_mean * loss_mean_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param in G_zx.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = (lambda_1 * find_loss(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_2 * find_loss_2(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zx_error = mmd_loss_x + lambda_mean * loss_mean_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

            iter_count += 1
            batch_count += 1

        current_loss = g_zx_error + g_zy_error
        if current_loss < best_loss - min_delta:
            best_loss = current_loss
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            break

    return G_zy, G_zx


def mGAN(n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_orcale=False, lambda_1=1, lambda_2=1,
         lambda_mean=0.3, mean_samples=20, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2,
         noise_dimension_var=1, noise_dimension_type="normal", lambda_4=1,
         gpu_id=0):  # [修改] 新增 gpu_id 参数
    """
    gpu_id: 该 worker 使用的 GPU 编号（0/1/2/3）。
    由 run_experiment() 通过 job_index % num_gpus 传入，
    使不同 worker 分配到不同 GPU，而非全部挤在 GPU 0 上。
    """
    # [修改] 在函数内部根据 gpu_id 创建局部 device
    enable_cuda = True
    if torch.cuda.is_available() and enable_cuda:
        device = torch.device(f'cuda:{gpu_id}')
    else:
        device = torch.device('cpu')

    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H0', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H1', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x.to(device), sim_y.to(device), sim_z.to(device)

    w_mx = torch.linalg.vector_norm(
        z.repeat(n, 1, 1) - torch.swapaxes(z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    sigma_w = torch.median(w_mx).item()
    u_mx = torch.exp(-torch.abs(y.repeat(1, n) - y.repeat(1, n).T))
    sigma_u = torch.median(u_mx).item()
    v_mx = torch.exp(-torch.abs(x.repeat(1, n) - x.repeat(1, n).T))
    sigma_v = torch.median(v_mx).item()

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    if not using_orcale:
        G_zy = Generator(z_dim, y_dims, noise_dimension, hidden_layer_size,
                         False, 0.1, drop_out_p).to(device)   # [修改]
        G_zx = Generator(z_dim, x_dims, noise_dimension, hidden_layer_size,
                         False, 0.1, drop_out_p).to(device)   # [修改]

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))
        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]
        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))
        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_orcale:
            current_epochs = epochs_num if k_fold == 0 else max(10, epochs_num // 5)
            G_zy, G_zx = train_ver3(
                G_zx=G_zx, G_zy=G_zy,
                X=X_train, Y=Y_train, Z=Z_train, M=M,
                X_test=X_test, Y_test=Y_test, Z_test=Z_test,
                noise_dimension=noise_dimension, noise_type=noise_dimension_type,
                G_lr=G_lr, hidden_layer_size=hidden_layer_size,
                DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
                lambda_mean=lambda_mean, mean_samples=mean_samples,
                epochs_num=epochs_num, sigma_z=sigma_w, sigma_x=sigma_v, sigma_y=sigma_u,
                normal_ini=normal_ini, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, wgt_decay=wgt_decay, lambda_3=lambda_3,
                drop_out_p=drop_out_p, noise_dimension_var=noise_dimension_var,
                lambda_4=lambda_4,
                device=device)   # [修改] 传入局部 device

        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M, device=device)   # [修改]
        gen_y_all = torch.zeros(test_size, M, device=device)   # [修改]
        z_all = torch.zeros(test_size, z_dim, device=device)   # [修改]
        x_all = torch.zeros(test_size, x_dims, device=device)  # [修改]
        y_all = torch.zeros(test_size, y_dims, device=device)  # [修改]
        cur_itr = 0
        G_zx = G_zx.eval()
        G_zy = G_zy.eval()

        for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
            z_test_temp = z_test.repeat(M, 1)
            if not using_orcale:
                z_test_temp = z_test_temp.to(device)                                    # [修改]
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)            # [修改]
                with torch.no_grad():
                    fake_x = G_zx(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)            # [修改]
                with torch.no_grad():
                    fake_y = G_zy(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
            elif using_orcale:
                if simulation == 'type1error':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H0', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)
                elif simulation == 'power':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H1', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)

            gen_x_all[cur_itr, :] = fake_x.detach().reshape(-1)
            gen_y_all[cur_itr, :] = fake_y.detach().reshape(-1)
            x_all[cur_itr, :] = x_test
            y_all[cur_itr, :] = y_test
            z_all[cur_itr, :] = z_test
            cur_itr = cur_itr + 1

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type,
            device=device)   # [修改] 传入局部 device

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp)
        cur_k = cur_k + 1

    if using_orcale:
        gen_x_mean = torch.mean(gen_x_all, dim=1).reshape(-1, 1)
        gen_y_mean = torch.mean(gen_y_all, dim=1).reshape(-1, 1)
        mse_x = torch.mean((gen_x_mean - x_all) ** 2).item()
        mse_y = torch.mean((gen_y_mean - y_all) ** 2).item()
        print(f'Test MSE x [{mse_x}], MSE y [{mse_y}]')

    return np.mean(torch.mean(boot_temp_all, dim=0).numpy() > torch.mean(stat_all).item())


# ============================================================
# 并行部分
# ============================================================
from joblib import Parallel, delayed
import multiprocessing
import numpy as np
from datetime import datetime


def run_experiment(params):
    # 1. 提取参数
    test                 = params["test"]
    sample_size          = params["sample_size"]
    batch_size           = params["batch_size"]
    z_dim                = params["z_dim"]
    dx                   = params["dx"]
    dy                   = params["dy"]
    n_test               = params["n_test"]
    epochs_num           = params["epochs_num"]
    eps_std              = params["eps_std"]
    dist_z               = params["dist_z"]
    alpha_x              = params["alpha_x"]
    m_value              = params["m_value"]
    k_value              = params["k_value"]
    j_value              = params["j_value"]
    noise_dimension      = params["noise_dimension"]
    noise_dimension_type = params["noise_dimension_type"]
    noise_dimension_var  = params["noise_dimension_var"]
    hidden_layer_size    = params["hidden_layer_size"]
    normal_ini           = params["normal_ini"]
    preprocess           = params["preprocess"]
    G_lr                 = params["G_lr"]
    alpha                = params["alpha"]
    alpha1               = params["alpha1"]
    set_seeds            = params["set_seeds"]
    using_orcale         = params["using_orcale"]
    lambda_1             = params["lambda_1"]
    lambda_2             = params["lambda_2"]
    using_Gen            = params["using_Gen"]
    boor_rv_type         = params["boor_rv_type"]
    wgt_decay            = params["wgt_decay"]
    lambda_3             = params["lambda_3"]
    lambda_4             = params["lambda_4"]
    drop_out_p           = params["drop_out_p"]
    lambda_mean          = params["lambda_mean"]
    mean_samples         = params["mean_samples"]

    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    # 2. [修改] 获取可用 GPU 数量，用于轮询分配
    num_gpus = torch.cuda.device_count() if torch.cuda.is_available() else 1
    num_cores = min(28, n_test)
    if num_cores < 1:
        num_cores = 1

    print(f"[{datetime.now().strftime('%H:%M:%S')}] 开始并行实验...")
    print(f"模式: {test}, 样本量: {sample_size}, 交叉验证折数: {k_value}, "
          f"模型均值对齐超参数: {lambda_mean}, 实验次数: {n_test}, "
          f"并行核数: {num_cores}, 可用GPU数: {num_gpus}")
    if test == 'power':
        print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")

    # 3. [修改] 按 job_index % num_gpus 轮询分配 GPU
    #    job 0,4,8,...  → GPU 0
    #    job 1,5,9,...  → GPU 1
    #    job 2,6,10,... → GPU 2
    #    job 3,7,11,... → GPU 3
    p_values = Parallel(n_jobs=num_cores)(
        delayed(mGAN)(
            n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
            epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
            a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
            noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
            normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
            using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
            lambda_mean=lambda_mean, mean_samples=mean_samples,
            using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
            lambda_3=lambda_3, drop_out_p=drop_out_p,
            noise_dimension_var=noise_dimension_var,
            noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
            gpu_id=job_index % num_gpus    # [修改] 轮询分配 GPU
        )
        for job_index, _ in enumerate(range(n_test))  # [修改] enumerate 获取 job_index
    )

    p_values = np.array(p_values)

    # 4. 计算拒绝率
    fp = [pval < alpha for pval in p_values]
    final_result = np.mean(fp)
    fp1 = [pval < alpha1 for pval in p_values]
    final_result1 = np.mean(fp1)

    # 5. 打印结果
    print(f"\n" + "=" * 50)
    print(f"实验类型: {test.upper()}")
    print(f"Z Dimension: {z_dim}")
    print(f"Emp Rej Rate: {final_result:.4f} (at significance level {alpha})")
    print(f"Emp Rej Rate: {final_result1:.4f} (at significance level {alpha1})")
    print("=" * 50 + "\n")

    return p_values

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_mean"] = 0
param["mean_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [15:10:42] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2300 (at significance level 0.1)
# Emp Rej Rate: 0.0950 (at significance level 0.05)
# ==================================================
#
# [15:15:44] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
# Process LokyProcess-612:
# Process LokyProcess-605:
# Process LokyProcess-598:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-622:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-618:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-626:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-625:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-623:
# Process LokyProcess-602:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 518, in _process_worker
#     mem_usage = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-621:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# Process LokyProcess-620:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 505, in _process_worker
#     _process_reference_size = _get_memory_usage(pid, force_gc=True)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 110, in _get_memory_usage
#     gc.collect()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1797 if (nb_jobs == 0) or (
#    1798     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799 ):
# -> 1800     time.sleep(0.01)
#    1801     continue
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 22
#      20 for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
#      21         param["alpha_x"] = alpha_x
# ---> 22         p_val_list_h1 = run_experiment(param)
#
# Cell In[6], line 746, in run_experiment(params)
#     739     print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")
#     741 # 3. [修改] 按 job_index % num_gpus 轮询分配 GPU
#     742 #    job 0,4,8,...  → GPU 0
#     743 #    job 1,5,9,...  → GPU 1
#     744 #    job 2,6,10,... → GPU 2
#     745 #    job 3,7,11,... → GPU 3
# --> 746 p_values = Parallel(n_jobs=num_cores)(
#     747     delayed(mGAN)(
#     748         n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
#     749         epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
#     750         a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
#     751         noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
#     752         normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
#     753         using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
#     754         lambda_mean=lambda_mean, mean_samples=mean_samples,
#     755         using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
#     756         lambda_3=lambda_3, drop_out_p=drop_out_p,
#     757         noise_dimension_var=noise_dimension_var,
#     758         noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
#     759         gpu_id=job_index % num_gpus    # [修改] 轮询分配 GPU
#     760     )
#     761     for job_index, _ in enumerate(range(n_test))  # [修改] enumerate 获取 job_index
#     762 )
#     764 p_values = np.array(p_values)
#     766 # 4. 计算拒绝率
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1732, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1730 except BaseException:
#    1731     self._exception = True
# -> 1732     self._abort()
#    1733     raise
#    1734 finally:
#    1735     # Store the unconsumed tasks and terminate the workers if necessary
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1646, in Parallel._abort(self)
#    1641 if not self._aborted and hasattr(backend, "abort_everything"):
#    1642     # If the backend is managed externally we need to make sure
#    1643     # to leave it in a working state to allow for future jobs
#    1644     # scheduling.
#    1645     ensure_ready = self._managed_backend
# -> 1646     backend.abort_everything(ensure_ready=ensure_ready)
#    1647 self._aborted = True
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/_parallel_backends.py:725, in LokyBackend.abort_everything(self, ensure_ready)
#     723 def abort_everything(self, ensure_ready=True):
#     724     """Shutdown the workers and restart a new one with the same parameters"""
# --> 725     self._workers.terminate(kill_workers=True)
#     726     self._workers = None
#     728     if ensure_ready:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/executor.py:86, in MemmappingExecutor.terminate(self, kill_workers)
#      85 def terminate(self, kill_workers=False):
# ---> 86     self.shutdown(kill_workers=kill_workers)
#      88     # When workers are killed in a brutal manner, they cannot execute the
#      89     # finalizer of their shared memmaps. The refcount of those memmaps may
#      90     # be off by an unknown number, so instead of decref'ing them, we force
#    (...)
#      95     # with allow_non_empty=True but if we can't, it will be clean up later
#      96     # on by the resource_tracker.
#      97     with self._submit_resize_lock:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1333, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1329 if executor_manager_thread is not None and wait:
#    1330     # This locks avoids concurrent join if the interpreter
#    1331     # is shutting down.
#    1332     with _global_shutdown_lock:
# -> 1333         executor_manager_thread.join()
#    1334         _threads_wakeups.pop(executor_manager_thread, None)
#    1336 # To reduce the risk of opening too many files, remove references to
#    1337 # objects that use file descriptors.
#
# File /opt/anaconda3/lib/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/anaconda3/lib/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_mean"] = 0.3
param["mean_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [22:32:40] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.0750 (at significance level 0.1)
# Emp Rej Rate: 0.0250 (at significance level 0.05)
# ==================================================
#
# [22:37:11] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1900 (at significance level 0.1258)
# Emp Rej Rate: 0.1200 (at significance level 0.07530000000000002)
# ==================================================
#
# [22:41:30] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2150 (at significance level 0.1258)
# Emp Rej Rate: 0.1600 (at significance level 0.07530000000000002)
# ==================================================
#
# [22:45:44] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2750 (at significance level 0.1258)
# Emp Rej Rate: 0.1800 (at significance level 0.07530000000000002)
# ==================================================
#
# [22:49:58] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_mean"] = 0.3
param["mean_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [11:38:23] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# /home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.0850 (at significance level 0.1)
# Emp Rej Rate: 0.0400 (at significance level 0.05)
# ==================================================
#
# [11:42:56] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3500 (at significance level 0.11640000000000002)
# Emp Rej Rate: 0.2100 (at significance level 0.05670000000000001)
# ==================================================
#
# [11:47:14] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4650 (at significance level 0.11640000000000002)
# Emp Rej Rate: 0.3250 (at significance level 0.05670000000000001)
# ==================================================
#
# [11:51:38] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7050 (at significance level 0.11640000000000002)
# Emp Rej Rate: 0.5900 (at significance level 0.05670000000000001)
# ==================================================
#
# [11:55:51] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8400 (at significance level 0.11640000000000002)
# Emp Rej Rate: 0.7650 (at significance level 0.05670000000000001)
# ==================================================
#
# [12:00:11] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9700 (at significance level 0.11640000000000002)
# Emp Rej Rate: 0.9500 (at significance level 0.05670000000000001)
# ==================================================
#
# [12:04:25] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.11640000000000002)
# Emp Rej Rate: 1.0000 (at significance level 0.05670000000000001)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_mean"] = 0.5
param["mean_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [12:12:39] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.0750 (at significance level 0.1)
# Emp Rej Rate: 0.0450 (at significance level 0.05)
# ==================================================
#
# [12:16:09] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1600 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.0700 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:19:44] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2800 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.1750 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:23:17] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3200 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.2050 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:26:54] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3900 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.2750 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:30:26] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5600 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.4150 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:34:01] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.6700 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.5750 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:37:37] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8700 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.7700 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:41:07] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9950 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.9550 (at significance level 0.055900000000000005)
# ==================================================
#
# [12:44:38] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 模型均值对齐超参数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9900 (at significance level 0.11580000000000001)
# Emp Rej Rate: 0.9900 (at significance level 0.055900000000000005)
# ==================================================

# %%
param = {
    "test": "power",
    "sample_size": 200,
    "batch_size": 128,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 100,
    "eps_std": 1.0,
    "dist_z": 'gaussian',
    "alpha_x": 0.20,
    "m_value": 100,
    "k_value": 8,
    "j_value": 1000,
    "noise_dimension": 5,
    "noise_dimension_type": "normal",
    "noise_dimension_var": 1,
    "hidden_layer_size": 1024,
    "normal_ini": False,
    "preprocess": 'scale',
    "G_lr": 7e-5,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 0,
    "using_orcale": False,
    "lambda_1": 1,
    "lambda_2": 1,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-4,
    "lambda_4": 2e-5,
    "drop_out_p": 0.2,
    "is_sparse": True,
    "sparse_ratio": 0.05,
    "lambda_quantile": 0.5,
    "quantile_samples": 20
}

import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools
from tqdm import tqdm

# [修改1] 删除全局 device，改为在 mGAN() 内部按 gpu_id 动态创建

def generate_samples_random(size=1000, sType='H0', dx=1, dy=1, dz=1,
                            nstd=1.0, alpha_x=0.05,
                            preprocess="None", dist_z='student_t_heavy',
                            t_df=3.0):    
    """    Student-t heavy-tailed conditional dependence DGP.
    H0:        X = Z + s(Z) * eps_x        Y = Z + s(Z) * eps_y
    H1:        X = Z + s(Z) * eps_x        Y = Z + s(Z) * [Delta * eps_x + (1 - Delta) * eps_y]
    where eps_x, eps_y are standardized Student-t noises.    """

    num = size

    # Z distribution
    if dist_z in ['student_t_heavy', 'uniform']:
        Z = 2.0 * torch.rand(num, dz) - 1.0
    elif dist_z == 'gaussian':
        z_generator = TD.MultivariateNormal(torch.zeros(dz), torch.eye(dz))
        Z = z_generator.sample((num,))
    elif dist_z == 'laplace':
        laplace = TD.Laplace(torch.zeros(dz), torch.ones(dz))
        Z = laplace.sample((num,))
    else:
        raise ValueError(f"Unsupported dist_z: {dist_z}")

    z1 = Z[:, 0:1]

    # conditional location
    mX = z1
    mY = z1

    # conditional scale: heteroskedastic but smooth
    sX = 0.5 + torch.abs(z1)
    sY = 0.5 + torch.abs(z1)

    # Student-t heavy-tailed noise
    t_dist = TD.StudentT(df=torch.tensor(t_df))

    eps_x = t_dist.sample((num, 1))
    eps_y = t_dist.sample((num, 1))

    # standardize variance when df > 2
    if t_df > 2:
        scale = np.sqrt(t_df / (t_df - 2.0))
        eps_x = eps_x / scale
        eps_y = eps_y / scale

    if sType == 'H0':
        eps_y_star = eps_y

    elif sType == 'H1':
        delta = torch.bernoulli(torch.ones(num, 1) * alpha_x)
        eps_y_star = delta * eps_x + (1.0 - delta) * eps_y

    else:
        raise ValueError("sType must be 'H0' or 'H1'.")

    X = mX + sX * nstd * eps_x
    Y = mY + sY * nstd * eps_y_star

    if dx > 1:
        X = X.repeat(1, dx)
    if dy > 1:
        Y = Y.repeat(1, dy)

    return X.float(), Y.float(), Z.float()


def generate_samples_from_fixed_Z_random(Z, size=1000, sType='H0', dx=1, dy=1, dz=1, nstd=1.0,
                                          alpha_x=0.05, normalize=True, seed=None, dist_z='gaussian'):
    num = size
    error_generator_x = TD.MultivariateNormal(torch.zeros(dx), 1 * torch.eye(dx))
    error_generator_y = TD.MultivariateNormal(torch.zeros(dy), 1 * torch.eye(dy))
    Axy = torch.ones((dx, dy)) * alpha_x
    m = TD.Bernoulli(torch.tensor([alpha_x]))
    if sType == 'H0':
        error_x = error_generator_x.sample((num,))
        error_y = error_generator_y.sample((num,))
        X = Z + nstd * error_x
        Y = Z + nstd * error_y
    else:
        error_x = error_generator_x.sample((num,))
        error_y = error_generator_y.sample((num,))
        delta = m.sample((num,))
        X = Z + (1 - delta) * nstd * error_x + delta * nstd * error_y
        Y = Z + nstd * error_y
    return X, Y


def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch, x_torch, y_torch, z_torch,
                        sigma_w, sigma_u=1, sigma_v=1, boor_rv_type="gaussian",
                        device=None):  # [修改2] 新增 device 参数
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    w_mx = torch.exp(-w_mx / sigma_w)
    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u),
        dim=2)
    u_mx_3 = u_mx_2.T
    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v),
        dim=2)
    v_mx_3 = v_mx_2.T
    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
        sum_mx = sum_mx + temp_add_mx
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
        sum2_mx = sum2_mx + temp2_add_mx
    u_mx_4 = 1 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4
    v_mx_4 = 1 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4
    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n).to(device))  # [修改2]
    stat = 1 / (n - 1) * torch.sum(FF_mx).item()
    boottemp = np.array([])
    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num)).to(device)  # [修改2]
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num).to(device)              # [修改2]
    for bb in range(boot_num):
        random_mx = torch.matmul(eboot[:, bb].reshape(-1, 1), eboot[:, bb].reshape(-1, 1).T)
        bootmatrix = FF_mx * random_mx
        stat_boot = 1 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)
    return stat, boottemp


class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index], \
               self.Z_real[(self.batch_size + index) % self.sample_size]


class DatasetSelect_GAN_ver2(torch.utils.data.Dataset):
    def __init__(self, Y, Z, batch_size):
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = Z.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.Y_real[index], self.Z_real[index]


def sample_noise(sample_size, noise_dimension, noise_type, input_var=1,
                 device=None):  # [修改3] 新增 device 参数
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),           # [修改3]
            input_var * torch.eye(noise_dimension).to(device)) # [修改3]
        Z = noise_generator.sample((sample_size,))
    if noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension)
    if noise_type == "Cauchy":
        Z = TD.Cauchy(torch.tensor([0.0]), torch.tensor([1.0])).sample(
            (sample_size, noise_dimension)).squeeze(2)
    return Z


class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, drop_out_p, drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN3 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc3 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)
        self.sigmoid = torch.nn.Sigmoid()
        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out3 = torch.nn.Dropout(p=drop_out_p)
        self.drop_input = drop_input

    def forward(self, x):
        if self.BN_type:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
            x = self.fc_last(x)
        else:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))
            x = self.fc_last(x)
        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        # [修改3] 不在构造函数中 .to(device)，由外层统一 .to(device)
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias)
        self.mask = functools.reduce(
            torch.block_diag, [torch.ones(size_out, size_in) for i in range(m)])

    def forward(self, x):
        # [修改3] mask 动态跟随模型所在设备
        self.linear.weight.data *= self.mask.to(self.linear.weight.device)
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)
        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0])
        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for i in range(len(self.hidden_layer_sizes))
        ])
        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)
        return self.linear8(output)


def find_loss(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-torch.abs(Y.repeat(1, n) - Y.repeat(1, n).T) / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    mx_1_2 = torch.exp(-mx_1_2 / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-torch.abs(Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-torch.abs(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def find_loss_2(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-(Y.repeat(1, n) - Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=2, dim=2)
    mx_1_2 = torch.exp(-(mx_1_2 ** 2) / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-(Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def pinball_loss(y_true, y_pred, tau):
    err = y_true - y_pred
    return torch.mean(torch.max(tau * err, (tau - 1.0) * err))


def train_ver3(
        G_zx, G_zy,
        X, Y, Z, X_test, Y_test, Z_test, M,
        noise_dimension, noise_type, G_lr, hidden_layer_size,
        DataLoader, BN_type, ReLU_coef,
        lambda_quantile=0.5, quantile_samples=20,
        epochs_num=50,
        patience=5, min_delta=1e-5,
        sigma_z=1, sigma_x=1, sigma_y=1,
        normal_ini=False,
        lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
        lambda_3=0, drop_out_p=0.2, noise_dimension_var=1,
        lambda_4=0,
        device=None):  # [修改3] 新增 device 参数

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if G_zy is None or G_zx is None:
        if using_Gen == '1':
            G_zy = Generator(input_dimension, output_dimension_y, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
            G_zx = Generator(input_dimension, output_dimension_x, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
        elif using_Gen == '2':
            G_zy = Generator_2(input_dimension, output_dimension_y, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]
            G_zx = Generator_2(input_dimension, output_dimension_x, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]

        if normal_ini:
            for p in G_zy.parameters():
                p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]
            for p in G_zx.parameters():
                p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]

    G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    iter_count = 0
    G_zy = G_zy.train()
    G_zx = G_zx.train()

    best_loss = float('inf')
    counter = 0

    for epoch in range(epochs_num):
        batch_count = 0
        G_zy = G_zy.train()
        G_zx = G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)   # [修改3]
            Y_real = Y_real.to(device)   # [修改3]
            Z_real = Z_real.to(device)   # [修改3]
            Z_fake = Z_fake.to(device)   # [修改3]

            batch_size = Z_real.shape[0]
            Z_repeated = Z_real.repeat_interleave(quantile_samples, dim=0)

            Noise_for_quantile = sample_noise(
                Z_repeated.shape[0], noise_dimension, noise_type,
                input_var=noise_dimension_var, device=device).to(device)  # [修改3]

            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            Y_fake = G_zy(torch.cat((Z_real, Noise_fake), dim=1)).to(device)
            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            X_fake = G_zx(torch.cat((Z_real, Noise_fake), dim=1)).to(device)

            Y_generated_group = G_zy(torch.cat((Z_repeated, Noise_for_quantile), dim=1))
            Y_generated_reshaped = Y_generated_group.reshape(batch_size, quantile_samples, -1)
            q_25_y = torch.quantile(Y_generated_reshaped, q=0.25, dim=1)
            q_50_y = torch.quantile(Y_generated_reshaped, q=0.50, dim=1)
            q_75_y = torch.quantile(Y_generated_reshaped, q=0.75, dim=1)
            loss_q25_y = pinball_loss(Y_real, q_25_y, 0.25)
            loss_q50_y = pinball_loss(Y_real, q_50_y, 0.50)
            loss_q75_y = pinball_loss(Y_real, q_75_y, 0.75)
            loss_quantile_y = 0.15 * loss_q25_y + 0.70 * loss_q50_y + 0.15 * loss_q75_y

            X_generated_group = G_zx(torch.cat((Z_repeated, Noise_for_quantile), dim=1))
            X_generated_reshaped = X_generated_group.reshape(batch_size, quantile_samples, -1)
            q_25_x = torch.quantile(X_generated_reshaped, q=0.25, dim=1)
            q_50_x = torch.quantile(X_generated_reshaped, q=0.50, dim=1)
            q_75_x = torch.quantile(X_generated_reshaped, q=0.75, dim=1)
            loss_q25_x = pinball_loss(X_real, q_25_x, 0.25)
            loss_q50_x = pinball_loss(X_real, q_50_x, 0.50)
            loss_q75_x = pinball_loss(X_real, q_75_x, 0.75)
            loss_quantile_x = 0.15 * loss_q25_x + 0.70 * loss_q50_x + 0.15 * loss_q75_x

            g_zy_error = None
            G_zy_solver.zero_grad()
            g_zx_error = None
            G_zx_solver.zero_grad()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zy.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_y = (lambda_1 * find_loss(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_2 * find_loss_2(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zy_error = mmd_loss_y + lambda_quantile * loss_quantile_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zx.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_x = (lambda_1 * find_loss(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_2 * find_loss_2(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zx_error = mmd_loss_x + lambda_quantile * loss_quantile_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

            iter_count += 1
            batch_count += 1

        current_loss = g_zx_error + g_zy_error
        if current_loss < best_loss - min_delta:
            best_loss = current_loss
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            break

    return G_zy, G_zx


def mGAN(n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_orcale=False, lambda_1=1, lambda_2=1,
         lambda_quantile=0.5, quantile_samples=20,
         using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2,
         noise_dimension_var=1, noise_dimension_type="normal", lambda_4=1,
         gpu_id=0):  # [修改4] 新增 gpu_id 参数

    # [修改4] 在函数内部根据 gpu_id 创建局部 device
    enable_cuda = True
    if torch.cuda.is_available() and enable_cuda:
        device = torch.device(f'cuda:{gpu_id}')
    else:
        device = torch.device('cpu')

    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H0', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H1', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x.to(device), sim_y.to(device), sim_z.to(device)

    w_mx = torch.linalg.vector_norm(
        z.repeat(n, 1, 1) - torch.swapaxes(z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    sigma_w = torch.median(w_mx).item()
    u_mx = torch.exp(-torch.abs(y.repeat(1, n) - y.repeat(1, n).T))
    sigma_u = torch.median(u_mx).item()
    v_mx = torch.exp(-torch.abs(x.repeat(1, n) - x.repeat(1, n).T))
    sigma_v = torch.median(v_mx).item()

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    if not using_orcale:
        G_zy = Generator(z_dim, y_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)
        G_zx = Generator(z_dim, x_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))
        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]
        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))
        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_orcale:
            current_epochs = epochs_num if k_fold == 0 else max(10, epochs_num // 5)
            G_zy, G_zx = train_ver3(
                G_zx=G_zx, G_zy=G_zy,
                X=X_train, Y=Y_train, Z=Z_train, M=M,
                X_test=X_test, Y_test=Y_test, Z_test=Z_test,
                noise_dimension=noise_dimension, noise_type=noise_dimension_type,
                G_lr=G_lr, hidden_layer_size=hidden_layer_size,
                DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
                lambda_quantile=lambda_quantile, quantile_samples=quantile_samples,
                epochs_num=epochs_num,
                sigma_z=sigma_w, sigma_x=sigma_v, sigma_y=sigma_u,
                normal_ini=normal_ini, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, wgt_decay=wgt_decay, lambda_3=lambda_3,
                drop_out_p=drop_out_p, noise_dimension_var=noise_dimension_var,
                lambda_4=lambda_4,
                device=device)  # [修改4] 传入局部 device

        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M, device=device)   # [修改4]
        gen_y_all = torch.zeros(test_size, M, device=device)   # [修改4]
        z_all = torch.zeros(test_size, z_dim, device=device)   # [修改4]
        x_all = torch.zeros(test_size, x_dims, device=device)  # [修改4]
        y_all = torch.zeros(test_size, y_dims, device=device)  # [修改4]
        cur_itr = 0

        if not using_orcale:
            G_zx = G_zx.eval()
            G_zy = G_zy.eval()

        for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
            z_test_temp = z_test.repeat(M, 1)
            if not using_orcale:
                z_test_temp = z_test_temp.to(device)                                      # [修改4]
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_x = G_zx(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_y = G_zy(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
            elif using_orcale:
                if simulation == 'type1error':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H0', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)
                elif simulation == 'power':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H1', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)

            gen_x_all[cur_itr, :] = fake_x.detach().reshape(-1)
            gen_y_all[cur_itr, :] = fake_y.detach().reshape(-1)
            x_all[cur_itr, :] = x_test
            y_all[cur_itr, :] = y_test
            z_all[cur_itr, :] = z_test
            cur_itr = cur_itr + 1

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type,
            device=device)  # [修改4] 传入局部 device
        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp)
        cur_k = cur_k + 1

        if using_orcale:
            gen_x_50 = torch.quantile(gen_x_all, 0.50, dim=1).reshape(-1, 1)
            gen_y_50 = torch.quantile(gen_y_all, 0.50, dim=1).reshape(-1, 1)
            mse_x = torch.mean((gen_x_50 - x_all) ** 2).item()
            mse_y = torch.mean((gen_y_50 - y_all) ** 2).item()
            print(f'Test MSE x (median diff) [{mse_x}], MSE y (median diff) [{mse_y}]')

    return np.mean(torch.mean(boot_temp_all, dim=0).numpy() > torch.mean(stat_all).item())


# ============================================================
# 并行部分
# ============================================================
from joblib import Parallel, delayed
import multiprocessing

def run_experiment(params):
    test                 = params["test"]
    sample_size          = params["sample_size"]
    batch_size           = params["batch_size"]
    z_dim                = params["z_dim"]
    dx                   = params["dx"]
    dy                   = params["dy"]
    n_test               = params["n_test"]
    epochs_num           = params["epochs_num"]
    eps_std              = params["eps_std"]
    dist_z               = params["dist_z"]
    alpha_x              = params["alpha_x"]
    m_value              = params["m_value"]
    k_value              = params["k_value"]
    j_value              = params["j_value"]
    noise_dimension      = params["noise_dimension"]
    noise_dimension_type = params["noise_dimension_type"]
    noise_dimension_var  = params["noise_dimension_var"]
    hidden_layer_size    = params["hidden_layer_size"]
    normal_ini           = params["normal_ini"]
    preprocess           = params["preprocess"]
    G_lr                 = params["G_lr"]
    alpha                = params["alpha"]
    alpha1               = params["alpha1"]
    set_seeds            = params["set_seeds"]
    using_orcale         = params["using_orcale"]
    lambda_1             = params["lambda_1"]
    lambda_2             = params["lambda_2"]
    using_Gen            = params["using_Gen"]
    boor_rv_type         = params["boor_rv_type"]
    wgt_decay            = params["wgt_decay"]
    lambda_3             = params["lambda_3"]
    lambda_4             = params["lambda_4"]
    drop_out_p           = params["drop_out_p"]
    lambda_quantile      = params["lambda_quantile"]
    quantile_samples     = params["quantile_samples"]

    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    # [修改4] 获取可用 GPU 数量，控制并发数，轮询分配 GPU
    num_gpus = torch.cuda.device_count() if torch.cuda.is_available() else 1
    num_cores = min(32, n_test)
    if num_cores < 1:
        num_cores = 1

    print(f"[{datetime.now().strftime('%H:%M:%S')}] 开始并行实验...")
    print(f"模式: {test}, 样本量: {sample_size}, 交叉验证折数: {k_value}, "
          f"多重分位数对齐系数: {lambda_quantile}, 实验次数: {n_test}, "
          f"并行核数: {num_cores}, 可用GPU数: {num_gpus}")
    if test == 'power':
        print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")

    # [修改4] 按 job_index % num_gpus 轮询分配 GPU
    p_values = Parallel(n_jobs=num_cores)(
        delayed(mGAN)(
            n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
            epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
            a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
            noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
            normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
            using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
            lambda_quantile=lambda_quantile, quantile_samples=quantile_samples,
            using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
            lambda_3=lambda_3, drop_out_p=drop_out_p,
            noise_dimension_var=noise_dimension_var,
            noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
            gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
        )
        for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
    )

    p_values = np.array(p_values)
    fp = [pval < alpha for pval in p_values]
    final_result = np.mean(fp)
    fp1 = [pval < alpha1 for pval in p_values]
    final_result1 = np.mean(fp1)

    print(f"\n" + "=" * 50)
    print(f"实验类型: {test.upper()}")
    print(f"Z Dimension: {z_dim}")
    print(f"Emp Rej Rate: {final_result:.4f} (at significance level {alpha})")
    print(f"Emp Rej Rate: {final_result1:.4f} (at significance level {alpha1})")
    print("=" * 50 + "\n")

    return p_values

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_quantile"] = 0.3
param["quantile_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [16:56:33] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2400 (at significance level 0.1)
# Emp Rej Rate: 0.1450 (at significance level 0.05)
# ==================================================
#
# [17:02:11] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1250 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.0550 (at significance level 0.01)
# ==================================================
#
# [17:07:24] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2250 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.1150 (at significance level 0.01)
# ==================================================
#
# [17:12:34] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2750 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.1600 (at significance level 0.01)
# ==================================================
#
# [17:17:44] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3300 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.2150 (at significance level 0.01)
# ==================================================
#
# [17:22:54] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5400 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.4150 (at significance level 0.01)
# ==================================================
#
# [17:28:05] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7400 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.6050 (at significance level 0.01)
# ==================================================
#
# [17:33:14] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8350 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.7100 (at significance level 0.01)
# ==================================================
#
# [17:38:24] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9900 (at significance level 0.029900000000000003)
# Emp Rej Rate: 0.9450 (at significance level 0.01)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_quantile"] = 0.5
param["quantile_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [17:57:17] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2200 (at significance level 0.1)
# Emp Rej Rate: 0.1250 (at significance level 0.05)
# ==================================================
#
# [18:02:35] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2000 (at significance level 0.04)
# Emp Rej Rate: 0.1250 (at significance level 0.02)
# ==================================================
#
# [18:07:37] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2550 (at significance level 0.04)
# Emp Rej Rate: 0.1800 (at significance level 0.02)
# ==================================================
#
# [18:12:37] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3100 (at significance level 0.04)
# Emp Rej Rate: 0.2100 (at significance level 0.02)
# ==================================================
#
# [18:17:39] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3600 (at significance level 0.04)
# Emp Rej Rate: 0.2900 (at significance level 0.02)
# ==================================================
#
# [18:22:41] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5550 (at significance level 0.04)
# Emp Rej Rate: 0.4800 (at significance level 0.02)
# ==================================================
#
# [18:27:40] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7450 (at significance level 0.04)
# Emp Rej Rate: 0.6300 (at significance level 0.02)
# ==================================================
#
# [18:32:40] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8800 (at significance level 0.04)
# Emp Rej Rate: 0.8150 (at significance level 0.02)
# ==================================================
#
# [18:37:46] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9600 (at significance level 0.04)
# Emp Rej Rate: 0.9450 (at significance level 0.02)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_quantile"] = 0.5
param["quantile_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [13:35:33] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.1000 (at significance level 0.1)
# Emp Rej Rate: 0.0600 (at significance level 0.05)
# ==================================================
#
# [13:40:46] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1150 (at significance level 0.1017)
# Emp Rej Rate: 0.0450 (at significance level 0.03995)
# ==================================================
#
# [13:45:56] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1650 (at significance level 0.1017)
# Emp Rej Rate: 0.0850 (at significance level 0.03995)
# ==================================================
#
# [13:51:07] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2450 (at significance level 0.1017)
# Emp Rej Rate: 0.1350 (at significance level 0.03995)
# ==================================================
#
# [13:56:18] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4500 (at significance level 0.1017)
# Emp Rej Rate: 0.2800 (at significance level 0.03995)
# ==================================================
#
# [14:01:31] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.6350 (at significance level 0.1017)
# Emp Rej Rate: 0.4900 (at significance level 0.03995)
# ==================================================
#
# [14:06:42] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8550 (at significance level 0.1017)
# Emp Rej Rate: 0.7350 (at significance level 0.03995)
# ==================================================
#
# [14:11:52] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9600 (at significance level 0.1017)
# Emp Rej Rate: 0.8950 (at significance level 0.03995)
# ==================================================
#
# [14:17:04] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 32, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 1.0000 (at significance level 0.1017)
# Emp Rej Rate: 0.9900 (at significance level 0.03995)
# ==================================================

# %%
# ============================================================
# 参数配置
# ============================================================
param = {
    "test": "power",
    "sample_size": 200,
    "batch_size": 128,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 100,
    "eps_std": 1.0,
    "dist_z": 'gaussian',
    "alpha_x": 0.20,
    "m_value": 100,
    "k_value": 8,
    "j_value": 1000,
    "noise_dimension": 5,
    "noise_dimension_type": "normal",
    "noise_dimension_var": 1,
    "hidden_layer_size": 1024,
    "normal_ini": False,
    "preprocess": 'scale',
    "G_lr": 7e-5,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 0,
    "using_orcale": False,
    "lambda_1": 1,
    "lambda_2": 1,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-4,
    "lambda_4": 2e-5,
    "drop_out_p": 0.2,
    "is_sparse": True,
    "sparse_ratio": 0.05,
    "lambda_quantile": 0.5,
    "quantile_samples": 30
}

import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools
from tqdm import tqdm

# [修改1] 删除全局 device，改为在 mGAN() 内部按 gpu_id 动态创建
# 原代码：
#   enable_cuda = True
#   device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


def generate_samples_random(size=1000, sType='H0', dx=1, dy=1, dz=1,
                            nstd=1.0, alpha_x=0.05,
                            preprocess="None", dist_z='student_t_heavy',
                            t_df=3.0):    
    """    Student-t heavy-tailed conditional dependence DGP.
    H0:        X = Z + s(Z) * eps_x        Y = Z + s(Z) * eps_y
    H1:        X = Z + s(Z) * eps_x        Y = Z + s(Z) * [Delta * eps_x + (1 - Delta) * eps_y]
    where eps_x, eps_y are standardized Student-t noises.    """

    num = size

    # Z distribution
    if dist_z in ['student_t_heavy', 'uniform']:
        Z = 2.0 * torch.rand(num, dz) - 1.0
    elif dist_z == 'gaussian':
        z_generator = TD.MultivariateNormal(torch.zeros(dz), torch.eye(dz))
        Z = z_generator.sample((num,))
    elif dist_z == 'laplace':
        laplace = TD.Laplace(torch.zeros(dz), torch.ones(dz))
        Z = laplace.sample((num,))
    else:
        raise ValueError(f"Unsupported dist_z: {dist_z}")

    z1 = Z[:, 0:1]

    # conditional location
    mX = z1
    mY = z1

    # conditional scale: heteroskedastic but smooth
    sX = 0.5 + torch.abs(z1)
    sY = 0.5 + torch.abs(z1)

    # Student-t heavy-tailed noise
    t_dist = TD.StudentT(df=torch.tensor(t_df))

    eps_x = t_dist.sample((num, 1))
    eps_y = t_dist.sample((num, 1))

    # standardize variance when df > 2
    if t_df > 2:
        scale = np.sqrt(t_df / (t_df - 2.0))
        eps_x = eps_x / scale
        eps_y = eps_y / scale

    if sType == 'H0':
        eps_y_star = eps_y

    elif sType == 'H1':
        delta = torch.bernoulli(torch.ones(num, 1) * alpha_x)
        eps_y_star = delta * eps_x + (1.0 - delta) * eps_y

    else:
        raise ValueError("sType must be 'H0' or 'H1'.")

    X = mX + sX * nstd * eps_x
    Y = mY + sY * nstd * eps_y_star

    if dx > 1:
        X = X.repeat(1, dx)
    if dy > 1:
        Y = Y.repeat(1, dy)

    return X.float(), Y.float(), Z.float()



def generate_samples_from_fixed_Z_random(Z, size=1000, sType='H0', dx=1, dy=1, dz=1, nstd=1.0,
                                          alpha_x=0.05, normalize=True, seed=None, dist_z='gaussian'):
    num = size
    error_generator_x = TD.MultivariateNormal(torch.zeros(dx), 1 * torch.eye(dx))
    error_generator_y = TD.MultivariateNormal(torch.zeros(dy), 1 * torch.eye(dy))
    Axy = torch.ones((dx, dy)) * alpha_x
    m = TD.Bernoulli(torch.tensor([alpha_x]))
    if sType == 'H0':
        error_x = error_generator_x.sample((num,))
        error_y = error_generator_y.sample((num,))
        X = Z + nstd * error_x
        Y = Z + nstd * error_y
    else:
        error_x = error_generator_x.sample((num,))
        error_y = error_generator_y.sample((num,))
        delta = m.sample((num,))
        X = Z + (1 - delta) * nstd * error_x + delta * nstd * error_y
        Y = Z + nstd * error_y
    return X, Y


def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch, x_torch, y_torch, z_torch,
                        sigma_w, sigma_u=1, sigma_v=1, boor_rv_type="gaussian",
                        device=None):  # [修改2] 新增 device 参数
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    w_mx = torch.exp(-w_mx / sigma_w)
    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u),
        dim=2)
    u_mx_3 = u_mx_2.T
    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v),
        dim=2)
    v_mx_3 = v_mx_2.T
    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u), dim=2)
        sum_mx = sum_mx + temp_add_mx
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v), dim=2)
        sum2_mx = sum2_mx + temp2_add_mx
    u_mx_4 = 1 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4
    v_mx_4 = 1 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4
    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n).to(device))  # [修改2]
    stat = 1 / (n - 1) * torch.sum(FF_mx).item()
    boottemp = np.array([])
    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num)).to(device)  # [修改2]
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num).to(device)              # [修改2]
    for bb in range(boot_num):
        random_mx = torch.matmul(eboot[:, bb].reshape(-1, 1), eboot[:, bb].reshape(-1, 1).T)
        bootmatrix = FF_mx * random_mx
        stat_boot = 1 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)
    return stat, boottemp


class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index], \
               self.Z_real[(self.batch_size + index) % self.sample_size]


class DatasetSelect_GAN_ver2(torch.utils.data.Dataset):
    def __init__(self, Y, Z, batch_size):
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = Z.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.Y_real[index], self.Z_real[index]


def sample_noise(sample_size, noise_dimension, noise_type, input_var=1,
                 device=None):  # [修改3] 新增 device 参数
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),           # [修改3]
            input_var * torch.eye(noise_dimension).to(device)) # [修改3]
        Z = noise_generator.sample((sample_size,))
    if noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension)
    if noise_type == "Cauchy":
        Z = TD.Cauchy(torch.tensor([0.0]), torch.tensor([1.0])).sample(
            (sample_size, noise_dimension)).squeeze(2)
    return Z


class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, drop_out_p, drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN3 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc3 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)
        self.sigmoid = torch.nn.Sigmoid()
        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out3 = torch.nn.Dropout(p=drop_out_p)
        self.drop_input = drop_input

    def forward(self, x):
        if self.BN_type:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
            x = self.fc_last(x)
        else:
            if self.drop_input:
                x = self.drop_out0(x)
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))
            x = self.fc_last(x)
        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        # [修改3] 不在构造函数中 .to(device)，由外层统一 .to(device)
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias)
        self.mask = functools.reduce(
            torch.block_diag, [torch.ones(size_out, size_in) for i in range(m)])

    def forward(self, x):
        # [修改3] mask 动态跟随模型所在设备
        self.linear.weight.data *= self.mask.to(self.linear.weight.device)
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension, hidden_layer_size,
                 BN_type, ReLU_coef, hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)
        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0])
        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for i in range(len(self.hidden_layer_sizes))
        ])
        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)
        return self.linear8(output)


def find_loss(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-torch.abs(Y.repeat(1, n) - Y.repeat(1, n).T) / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    mx_1_2 = torch.exp(-mx_1_2 / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-torch.abs(Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-torch.abs(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def find_loss_2(Y, hat_Y, Z, sigma_z, sigma_y):
    n = Z.shape[0]
    mx_1_1 = torch.exp(-(Y.repeat(1, n) - Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_1_2 = torch.linalg.vector_norm(
        Z.repeat(n, 1, 1) - torch.swapaxes(Z.repeat(n, 1, 1), 0, 1), ord=2, dim=2)
    mx_1_2 = torch.exp(-(mx_1_2 ** 2) / sigma_z)
    mx_1 = mx_1_1 * mx_1_2
    mx_2_1 = torch.exp(-(Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_2 = mx_2_1 * mx_1_2
    mx_3 = mx_2.T
    mx_4_1 = torch.exp(-(hat_Y.repeat(1, n) - hat_Y.repeat(1, n).T) ** 2 / sigma_y)
    mx_4 = mx_4_1 * mx_1_2
    FF_mx = (mx_1 - mx_2 - mx_3 + mx_4)
    loss = 1 / (n ** 2) * torch.sum(FF_mx)
    return loss


def pinball_loss(y_true, y_pred, tau):
    err = y_true - y_pred
    return torch.mean(torch.max(tau * err, (tau - 1.0) * err))


def train_ver3(
        G_zx, G_zy,
        X, Y, Z, X_test, Y_test, Z_test, M,
        noise_dimension, noise_type, G_lr, hidden_layer_size,
        DataLoader, BN_type, ReLU_coef,
        lambda_quantile=0.5, quantile_samples=20,
        epochs_num=50,
        patience=5, min_delta=1e-5,
        sigma_z=1, sigma_x=1, sigma_y=1,
        normal_ini=False,
        lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
        lambda_3=0, drop_out_p=0.2, noise_dimension_var=1,
        lambda_4=0,
        device=None):  # [修改3] 新增 device 参数

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if G_zy is None or G_zx is None:
        if using_Gen == '1':
            G_zy = Generator(input_dimension, output_dimension_y, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
            G_zx = Generator(input_dimension, output_dimension_x, noise_dimension,
                             hidden_layer_size, BN_type, ReLU_coef, drop_out_p).to(device)  # [修改3]
        elif using_Gen == '2':
            G_zy = Generator_2(input_dimension, output_dimension_y, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]
            G_zx = Generator_2(input_dimension, output_dimension_x, noise_dimension,
                               hidden_layer_size, BN_type, ReLU_coef).to(device)             # [修改3]

        if normal_ini:
            for p in G_zy.parameters():
                p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]
            for p in G_zx.parameters():
                p.data = torch.randn(p.shape, device=device) / np.sqrt(float(hidden_layer_size * 2))  # [修改3]

    G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    iter_count = 0
    G_zy = G_zy.train()
    G_zx = G_zx.train()

    best_loss = float('inf')
    counter = 0

    for epoch in range(epochs_num):
        batch_count = 0
        G_zy = G_zy.train()
        G_zx = G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)   # [修改3]
            Y_real = Y_real.to(device)   # [修改3]
            Z_real = Z_real.to(device)   # [修改3]
            Z_fake = Z_fake.to(device)   # [修改3]

            batch_size = Z_real.shape[0]
            Z_repeated = Z_real.repeat_interleave(quantile_samples, dim=0)

            Noise_for_quantile = sample_noise(
                Z_repeated.shape[0], noise_dimension, noise_type,
                input_var=noise_dimension_var, device=device).to(device)  # [修改3]

            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            Y_fake = G_zy(torch.cat((Z_real, Noise_fake), dim=1)).to(device)
            Noise_fake = sample_noise(Z_real.shape[0], noise_dimension, noise_type,
                                      input_var=noise_dimension_var, device=device).to(device)  # [修改3]
            X_fake = G_zx(torch.cat((Z_real, Noise_fake), dim=1)).to(device)

            Y_generated_group = G_zy(torch.cat((Z_repeated, Noise_for_quantile), dim=1))
            Y_generated_reshaped = Y_generated_group.reshape(batch_size, quantile_samples, -1)
            q_25_y = torch.quantile(Y_generated_reshaped, q=0.25, dim=1)
            q_50_y = torch.quantile(Y_generated_reshaped, q=0.50, dim=1)
            q_75_y = torch.quantile(Y_generated_reshaped, q=0.75, dim=1)
            loss_q25_y = pinball_loss(Y_real, q_25_y, 0.25)
            loss_q50_y = pinball_loss(Y_real, q_50_y, 0.50)
            loss_q75_y = pinball_loss(Y_real, q_75_y, 0.75)
            loss_quantile_y = 0.25 * loss_q25_y + 0.50 * loss_q50_y + 0.25 * loss_q75_y

            X_generated_group = G_zx(torch.cat((Z_repeated, Noise_for_quantile), dim=1))
            X_generated_reshaped = X_generated_group.reshape(batch_size, quantile_samples, -1)
            q_25_x = torch.quantile(X_generated_reshaped, q=0.25, dim=1)
            q_50_x = torch.quantile(X_generated_reshaped, q=0.50, dim=1)
            q_75_x = torch.quantile(X_generated_reshaped, q=0.75, dim=1)
            loss_q25_x = pinball_loss(X_real, q_25_x, 0.25)
            loss_q50_x = pinball_loss(X_real, q_50_x, 0.50)
            loss_q75_x = pinball_loss(X_real, q_75_x, 0.75)
            loss_quantile_x = 0.25 * loss_q25_x + 0.50 * loss_q50_x + 0.25 * loss_q75_x

            g_zy_error = None
            G_zy_solver.zero_grad()
            g_zx_error = None
            G_zx_solver.zero_grad()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zy.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_y = (lambda_1 * find_loss(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_2 * find_loss_2(Y_real, Y_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_y) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zy_error = mmd_loss_y + lambda_quantile * loss_quantile_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            l1_regularization_first_layer = 0
            l1_regularization_rest_layers = 0
            for name, param_g in G_zx.named_parameters():
                if "fc1" in name:
                    l1_regularization_first_layer += torch.linalg.vector_norm(param_g, ord=1)
                else:
                    l1_regularization_rest_layers += torch.linalg.vector_norm(param_g, ord=1)

            mmd_loss_x = (lambda_1 * find_loss(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_2 * find_loss_2(X_real, X_fake, Z_real, sigma_z=sigma_z, sigma_y=sigma_x) +
                          lambda_3 * l1_regularization_rest_layers +
                          lambda_4 * l1_regularization_first_layer)
            g_zx_error = mmd_loss_x + lambda_quantile * loss_quantile_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

            iter_count += 1
            batch_count += 1

        current_loss = g_zx_error + g_zy_error
        if current_loss < best_loss - min_delta:
            best_loss = current_loss
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            break

    return G_zy, G_zx


def mGAN(n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_orcale=False, lambda_1=1, lambda_2=1,
         lambda_quantile=0.5, quantile_samples=20,
         using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2,
         noise_dimension_var=1, noise_dimension_type="normal", lambda_4=1,
         gpu_id=0):  # [修改4] 新增 gpu_id 参数

    # [修改4] 在函数内部根据 gpu_id 创建局部 device
    enable_cuda = True
    if torch.cuda.is_available() and enable_cuda:
        device = torch.device(f'cuda:{gpu_id}')
    else:
        device = torch.device('cpu')

    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H0', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            size=n, sType='H1', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess)
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x.to(device), sim_y.to(device), sim_z.to(device)

    w_mx = torch.linalg.vector_norm(
        z.repeat(n, 1, 1) - torch.swapaxes(z.repeat(n, 1, 1), 0, 1), ord=1, dim=2)
    sigma_w = torch.median(w_mx).item()
    u_mx = torch.exp(-torch.abs(y.repeat(1, n) - y.repeat(1, n).T))
    sigma_u = torch.median(u_mx).item()
    v_mx = torch.exp(-torch.abs(x.repeat(1, n) - x.repeat(1, n).T))
    sigma_v = torch.median(v_mx).item()

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    if not using_orcale:
        G_zy = Generator(z_dim, y_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)
        G_zx = Generator(z_dim, x_dims, noise_dimension, hidden_layer_size, False, 0.1, drop_out_p).to(device)

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))
        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]
        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))
        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_orcale:
            current_epochs = epochs_num if k_fold == 0 else max(10, epochs_num // 5)
            G_zy, G_zx = train_ver3(
                G_zx=G_zx, G_zy=G_zy,
                X=X_train, Y=Y_train, Z=Z_train, M=M,
                X_test=X_test, Y_test=Y_test, Z_test=Z_test,
                noise_dimension=noise_dimension, noise_type=noise_dimension_type,
                G_lr=G_lr, hidden_layer_size=hidden_layer_size,
                DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
                lambda_quantile=lambda_quantile, quantile_samples=quantile_samples,
                epochs_num=epochs_num,
                sigma_z=sigma_w, sigma_x=sigma_v, sigma_y=sigma_u,
                normal_ini=normal_ini, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, wgt_decay=wgt_decay, lambda_3=lambda_3,
                drop_out_p=drop_out_p, noise_dimension_var=noise_dimension_var,
                lambda_4=lambda_4,
                device=device)  # [修改4] 传入局部 device

        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M, device=device)   # [修改4]
        gen_y_all = torch.zeros(test_size, M, device=device)   # [修改4]
        z_all = torch.zeros(test_size, z_dim, device=device)   # [修改4]
        x_all = torch.zeros(test_size, x_dims, device=device)  # [修改4]
        y_all = torch.zeros(test_size, y_dims, device=device)  # [修改4]
        cur_itr = 0

        if not using_orcale:
            G_zx = G_zx.eval()
            G_zy = G_zy.eval()

        for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
            z_test_temp = z_test.repeat(M, 1)
            if not using_orcale:
                z_test_temp = z_test_temp.to(device)                                      # [修改4]
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_x = G_zx(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
                Noise_fake = sample_noise(z_test_temp.size()[0], noise_dimension,
                                          "normal", device=device).to(device)              # [修改4]
                with torch.no_grad():
                    fake_y = G_zy(torch.cat((z_test_temp, Noise_fake), dim=1)).reshape(1, -1)
            elif using_orcale:
                if simulation == 'type1error':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H0', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)
                elif simulation == 'power':
                    fake_x, fake_y = generate_samples_from_fixed_Z_random(
                        z_test_temp, size=M, sType='H1', dx=x_dims, dy=y_dims,
                        dz=z_dim, nstd=nstd, alpha_x=a_x, dist_z=z_dist)

            gen_x_all[cur_itr, :] = fake_x.detach().reshape(-1)
            gen_y_all[cur_itr, :] = fake_y.detach().reshape(-1)
            x_all[cur_itr, :] = x_test
            y_all[cur_itr, :] = y_test
            z_all[cur_itr, :] = z_test
            cur_itr = cur_itr + 1

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type,
            device=device)  # [修改4] 传入局部 device
        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp)
        cur_k = cur_k + 1

        if using_orcale:
            gen_x_50 = torch.quantile(gen_x_all, 0.50, dim=1).reshape(-1, 1)
            gen_y_50 = torch.quantile(gen_y_all, 0.50, dim=1).reshape(-1, 1)
            mse_x = torch.mean((gen_x_50 - x_all) ** 2).item()
            mse_y = torch.mean((gen_y_50 - y_all) ** 2).item()
            print(f'Test MSE x (median diff) [{mse_x}], MSE y (median diff) [{mse_y}]')

    return np.mean(torch.mean(boot_temp_all, dim=0).numpy() > torch.mean(stat_all).item())


# ============================================================
# 并行部分
# ============================================================
from joblib import Parallel, delayed
import multiprocessing

def run_experiment(params):
    test                 = params["test"]
    sample_size          = params["sample_size"]
    batch_size           = params["batch_size"]
    z_dim                = params["z_dim"]
    dx                   = params["dx"]
    dy                   = params["dy"]
    n_test               = params["n_test"]
    epochs_num           = params["epochs_num"]
    eps_std              = params["eps_std"]
    dist_z               = params["dist_z"]
    alpha_x              = params["alpha_x"]
    m_value              = params["m_value"]
    k_value              = params["k_value"]
    j_value              = params["j_value"]
    noise_dimension      = params["noise_dimension"]
    noise_dimension_type = params["noise_dimension_type"]
    noise_dimension_var  = params["noise_dimension_var"]
    hidden_layer_size    = params["hidden_layer_size"]
    normal_ini           = params["normal_ini"]
    preprocess           = params["preprocess"]
    G_lr                 = params["G_lr"]
    alpha                = params["alpha"]
    alpha1               = params["alpha1"]
    set_seeds            = params["set_seeds"]
    using_orcale         = params["using_orcale"]
    lambda_1             = params["lambda_1"]
    lambda_2             = params["lambda_2"]
    using_Gen            = params["using_Gen"]
    boor_rv_type         = params["boor_rv_type"]
    wgt_decay            = params["wgt_decay"]
    lambda_3             = params["lambda_3"]
    lambda_4             = params["lambda_4"]
    drop_out_p           = params["drop_out_p"]
    lambda_quantile      = params["lambda_quantile"]
    quantile_samples     = params["quantile_samples"]

    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    # [修改4] 获取可用 GPU 数量，控制并发数，轮询分配 GPU
    num_gpus = torch.cuda.device_count() if torch.cuda.is_available() else 1
    num_cores = min(28, n_test)
    if num_cores < 1:
        num_cores = 1

    print(f"[{datetime.now().strftime('%H:%M:%S')}] 开始并行实验...")
    print(f"模式: {test}, 样本量: {sample_size}, 交叉验证折数: {k_value}, "
          f"多重分位数对齐系数: {lambda_quantile}, 实验次数: {n_test}, "
          f"并行核数: {num_cores}, 可用GPU数: {num_gpus}")
    if test == 'power':
        print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")

    # [修改4] 按 job_index % num_gpus 轮询分配 GPU
    p_values = Parallel(n_jobs=num_cores)(
        delayed(mGAN)(
            n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
            epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
            a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
            noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
            normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
            using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
            lambda_quantile=lambda_quantile, quantile_samples=quantile_samples,
            using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
            lambda_3=lambda_3, drop_out_p=drop_out_p,
            noise_dimension_var=noise_dimension_var,
            noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
            gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
        )
        for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
    )

    p_values = np.array(p_values)
    fp = [pval < alpha for pval in p_values]
    final_result = np.mean(fp)
    fp1 = [pval < alpha1 for pval in p_values]
    final_result1 = np.mean(fp1)

    print(f"\n" + "=" * 50)
    print(f"实验类型: {test.upper()}")
    print(f"Z Dimension: {z_dim}")
    print(f"Emp Rej Rate: {final_result:.4f} (at significance level {alpha})")
    print(f"Emp Rej Rate: {final_result1:.4f} (at significance level {alpha1})")
    print("=" * 50 + "\n")

    return p_values

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_quantile"] = 0.3
param["quantile_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [15:21:28] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.2250 (at significance level 0.1)
# Emp Rej Rate: 0.1200 (at significance level 0.05)
# ==================================================
#
# [15:26:55] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1550 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.1100 (at significance level 0.02695)
# ==================================================
#
# [15:32:07] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2650 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.1950 (at significance level 0.02695)
# ==================================================
#
# [15:37:18] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.4150 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.3350 (at significance level 0.02695)
# ==================================================
#
# [15:42:28] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5550 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.4650 (at significance level 0.02695)
# ==================================================
#
# [15:47:40] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.7450 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.6950 (at significance level 0.02695)
# ==================================================
#
# [15:52:53] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8900 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.8550 (at significance level 0.02695)
# ==================================================
#
# [15:58:08] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9600 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.9500 (at significance level 0.02695)
# ==================================================
#
# [16:03:19] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.2
# Process LokyProcess-1051:
# Process LokyProcess-1050:
# Process LokyProcess-1049:
# Process LokyProcess-1044:
# Process LokyProcess-1035:
# Process LokyProcess-1039:
# Process LokyProcess-1032:
# Process LokyProcess-1047:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 528, in _process_worker
#     with worker_exit_lock:
#   File "/home/23099458d/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py", line 119, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1797 if (nb_jobs == 0) or (
#    1798     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799 ):
# -> 1800     time.sleep(0.01)
#    1801     continue
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 22
#      20 for alpha_x in [0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.15, 0.20]:
#      21         param["alpha_x"] = alpha_x
# ---> 22         p_val_list_h1 = run_experiment(param)
#
# Cell In[10], line 736, in run_experiment(params)
#     733     print(f"备择假设H_1下的模型参数 alpha_x: {alpha_x}")
#     735 # [修改4] 按 job_index % num_gpus 轮询分配 GPU
# --> 736 p_values = Parallel(n_jobs=num_cores)(
#     737     delayed(mGAN)(
#     738         n=sample_size, z_dim=z_dim, simulation=test, batch_size=batch_size,
#     739         epochs_num=epochs_num, nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
#     740         a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
#     741         noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
#     742         normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
#     743         using_orcale=using_orcale, lambda_1=lambda_1, lambda_2=lambda_2,
#     744         lambda_quantile=lambda_quantile, quantile_samples=quantile_samples,
#     745         using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
#     746         lambda_3=lambda_3, drop_out_p=drop_out_p,
#     747         noise_dimension_var=noise_dimension_var,
#     748         noise_dimension_type=noise_dimension_type, lambda_4=lambda_4,
#     749         gpu_id=job_index % num_gpus  # [修改4] 轮询分配 GPU
#     750     )
#     751     for job_index, _ in enumerate(range(n_test))  # [修改4] enumerate 获取 job_index
#     752 )
#     754 p_values = np.array(p_values)
#     755 fp = [pval < alpha for pval in p_values]
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1732, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1730 except BaseException:
#    1731     self._exception = True
# -> 1732     self._abort()
#    1733     raise
#    1734 finally:
#    1735     # Store the unconsumed tasks and terminate the workers if necessary
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/parallel.py:1646, in Parallel._abort(self)
#    1641 if not self._aborted and hasattr(backend, "abort_everything"):
#    1642     # If the backend is managed externally we need to make sure
#    1643     # to leave it in a working state to allow for future jobs
#    1644     # scheduling.
#    1645     ensure_ready = self._managed_backend
# -> 1646     backend.abort_everything(ensure_ready=ensure_ready)
#    1647 self._aborted = True
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/_parallel_backends.py:725, in LokyBackend.abort_everything(self, ensure_ready)
#     723 def abort_everything(self, ensure_ready=True):
#     724     """Shutdown the workers and restart a new one with the same parameters"""
# --> 725     self._workers.terminate(kill_workers=True)
#     726     self._workers = None
#     728     if ensure_ready:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/executor.py:86, in MemmappingExecutor.terminate(self, kill_workers)
#      85 def terminate(self, kill_workers=False):
# ---> 86     self.shutdown(kill_workers=kill_workers)
#      88     # When workers are killed in a brutal manner, they cannot execute the
#      89     # finalizer of their shared memmaps. The refcount of those memmaps may
#      90     # be off by an unknown number, so instead of decref'ing them, we force
#    (...)
#      95     # with allow_non_empty=True but if we can't, it will be clean up later
#      96     # on by the resource_tracker.
#      97     with self._submit_resize_lock:
#
# File ~/venvs/myjupyter/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1333, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1329 if executor_manager_thread is not None and wait:
#    1330     # This locks avoids concurrent join if the interpreter
#    1331     # is shutting down.
#    1332     with _global_shutdown_lock:
# -> 1333         executor_manager_thread.join()
#    1334         _threads_wakeups.pop(executor_manager_thread, None)
#    1336 # To reduce the risk of opening too many files, remove references to
#    1337 # objects that use file descriptors.
#
# File /opt/anaconda3/lib/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/anaconda3/lib/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:

# %%
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.05]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [16:03:53] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.3, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2950 (at significance level 0.04560000000000001)
# Emp Rej Rate: 0.2050 (at significance level 0.02695)
# ==================================================

# %%
param["sample_size"] = 500
param["k_value"] = 2

# 固定阈值看 type1error
param["test"] = "type1error"
param["n_test"] = 200
param["lambda_quantile"] = 0.5
param["quantile_samples"] = 30
p_val_list = run_experiment(param)

# H0 校准 power 用的阈值
alpha_emp_10 = np.quantile(p_val_list, 0.10)
alpha_emp_05 = np.quantile(p_val_list, 0.05)

# 跑 power
param["test"] = "power"
param["alpha"] = alpha_emp_10
param["alpha1"] = alpha_emp_05

for alpha_x in [0.02, 0.04, 0.05, 0.06, 0.08, 0.10, 0.12, 0.15]:
        param["alpha_x"] = alpha_x
        p_val_list_h1 = run_experiment(param)
# Out:
# [16:09:36] 开始并行实验...
# 模式: type1error, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
#
# ==================================================
# 实验类型: TYPE1ERROR
# Z Dimension: 1
# Emp Rej Rate: 0.1800 (at significance level 0.1)
# Emp Rej Rate: 0.1100 (at significance level 0.05)
# ==================================================
#
# [16:14:40] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.02
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.1450 (at significance level 0.0478)
# Emp Rej Rate: 0.0600 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:19:43] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.04
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.2600 (at significance level 0.0478)
# Emp Rej Rate: 0.1500 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:24:45] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.05
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3400 (at significance level 0.0478)
# Emp Rej Rate: 0.1850 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:29:49] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.06
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.3950 (at significance level 0.0478)
# Emp Rej Rate: 0.2700 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:34:54] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.08
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.5650 (at significance level 0.0478)
# Emp Rej Rate: 0.4100 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:39:56] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.1
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8100 (at significance level 0.0478)
# Emp Rej Rate: 0.6650 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:44:57] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.12
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.8850 (at significance level 0.0478)
# Emp Rej Rate: 0.7900 (at significance level 0.016800000000000006)
# ==================================================
#
# [16:49:58] 开始并行实验...
# 模式: power, 样本量: 500, 交叉验证折数: 2, 多重分位数对齐系数: 0.5, 实验次数: 200, 并行核数: 28, 可用GPU数: 4
# 备择假设H_1下的模型参数 alpha_x: 0.15
#
# ==================================================
# 实验类型: POWER
# Z Dimension: 1
# Emp Rej Rate: 0.9700 (at significance level 0.0478)
# Emp Rej Rate: 0.9400 (at significance level 0.016800000000000006)
# ==================================================
