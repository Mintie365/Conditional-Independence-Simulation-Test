# %%
import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools


# =========================
# Device
# =========================
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


# =========================
# Parameters
# =========================
param = {
    "test": "type1error",
    "sample_size": 200,
    "batch_size": 128,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 200,
    "eps_std": 0.5,
    "dist_z": 'gaussian',
    "alpha_x": 0.75,
    "m_value": 100,
    "k_value": 2,
    "j_value": 1000,
    "noise_dimension": 3,
    "hidden_layer_size": 20,
    "normal_ini": False,
    "preprocess": 'None',
    "G_lr": 1e-3,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 42,
    "using_oracle": False,
    "lambda_1": 1,
    "lambda_2": 0,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-5,
    "drop_out_p": 0.2,
    "M_train": 10,

    # 你的改进
    "lambda_mean": 0.5,
    "mean_samples": 20
}



# =========================
# Data generation: binary version
# =========================
def generate_samples_random(Ax, Ay, size=1000, sType='CI', dx=1, dy=1, dz=1,
                            nstd=0.05, alpha_x=0.05,
                            preprocess="None", dist_z='gaussian'):
    """
    Binary data generator aligned with the author's pasted code.

    Output:
        X, Y, Z are all binary {0,1} tensors.
    """
    if dx != 1 or dy != 1 or dz != 1:
        raise ValueError("This binary version currently supports dx=dy=dz=1 only.")

    num = size

    if sType in ['CI', 'H0', 'type1error']:
        numbers_z = np.random.multinomial(num, [0.5, 0.5], size=1)
        number_z_zeros = numbers_z[0][0]
        number_z_ones = numbers_z[0][1]

        xy_arr = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

        xy_z_zero_index = np.random.choice(
            a=len(xy_arr), size=number_z_zeros,
            p=[0.25, 0.25, 0.25, 0.25]
        )
        xy_z_one_index = np.random.choice(
            a=len(xy_arr), size=number_z_ones,
            p=[0.25, 0.25, 0.25, 0.25]
        )

        xy_z_zero = xy_arr[xy_z_zero_index]
        xy_z_one = xy_arr[xy_z_one_index]

        xy = np.concatenate((xy_z_zero, xy_z_one), axis=0)

        x = xy[:, 0]
        y = xy[:, 1]
        z = np.concatenate((np.zeros(number_z_zeros), np.ones(number_z_ones)), axis=0)

    elif sType in ['dependent', 'H1', 'power']:
        z = np.random.binomial(1, 0.5, size=num)
        y = np.random.binomial(1, 0.5, size=num)

        delta = np.random.binomial(1, alpha_x, size=num)
        x_indep = np.random.binomial(1, 0.5, size=num)

        x = (1 - delta) * x_indep + delta * y
        x = x.astype(int)

    else:
        raise ValueError("sType must be one of ['CI','H0','type1error','dependent','H1','power']")

    indices = np.random.permutation(num)
    x, y, z = x[indices], y[indices], z[indices]

    X = x.reshape(-1, 1).astype(np.float32)
    Y = y.reshape(-1, 1).astype(np.float32)
    Z = z.reshape(-1, 1).astype(np.float32)

    if preprocess == "normalize":
        pass
    elif preprocess == "scale_Z":
        pass
    elif preprocess == "None":
        pass
    else:
        raise ValueError("preprocess must be one of ['normalize', 'scale_Z', 'None']")

    X = torch.from_numpy(X).float()
    Y = torch.from_numpy(Y).float()
    Z = torch.from_numpy(Z).float()

    return X, Y, Z


# =========================
# Statistic computation
# =========================
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                       x_torch, y_torch, z_torch,
                       sigma_w, sigma_u=1, sigma_v=1,
                       boor_rv_type="gaussian"):
    """
    Compute test statistic and bootstrap samples.
    Shapes:
        gen_x_all_torch, gen_y_all_torch: (n, M)
        x_torch, y_torch: (n, 1)
        z_torch: (n, dz)
    """
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v
        ),
        dim=2
    )
    v_mx_3 = v_mx_2.T

    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
        dim=2
    )

    for i in range(1, M):
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
            dim=2
        )
        sum2_mx = sum2_mx + temp2_add_mx

    v_mx_4 = 1.0 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n, device=device))

    stat = 1.0 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])

    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num, device=device))
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num, device=device)
    else:
        raise ValueError("boor_rv_type must be 'rademacher' or 'gaussian'")

    for bb in range(boot_num):
        random_mx = torch.matmul(
            eboot[:, bb].reshape(-1, 1),
            eboot[:, bb].reshape(-1, 1).T
        )
        bootmatrix = FF_mx * random_mx
        stat_boot = 1.0 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)

    return stat, boottemp


# =========================
# Dataset
# =========================
class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (
            self.X_real[index],
            self.Y_real[index],
            self.Z_real[index],
            self.Z_real[(self.batch_size + index) % self.sample_size]
        )


# =========================
# Noise sampler
# =========================
def sample_noise(sample_size, noise_dimension, noise_type, input_var):
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),
            input_var * torch.eye(noise_dimension).to(device)
        )
        Z = noise_generator.sample((sample_size,))
    elif noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension, device=device)
    elif noise_type == "Cauchy":
        Z = TD.Cauchy(
            torch.tensor([0.0], device=device),
            torch.tensor([1.0], device=device)
        ).sample((sample_size, noise_dimension)).squeeze(2)
    else:
        raise ValueError("noise_type must be one of ['normal', 'unif', 'Cauchy']")
    return Z


# =========================
# Generator
# =========================
class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p,
                 drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.drop_input = drop_input

        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)

        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)

        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        if self.drop_input:
            x = self.drop_out0(x)

        if self.BN_type:
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
        else:
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))

        x = self.fc_last(x)

        # Binary probability output
        x = self.sigmoid(x)

        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias).to(device)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for _ in range(m)]
        ).to(device)

    def forward(self, x):
        self.linear.weight.data *= self.mask
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)

        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0]
        )

        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for _ in range(len(self.hidden_layer_sizes))
        ])

        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        self.sigmoid = torch.nn.Sigmoid()

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)

        output = self.linear8(output)
        output = self.sigmoid(output)
        return output


# =========================
# Loss
# =========================
def find_loss(y_torch, gen_y_all_torch, z_torch, sigma_w, sigma_u, M):
    n = z_torch.shape[0]

    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    FF_mx = u_mx * w_mx * (1 - torch.eye(n, device=device))
    loss = 1.0 / n * torch.sum(FF_mx)

    return loss


# =========================
# Binary sampling helper
# =========================
def sample_binary_from_prob(prob_tensor):
    prob_tensor = torch.clamp(prob_tensor, 1e-6, 1 - 1e-6)
    return torch.bernoulli(prob_tensor)


# =========================
# Training
# =========================
def train_ver3(X, Y, Z, X_test, Y_test, Z_test, M,
               noise_dimension, noise_type, G_lr, hidden_layer_size,
               DataLoader, BN_type, ReLU_coef,
               epochs_num=10, sigma_z=1, sigma_x=1, sigma_y=1,
               normal_ini=False,
               lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
               lambda_3=0, drop_out_p=0.2, M_train=3,
               lambda_mean=0.0, mean_samples=20):

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if using_Gen == '1':
        G_zy = Generator(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    elif using_Gen == '2':
        G_zy = Generator_2(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator_2(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    else:
        raise ValueError("using_Gen must be '1' or '2'")

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))

    for epoch in range(epochs_num):
        G_zy.train()
        G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)
            Y_real = Y_real.to(device)
            Z_real = Z_real.to(device)
            Z_fake = Z_fake.to(device)

            batch_size = Z_real.shape[0]

            # =========================
            # Train G_zy
            # =========================
            G_zy_solver.zero_grad()

            Z_real_repeat_y = Z_real.repeat(M_train, 1)
            Noise_fake_y = sample_noise(
                Z_real_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            Y_fake_prob = G_zy(torch.cat((Z_real_repeat_y, Noise_fake_y), dim=1)).to(device)
            Y_fake = Y_fake_prob.reshape(batch_size, M_train)

            l1_regularization_y = 0.0
            for param in G_zy.parameters():
                l1_regularization_y += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = lambda_1 * find_loss(
                Y_real, Y_fake, Z_real, sigma_z, sigma_y, M_train
            )

            if lambda_mean > 0:
                # 这里保留你的改进：对同一个 Z 做 Monte Carlo 均值近似
                Z_mean_repeat_y = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_y = sample_noise(
                    Z_mean_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                Y_mean_fake_group = G_zy(torch.cat((Z_mean_repeat_y, Noise_mean_y), dim=1))
                Y_mean_fake = Y_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_y).mean(dim=1)

                mean_loss_y = torch.nn.functional.mse_loss(Y_mean_fake, Y_real)
            else:
                mean_loss_y = 0.0

            g_zy_error = mmd_loss_y + lambda_mean * mean_loss_y + lambda_3 * l1_regularization_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            # =========================
            # Train G_zx
            # =========================
            G_zx_solver.zero_grad()

            Z_real_repeat_x = Z_real.repeat(M_train, 1)
            Noise_fake_x = sample_noise(
                Z_real_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            X_fake_prob = G_zx(torch.cat((Z_real_repeat_x, Noise_fake_x), dim=1)).to(device)
            X_fake = X_fake_prob.reshape(batch_size, M_train)

            l1_regularization_x = 0.0
            for param in G_zx.parameters():
                l1_regularization_x += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = lambda_1 * find_loss(
                X_real, X_fake, Z_real, sigma_z, sigma_x, M_train
            )

            if lambda_mean > 0:
                Z_mean_repeat_x = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_x = sample_noise(
                    Z_mean_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                X_mean_fake_group = G_zx(torch.cat((Z_mean_repeat_x, Noise_mean_x), dim=1))
                X_mean_fake = X_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_x).mean(dim=1)

                mean_loss_x = torch.nn.functional.mse_loss(X_mean_fake, X_real)
            else:
                mean_loss_x = 0.0

            g_zx_error = mmd_loss_x + lambda_mean * mean_loss_x + lambda_3 * l1_regularization_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

    return G_zy, G_zx

# =========================
# Main experiment for one run
# =========================
def mGAN(Ax, Ay, n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_oracle=False, lambda_1=1, lambda_2=1, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2, exp_num=0,
         M_train=3, lambda_mean=0.0, mean_samples=20):


    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='CI', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='dependent', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x, sim_y, sim_z

    sigma_w_train = 1.0
    sigma_u_train = 1.0
    sigma_v_train = 1.0

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))

        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]

        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))

        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_oracle:
            G_zy, G_zx = train_ver3(
    X=X_train, Y=Y_train, Z=Z_train, M=M,
    X_test=X_test, Y_test=Y_test, Z_test=Z_test,
    noise_dimension=noise_dimension, noise_type="normal",
    G_lr=G_lr, hidden_layer_size=hidden_layer_size,
    DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
    epochs_num=epochs_num, sigma_z=sigma_w_train, sigma_x=sigma_v_train,
    sigma_y=sigma_u_train, normal_ini=normal_ini, lambda_1=lambda_1,
    lambda_2=lambda_2, using_Gen=using_Gen, wgt_decay=wgt_decay,
    lambda_3=lambda_3, drop_out_p=drop_out_p, M_train=M_train,
    lambda_mean=lambda_mean, mean_samples=mean_samples
)


        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M)
        gen_y_all = torch.zeros(test_size, M)

        z_all = torch.zeros(test_size, z_dim)
        x_all = torch.zeros(test_size, x_dims)
        y_all = torch.zeros(test_size, y_dims)

        cur_itr = 0

        if using_oracle:
            for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                z_scalar = int(z_test.item())

                fake_x = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)
                fake_y = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)

                gen_x_all[cur_itr, :] = fake_x.reshape(-1)
                gen_y_all[cur_itr, :] = fake_y.reshape(-1)

                x_all[cur_itr, :] = x_test
                y_all[cur_itr, :] = y_test
                z_all[cur_itr, :] = z_test
                cur_itr += 1
        else:
            G_zx.eval()
            G_zy.eval()

            with torch.no_grad():
                for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                    z_test_temp = z_test.repeat(M, 1).to(device)

                    noise_x = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_x_prob = G_zx(torch.cat((z_test_temp, noise_x), dim=1))
                    fake_x = sample_binary_from_prob(fake_x_prob).reshape(1, -1)

                    noise_y = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_y_prob = G_zy(torch.cat((z_test_temp, noise_y), dim=1))
                    fake_y = sample_binary_from_prob(fake_y_prob).reshape(1, -1)

                    gen_x_all[cur_itr, :] = fake_x.detach().cpu().reshape(-1)
                    gen_y_all[cur_itr, :] = fake_y.detach().cpu().reshape(-1)
                    x_all[cur_itr, :] = x_test
                    y_all[cur_itr, :] = y_test
                    z_all[cur_itr, :] = z_test
                    cur_itr += 1

        gen_x_all = gen_x_all.to(device)
        gen_y_all = gen_y_all.to(device)

        z_all = Z_test.to(device)
        x_all = X_test.to(device)
        y_all = Y_test.to(device)

        sigma_w = 1.0
        sigma_u = 1.0
        sigma_v = 1.0

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type
        )

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp).float()
        cur_k += 1

    return np.mean(torch.mean(boot_temp_all, dim=0).cpu().numpy() > torch.mean(stat_all).item())


# =========================
# Repeated experiment
# =========================
def run_experiment(params):
    test = params["test"]
    sample_size = params["sample_size"]
    batch_size = params["batch_size"]
    z_dim = params["z_dim"]
    dx = params["dx"]
    dy = params["dy"]
    n_test = params["n_test"]
    epochs_num = params["epochs_num"]
    eps_std = params["eps_std"]
    dist_z = params["dist_z"]
    alpha_x = params["alpha_x"]
    m_value = params["m_value"]
    k_value = params["k_value"]
    j_value = params["j_value"]
    noise_dimension = params["noise_dimension"]
    hidden_layer_size = params["hidden_layer_size"]
    normal_ini = params["normal_ini"]
    preprocess = params["preprocess"]
    G_lr = params["G_lr"]
    alpha = params["alpha"]
    alpha1 = params["alpha1"]
    set_seeds = params["set_seeds"]
    using_oracle = params["using_oracle"]
    lambda_1 = params["lambda_1"]
    lambda_2 = params["lambda_2"]
    using_Gen = params["using_Gen"]
    boor_rv_type = params["boor_rv_type"]
    wgt_decay = params["wgt_decay"]
    lambda_3 = params["lambda_3"]
    drop_out_p = params["drop_out_p"]
    M_train = params["M_train"]
    lambda_mean = params["lambda_mean"]
    mean_samples = params["mean_samples"]


    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    a_f = torch.rand((z_dim, dx))
    l1_norm_a_f = torch.linalg.vector_norm(a_f, ord=1)
    Ax = a_f / l1_norm_a_f

    a_g = torch.rand((z_dim, dy))
    l1_norm_a_g = torch.linalg.vector_norm(a_g, ord=1)
    Ay = a_g / l1_norm_a_g

    p_values = np.array([])
    test_count = 0

    if test == 'type1error':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train, lambda_mean=lambda_mean, mean_samples=mean_samples
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))

    elif test == 'power':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))
    else:
        raise ValueError("test must be 'type1error' or 'power'")

    return p_values


# =========================
# Run
# =========================
run_experiment(param)
# Out:
# --- The 1'th iteration take 0:00:07.763231 seconds ---
# The stat is 0.395
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 2'th iteration take 0:00:06.142442 seconds ---
# The stat is 0.13
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 3'th iteration take 0:00:06.094935 seconds ---
# The stat is 0.79
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 4'th iteration take 0:00:06.130395 seconds ---
# The stat is 0.476
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 5'th iteration take 0:00:06.135688 seconds ---
# The stat is 0.806
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 6'th iteration take 0:00:06.082036 seconds ---
# The stat is 0.653
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 7'th iteration take 0:00:06.119050 seconds ---
# The stat is 0.12
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 8'th iteration take 0:00:06.131884 seconds ---
# The stat is 0.902
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 9'th iteration take 0:00:06.359991 seconds ---
# The stat is 0.503
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 10'th iteration take 0:00:06.418087 seconds ---
# The stat is 0.262
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 11'th iteration take 0:00:06.069581 seconds ---
# The stat is 0.902
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 12'th iteration take 0:00:07.049853 seconds ---
# The stat is 0.804
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 13'th iteration take 0:00:06.191575 seconds ---
# The stat is 0.84
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 14'th iteration take 0:00:05.887239 seconds ---
# The stat is 0.563
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 15'th iteration take 0:00:05.900565 seconds ---
# The stat is 0.96
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 16'th iteration take 0:00:05.846800 seconds ---
# The stat is 0.624
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 17'th iteration take 0:00:05.859605 seconds ---
# The stat is 0.26
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 18'th iteration take 0:00:05.842467 seconds ---
# The stat is 0.639
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 19'th iteration take 0:00:05.849423 seconds ---
# The stat is 0.279
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 20'th iteration take 0:00:06.326499 seconds ---
# The stat is 0.895
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 21'th iteration take 0:00:05.927463 seconds ---
# The stat is 0.711
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 22'th iteration take 0:00:05.886385 seconds ---
# The stat is 0.614
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 23'th iteration take 0:00:05.915077 seconds ---
# The stat is 0.853
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 24'th iteration take 0:00:06.802347 seconds ---
# The stat is 0.729
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 25'th iteration take 0:00:06.070371 seconds ---
# The stat is 0.009
# Type 1 error: 0.04 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# --- The 26'th iteration take 0:00:05.983488 seconds ---
# The stat is 0.439
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.1
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.05
# --- The 27'th iteration take 0:00:05.951423 seconds ---
# The stat is 0.015
# Type 1 error: 0.07407407407407407 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07407407407407407 for z dimension 1 with significance level 0.05
# --- The 28'th iteration take 0:00:06.012640 seconds ---
# The stat is 0.979
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 29'th iteration take 0:00:05.981780 seconds ---
# The stat is 0.212
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.05
# --- The 30'th iteration take 0:00:05.985343 seconds ---
# The stat is 0.007
# Type 1 error: 0.1 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 31'th iteration take 0:00:06.003284 seconds ---
# The stat is 0.028
# Type 1 error: 0.12903225806451613 for z dimension 1 with significance level 0.1
# Type 1 error: 0.12903225806451613 for z dimension 1 with significance level 0.05
# --- The 32'th iteration take 0:00:06.006016 seconds ---
# The stat is 0.352
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.125 for z dimension 1 with significance level 0.05
# --- The 33'th iteration take 0:00:05.939926 seconds ---
# The stat is 0.701
# Type 1 error: 0.12121212121212122 for z dimension 1 with significance level 0.1
# Type 1 error: 0.12121212121212122 for z dimension 1 with significance level 0.05
# --- The 34'th iteration take 0:00:05.947411 seconds ---
# The stat is 0.974
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.05
# --- The 35'th iteration take 0:00:06.308747 seconds ---
# The stat is 0.394
# Type 1 error: 0.11428571428571428 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11428571428571428 for z dimension 1 with significance level 0.05
# --- The 36'th iteration take 0:00:06.223101 seconds ---
# The stat is 0.954
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 37'th iteration take 0:00:06.229329 seconds ---
# The stat is 0.001
# Type 1 error: 0.13513513513513514 for z dimension 1 with significance level 0.1
# Type 1 error: 0.13513513513513514 for z dimension 1 with significance level 0.05
# --- The 38'th iteration take 0:00:06.196519 seconds ---
# The stat is 0.181
# Type 1 error: 0.13157894736842105 for z dimension 1 with significance level 0.1
# Type 1 error: 0.13157894736842105 for z dimension 1 with significance level 0.05
# --- The 39'th iteration take 0:00:06.219581 seconds ---
# The stat is 0.089
# Type 1 error: 0.15384615384615385 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1282051282051282 for z dimension 1 with significance level 0.05
# --- The 40'th iteration take 0:00:06.241565 seconds ---
# The stat is 0.886
# Type 1 error: 0.15 for z dimension 1 with significance level 0.1
# Type 1 error: 0.125 for z dimension 1 with significance level 0.05
# --- The 41'th iteration take 0:00:06.229711 seconds ---
# The stat is 0.256
# Type 1 error: 0.14634146341463414 for z dimension 1 with significance level 0.1
# Type 1 error: 0.12195121951219512 for z dimension 1 with significance level 0.05
# --- The 42'th iteration take 0:00:06.273602 seconds ---
# The stat is 0.213
# Type 1 error: 0.14285714285714285 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11904761904761904 for z dimension 1 with significance level 0.05
# --- The 43'th iteration take 0:00:06.417309 seconds ---
# The stat is 0.79
# Type 1 error: 0.13953488372093023 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11627906976744186 for z dimension 1 with significance level 0.05
# --- The 44'th iteration take 0:00:06.244669 seconds ---
# The stat is 0.404
# Type 1 error: 0.13636363636363635 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11363636363636363 for z dimension 1 with significance level 0.05
# --- The 45'th iteration take 0:00:06.192190 seconds ---
# The stat is 0.081
# Type 1 error: 0.15555555555555556 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 46'th iteration take 0:00:06.179000 seconds ---
# The stat is 0.506
# Type 1 error: 0.15217391304347827 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10869565217391304 for z dimension 1 with significance level 0.05
# --- The 47'th iteration take 0:00:06.203419 seconds ---
# The stat is 0.786
# Type 1 error: 0.14893617021276595 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10638297872340426 for z dimension 1 with significance level 0.05
# --- The 48'th iteration take 0:00:06.242207 seconds ---
# The stat is 0.528
# Type 1 error: 0.14583333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10416666666666667 for z dimension 1 with significance level 0.05
# --- The 49'th iteration take 0:00:06.310120 seconds ---
# The stat is 0.524
# Type 1 error: 0.14285714285714285 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10204081632653061 for z dimension 1 with significance level 0.05
# --- The 50'th iteration take 0:00:06.210763 seconds ---
# The stat is 0.964
# Type 1 error: 0.14 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 51'th iteration take 0:00:06.236103 seconds ---
# The stat is 0.209
# Type 1 error: 0.13725490196078433 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09803921568627451 for z dimension 1 with significance level 0.05
# --- The 52'th iteration take 0:00:06.227645 seconds ---
# The stat is 0.21
# Type 1 error: 0.1346153846153846 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09615384615384616 for z dimension 1 with significance level 0.05
# --- The 53'th iteration take 0:00:06.282133 seconds ---
# The stat is 0.871
# Type 1 error: 0.1320754716981132 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09433962264150944 for z dimension 1 with significance level 0.05
# --- The 54'th iteration take 0:00:06.205889 seconds ---
# The stat is 0.868
# Type 1 error: 0.12962962962962962 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09259259259259259 for z dimension 1 with significance level 0.05
# --- The 55'th iteration take 0:00:06.217585 seconds ---
# The stat is 0.187
# Type 1 error: 0.12727272727272726 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 56'th iteration take 0:00:06.208035 seconds ---
# The stat is 0.749
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08928571428571429 for z dimension 1 with significance level 0.05
# --- The 57'th iteration take 0:00:06.221931 seconds ---
# The stat is 0.718
# Type 1 error: 0.12280701754385964 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08771929824561403 for z dimension 1 with significance level 0.05
# --- The 58'th iteration take 0:00:06.213189 seconds ---
# The stat is 0.017
# Type 1 error: 0.13793103448275862 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10344827586206896 for z dimension 1 with significance level 0.05
# --- The 59'th iteration take 0:00:06.283933 seconds ---
# The stat is 0.16
# Type 1 error: 0.13559322033898305 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1016949152542373 for z dimension 1 with significance level 0.05
# --- The 60'th iteration take 0:00:06.194347 seconds ---
# The stat is 0.472
# Type 1 error: 0.13333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 61'th iteration take 0:00:06.242058 seconds ---
# The stat is 0.973
# Type 1 error: 0.13114754098360656 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09836065573770492 for z dimension 1 with significance level 0.05
# --- The 62'th iteration take 0:00:06.233648 seconds ---
# The stat is 0.476
# Type 1 error: 0.12903225806451613 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0967741935483871 for z dimension 1 with significance level 0.05
# --- The 63'th iteration take 0:00:06.227304 seconds ---
# The stat is 0.347
# Type 1 error: 0.12698412698412698 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09523809523809523 for z dimension 1 with significance level 0.05
# --- The 64'th iteration take 0:00:06.226716 seconds ---
# The stat is 0.92
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09375 for z dimension 1 with significance level 0.05
# --- The 65'th iteration take 0:00:06.278281 seconds ---
# The stat is 0.766
# Type 1 error: 0.12307692307692308 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09230769230769231 for z dimension 1 with significance level 0.05
# --- The 66'th iteration take 0:00:06.227603 seconds ---
# The stat is 0.171
# Type 1 error: 0.12121212121212122 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 67'th iteration take 0:00:06.224116 seconds ---
# The stat is 0.294
# Type 1 error: 0.11940298507462686 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08955223880597014 for z dimension 1 with significance level 0.05
# --- The 68'th iteration take 0:00:06.214748 seconds ---
# The stat is 0.58
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08823529411764706 for z dimension 1 with significance level 0.05
# --- The 69'th iteration take 0:00:06.247210 seconds ---
# The stat is 0.853
# Type 1 error: 0.11594202898550725 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08695652173913043 for z dimension 1 with significance level 0.05
# --- The 70'th iteration take 0:00:06.200198 seconds ---
# The stat is 0.967
# Type 1 error: 0.11428571428571428 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08571428571428572 for z dimension 1 with significance level 0.05
# --- The 71'th iteration take 0:00:06.218634 seconds ---
# The stat is 0.538
# Type 1 error: 0.11267605633802817 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08450704225352113 for z dimension 1 with significance level 0.05
# --- The 72'th iteration take 0:00:06.301244 seconds ---
# The stat is 0.932
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 73'th iteration take 0:00:06.580820 seconds ---
# The stat is 0.888
# Type 1 error: 0.1095890410958904 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0821917808219178 for z dimension 1 with significance level 0.05
# --- The 74'th iteration take 0:00:06.224161 seconds ---
# The stat is 0.898
# Type 1 error: 0.10810810810810811 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08108108108108109 for z dimension 1 with significance level 0.05
# --- The 75'th iteration take 0:00:06.416254 seconds ---
# The stat is 0.505
# Type 1 error: 0.10666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08 for z dimension 1 with significance level 0.05
# --- The 76'th iteration take 0:00:06.211283 seconds ---
# The stat is 0.6
# Type 1 error: 0.10526315789473684 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07894736842105263 for z dimension 1 with significance level 0.05
# --- The 77'th iteration take 0:00:06.274962 seconds ---
# The stat is 0.33
# Type 1 error: 0.1038961038961039 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07792207792207792 for z dimension 1 with significance level 0.05
# --- The 78'th iteration take 0:00:06.395738 seconds ---
# The stat is 0.769
# Type 1 error: 0.10256410256410256 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 79'th iteration take 0:00:06.242302 seconds ---
# The stat is 0.683
# Type 1 error: 0.10126582278481013 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0759493670886076 for z dimension 1 with significance level 0.05
# --- The 80'th iteration take 0:00:06.283472 seconds ---
# The stat is 0.51
# Type 1 error: 0.1 for z dimension 1 with significance level 0.1
# Type 1 error: 0.075 for z dimension 1 with significance level 0.05
# --- The 81'th iteration take 0:00:06.322545 seconds ---
# The stat is 0.636
# Type 1 error: 0.09876543209876543 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07407407407407407 for z dimension 1 with significance level 0.05
# --- The 82'th iteration take 0:00:06.424340 seconds ---
# The stat is 0.628
# Type 1 error: 0.0975609756097561 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07317073170731707 for z dimension 1 with significance level 0.05
# --- The 83'th iteration take 0:00:06.328893 seconds ---
# The stat is 0.528
# Type 1 error: 0.0963855421686747 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07228915662650602 for z dimension 1 with significance level 0.05
# --- The 84'th iteration take 0:00:06.273103 seconds ---
# The stat is 0.546
# Type 1 error: 0.09523809523809523 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 85'th iteration take 0:00:06.297795 seconds ---
# The stat is 0.144
# Type 1 error: 0.09411764705882353 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07058823529411765 for z dimension 1 with significance level 0.05
# --- The 86'th iteration take 0:00:06.204267 seconds ---
# The stat is 0.175
# Type 1 error: 0.09302325581395349 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06976744186046512 for z dimension 1 with significance level 0.05
# --- The 87'th iteration take 0:00:06.258661 seconds ---
# The stat is 0.486
# Type 1 error: 0.09195402298850575 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.05
# --- The 88'th iteration take 0:00:06.217615 seconds ---
# The stat is 0.389
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06818181818181818 for z dimension 1 with significance level 0.05
# --- The 89'th iteration take 0:00:06.263230 seconds ---
# The stat is 0.623
# Type 1 error: 0.0898876404494382 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06741573033707865 for z dimension 1 with significance level 0.05
# --- The 90'th iteration take 0:00:08.271465 seconds ---
# The stat is 0.819
# Type 1 error: 0.08888888888888889 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 91'th iteration take 0:00:06.959294 seconds ---
# The stat is 0.785
# Type 1 error: 0.08791208791208792 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06593406593406594 for z dimension 1 with significance level 0.05
# --- The 92'th iteration take 0:00:06.345667 seconds ---
# The stat is 0.76
# Type 1 error: 0.08695652173913043 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06521739130434782 for z dimension 1 with significance level 0.05
# --- The 93'th iteration take 0:00:06.305870 seconds ---
# The stat is 0.844
# Type 1 error: 0.08602150537634409 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.05
# --- The 94'th iteration take 0:00:06.323275 seconds ---
# The stat is 0.538
# Type 1 error: 0.0851063829787234 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06382978723404255 for z dimension 1 with significance level 0.05
# --- The 95'th iteration take 0:00:06.235894 seconds ---
# The stat is 0.655
# Type 1 error: 0.08421052631578947 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06315789473684211 for z dimension 1 with significance level 0.05
# --- The 96'th iteration take 0:00:06.251087 seconds ---
# The stat is 0.392
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 97'th iteration take 0:00:08.087292 seconds ---
# The stat is 0.773
# Type 1 error: 0.08247422680412371 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061855670103092786 for z dimension 1 with significance level 0.05
# --- The 98'th iteration take 0:00:07.303653 seconds ---
# The stat is 0.208
# Type 1 error: 0.08163265306122448 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061224489795918366 for z dimension 1 with significance level 0.05
# --- The 99'th iteration take 0:00:06.247732 seconds ---
# The stat is 0.243
# Type 1 error: 0.08080808080808081 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06060606060606061 for z dimension 1 with significance level 0.05
# --- The 100'th iteration take 0:00:06.319592 seconds ---
# The stat is 0.602
# Type 1 error: 0.08 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06 for z dimension 1 with significance level 0.05
# array([0.395, 0.13 , 0.79 , 0.476, 0.806, 0.653, 0.12 , 0.902, 0.503,
#        0.262, 0.902, 0.804, 0.84 , 0.563, 0.96 , 0.624, 0.26 , 0.639,
#        0.279, 0.895, 0.711, 0.614, 0.853, 0.729, 0.009, 0.439, 0.015,
#        0.979, 0.212, 0.007, 0.028, 0.352, 0.701, 0.974, 0.394, 0.954,
#        0.001, 0.181, 0.089, 0.886, 0.256, 0.213, 0.79 , 0.404, 0.081,
#        0.506, 0.786, 0.528, 0.524, 0.964, 0.209, 0.21 , 0.871, 0.868,
#        0.187, 0.749, 0.718, 0.017, 0.16 , 0.472, 0.973, 0.476, 0.347,
#        0.92 , 0.766, 0.171, 0.294, 0.58 , 0.853, 0.967, 0.538, 0.932,
#        0.888, 0.898, 0.505, 0.6  , 0.33 , 0.769, 0.683, 0.51 , 0.636,
#        0.628, 0.528, 0.546, 0.144, 0.175, 0.486, 0.389, 0.623, 0.819,
#        0.785, 0.76 , 0.844, 0.538, 0.655, 0.392, 0.773, 0.208, 0.243,
#        0.602])

# %%
import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools


# =========================
# Device
# =========================
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


# =========================
# Parameters
# =========================
param = {
    "test": "type1error",
    "sample_size": 600,
    "batch_size": 256,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 200,
    "eps_std": 0.5,
    "dist_z": 'gaussian',
    "alpha_x": 0.75,
    "m_value": 100,
    "k_value": 2,
    "j_value": 1000,
    "noise_dimension": 3,
    "hidden_layer_size": 20,
    "normal_ini": False,
    "preprocess": 'None',
    "G_lr": 1e-3,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 42,
    "using_oracle": False,
    "lambda_1": 1,
    "lambda_2": 0,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-5,
    "drop_out_p": 0.2,
    "M_train": 10,

    # 你的改进
    "lambda_mean": 0.5,
    "mean_samples": 20
}



# =========================
# Data generation: binary version
# =========================
def generate_samples_random(Ax, Ay, size=1000, sType='CI', dx=1, dy=1, dz=1,
                            nstd=0.05, alpha_x=0.05,
                            preprocess="None", dist_z='gaussian'):
    """
    Binary data generator aligned with the author's pasted code.

    Output:
        X, Y, Z are all binary {0,1} tensors.
    """
    if dx != 1 or dy != 1 or dz != 1:
        raise ValueError("This binary version currently supports dx=dy=dz=1 only.")

    num = size

    if sType in ['CI', 'H0', 'type1error']:
        numbers_z = np.random.multinomial(num, [0.5, 0.5], size=1)
        number_z_zeros = numbers_z[0][0]
        number_z_ones = numbers_z[0][1]

        xy_arr = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

        xy_z_zero_index = np.random.choice(
            a=len(xy_arr), size=number_z_zeros,
            p=[0.25, 0.25, 0.25, 0.25]
        )
        xy_z_one_index = np.random.choice(
            a=len(xy_arr), size=number_z_ones,
            p=[0.25, 0.25, 0.25, 0.25]
        )

        xy_z_zero = xy_arr[xy_z_zero_index]
        xy_z_one = xy_arr[xy_z_one_index]

        xy = np.concatenate((xy_z_zero, xy_z_one), axis=0)

        x = xy[:, 0]
        y = xy[:, 1]
        z = np.concatenate((np.zeros(number_z_zeros), np.ones(number_z_ones)), axis=0)

    elif sType in ['dependent', 'H1', 'power']:
        z = np.random.binomial(1, 0.5, size=num)
        y = np.random.binomial(1, 0.5, size=num)

        delta = np.random.binomial(1, alpha_x, size=num)
        x_indep = np.random.binomial(1, 0.5, size=num)

        x = (1 - delta) * x_indep + delta * y
        x = x.astype(int)

    else:
        raise ValueError("sType must be one of ['CI','H0','type1error','dependent','H1','power']")

    indices = np.random.permutation(num)
    x, y, z = x[indices], y[indices], z[indices]

    X = x.reshape(-1, 1).astype(np.float32)
    Y = y.reshape(-1, 1).astype(np.float32)
    Z = z.reshape(-1, 1).astype(np.float32)

    if preprocess == "normalize":
        pass
    elif preprocess == "scale_Z":
        pass
    elif preprocess == "None":
        pass
    else:
        raise ValueError("preprocess must be one of ['normalize', 'scale_Z', 'None']")

    X = torch.from_numpy(X).float()
    Y = torch.from_numpy(Y).float()
    Z = torch.from_numpy(Z).float()

    return X, Y, Z


# =========================
# Statistic computation
# =========================
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                       x_torch, y_torch, z_torch,
                       sigma_w, sigma_u=1, sigma_v=1,
                       boor_rv_type="gaussian"):
    """
    Compute test statistic and bootstrap samples.
    Shapes:
        gen_x_all_torch, gen_y_all_torch: (n, M)
        x_torch, y_torch: (n, 1)
        z_torch: (n, dz)
    """
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v
        ),
        dim=2
    )
    v_mx_3 = v_mx_2.T

    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
        dim=2
    )

    for i in range(1, M):
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
            dim=2
        )
        sum2_mx = sum2_mx + temp2_add_mx

    v_mx_4 = 1.0 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n, device=device))

    stat = 1.0 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])

    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num, device=device))
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num, device=device)
    else:
        raise ValueError("boor_rv_type must be 'rademacher' or 'gaussian'")

    for bb in range(boot_num):
        random_mx = torch.matmul(
            eboot[:, bb].reshape(-1, 1),
            eboot[:, bb].reshape(-1, 1).T
        )
        bootmatrix = FF_mx * random_mx
        stat_boot = 1.0 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)

    return stat, boottemp


# =========================
# Dataset
# =========================
class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (
            self.X_real[index],
            self.Y_real[index],
            self.Z_real[index],
            self.Z_real[(self.batch_size + index) % self.sample_size]
        )


# =========================
# Noise sampler
# =========================
def sample_noise(sample_size, noise_dimension, noise_type, input_var):
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),
            input_var * torch.eye(noise_dimension).to(device)
        )
        Z = noise_generator.sample((sample_size,))
    elif noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension, device=device)
    elif noise_type == "Cauchy":
        Z = TD.Cauchy(
            torch.tensor([0.0], device=device),
            torch.tensor([1.0], device=device)
        ).sample((sample_size, noise_dimension)).squeeze(2)
    else:
        raise ValueError("noise_type must be one of ['normal', 'unif', 'Cauchy']")
    return Z


# =========================
# Generator
# =========================
class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p,
                 drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.drop_input = drop_input

        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)

        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)

        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        if self.drop_input:
            x = self.drop_out0(x)

        if self.BN_type:
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
        else:
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))

        x = self.fc_last(x)

        # Binary probability output
        x = self.sigmoid(x)

        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias).to(device)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for _ in range(m)]
        ).to(device)

    def forward(self, x):
        self.linear.weight.data *= self.mask
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)

        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0]
        )

        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for _ in range(len(self.hidden_layer_sizes))
        ])

        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        self.sigmoid = torch.nn.Sigmoid()

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)

        output = self.linear8(output)
        output = self.sigmoid(output)
        return output


# =========================
# Loss
# =========================
def find_loss(y_torch, gen_y_all_torch, z_torch, sigma_w, sigma_u, M):
    n = z_torch.shape[0]

    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    FF_mx = u_mx * w_mx * (1 - torch.eye(n, device=device))
    loss = 1.0 / n * torch.sum(FF_mx)

    return loss


# =========================
# Binary sampling helper
# =========================
def sample_binary_from_prob(prob_tensor):
    prob_tensor = torch.clamp(prob_tensor, 1e-6, 1 - 1e-6)
    return torch.bernoulli(prob_tensor)


# =========================
# Training
# =========================
def train_ver3(X, Y, Z, X_test, Y_test, Z_test, M,
               noise_dimension, noise_type, G_lr, hidden_layer_size,
               DataLoader, BN_type, ReLU_coef,
               epochs_num=10, sigma_z=1, sigma_x=1, sigma_y=1,
               normal_ini=False,
               lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
               lambda_3=0, drop_out_p=0.2, M_train=3,
               lambda_mean=0.0, mean_samples=20):

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if using_Gen == '1':
        G_zy = Generator(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    elif using_Gen == '2':
        G_zy = Generator_2(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator_2(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    else:
        raise ValueError("using_Gen must be '1' or '2'")

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))

    for epoch in range(epochs_num):
        G_zy.train()
        G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)
            Y_real = Y_real.to(device)
            Z_real = Z_real.to(device)
            Z_fake = Z_fake.to(device)

            batch_size = Z_real.shape[0]

            # =========================
            # Train G_zy
            # =========================
            G_zy_solver.zero_grad()

            Z_real_repeat_y = Z_real.repeat(M_train, 1)
            Noise_fake_y = sample_noise(
                Z_real_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            Y_fake_prob = G_zy(torch.cat((Z_real_repeat_y, Noise_fake_y), dim=1)).to(device)
            Y_fake = Y_fake_prob.reshape(batch_size, M_train)

            l1_regularization_y = 0.0
            for param in G_zy.parameters():
                l1_regularization_y += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = lambda_1 * find_loss(
                Y_real, Y_fake, Z_real, sigma_z, sigma_y, M_train
            )

            if lambda_mean > 0:
                # 这里保留你的改进：对同一个 Z 做 Monte Carlo 均值近似
                Z_mean_repeat_y = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_y = sample_noise(
                    Z_mean_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                Y_mean_fake_group = G_zy(torch.cat((Z_mean_repeat_y, Noise_mean_y), dim=1))
                Y_mean_fake = Y_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_y).mean(dim=1)

                mean_loss_y = torch.nn.functional.mse_loss(Y_mean_fake, Y_real)
            else:
                mean_loss_y = 0.0

            g_zy_error = mmd_loss_y + lambda_mean * mean_loss_y + lambda_3 * l1_regularization_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            # =========================
            # Train G_zx
            # =========================
            G_zx_solver.zero_grad()

            Z_real_repeat_x = Z_real.repeat(M_train, 1)
            Noise_fake_x = sample_noise(
                Z_real_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            X_fake_prob = G_zx(torch.cat((Z_real_repeat_x, Noise_fake_x), dim=1)).to(device)
            X_fake = X_fake_prob.reshape(batch_size, M_train)

            l1_regularization_x = 0.0
            for param in G_zx.parameters():
                l1_regularization_x += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = lambda_1 * find_loss(
                X_real, X_fake, Z_real, sigma_z, sigma_x, M_train
            )

            if lambda_mean > 0:
                Z_mean_repeat_x = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_x = sample_noise(
                    Z_mean_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                X_mean_fake_group = G_zx(torch.cat((Z_mean_repeat_x, Noise_mean_x), dim=1))
                X_mean_fake = X_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_x).mean(dim=1)

                mean_loss_x = torch.nn.functional.mse_loss(X_mean_fake, X_real)
            else:
                mean_loss_x = 0.0

            g_zx_error = mmd_loss_x + lambda_mean * mean_loss_x + lambda_3 * l1_regularization_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

    return G_zy, G_zx

# =========================
# Main experiment for one run
# =========================
def mGAN(Ax, Ay, n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_oracle=False, lambda_1=1, lambda_2=1, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2, exp_num=0,
         M_train=3, lambda_mean=0.0, mean_samples=20):


    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='CI', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='dependent', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x, sim_y, sim_z

    sigma_w_train = 1.0
    sigma_u_train = 1.0
    sigma_v_train = 1.0

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))

        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]

        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))

        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_oracle:
            G_zy, G_zx = train_ver3(
    X=X_train, Y=Y_train, Z=Z_train, M=M,
    X_test=X_test, Y_test=Y_test, Z_test=Z_test,
    noise_dimension=noise_dimension, noise_type="normal",
    G_lr=G_lr, hidden_layer_size=hidden_layer_size,
    DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
    epochs_num=epochs_num, sigma_z=sigma_w_train, sigma_x=sigma_v_train,
    sigma_y=sigma_u_train, normal_ini=normal_ini, lambda_1=lambda_1,
    lambda_2=lambda_2, using_Gen=using_Gen, wgt_decay=wgt_decay,
    lambda_3=lambda_3, drop_out_p=drop_out_p, M_train=M_train,
    lambda_mean=lambda_mean, mean_samples=mean_samples
)


        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M)
        gen_y_all = torch.zeros(test_size, M)

        z_all = torch.zeros(test_size, z_dim)
        x_all = torch.zeros(test_size, x_dims)
        y_all = torch.zeros(test_size, y_dims)

        cur_itr = 0

        if using_oracle:
            for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                z_scalar = int(z_test.item())

                fake_x = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)
                fake_y = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)

                gen_x_all[cur_itr, :] = fake_x.reshape(-1)
                gen_y_all[cur_itr, :] = fake_y.reshape(-1)

                x_all[cur_itr, :] = x_test
                y_all[cur_itr, :] = y_test
                z_all[cur_itr, :] = z_test
                cur_itr += 1
        else:
            G_zx.eval()
            G_zy.eval()

            with torch.no_grad():
                for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                    z_test_temp = z_test.repeat(M, 1).to(device)

                    noise_x = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_x_prob = G_zx(torch.cat((z_test_temp, noise_x), dim=1))
                    fake_x = sample_binary_from_prob(fake_x_prob).reshape(1, -1)

                    noise_y = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_y_prob = G_zy(torch.cat((z_test_temp, noise_y), dim=1))
                    fake_y = sample_binary_from_prob(fake_y_prob).reshape(1, -1)

                    gen_x_all[cur_itr, :] = fake_x.detach().cpu().reshape(-1)
                    gen_y_all[cur_itr, :] = fake_y.detach().cpu().reshape(-1)
                    x_all[cur_itr, :] = x_test
                    y_all[cur_itr, :] = y_test
                    z_all[cur_itr, :] = z_test
                    cur_itr += 1

        gen_x_all = gen_x_all.to(device)
        gen_y_all = gen_y_all.to(device)

        z_all = Z_test.to(device)
        x_all = X_test.to(device)
        y_all = Y_test.to(device)

        sigma_w = 1.0
        sigma_u = 1.0
        sigma_v = 1.0

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type
        )

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp).float()
        cur_k += 1

    return np.mean(torch.mean(boot_temp_all, dim=0).cpu().numpy() > torch.mean(stat_all).item())


# =========================
# Repeated experiment
# =========================
def run_experiment(params):
    test = params["test"]
    sample_size = params["sample_size"]
    batch_size = params["batch_size"]
    z_dim = params["z_dim"]
    dx = params["dx"]
    dy = params["dy"]
    n_test = params["n_test"]
    epochs_num = params["epochs_num"]
    eps_std = params["eps_std"]
    dist_z = params["dist_z"]
    alpha_x = params["alpha_x"]
    m_value = params["m_value"]
    k_value = params["k_value"]
    j_value = params["j_value"]
    noise_dimension = params["noise_dimension"]
    hidden_layer_size = params["hidden_layer_size"]
    normal_ini = params["normal_ini"]
    preprocess = params["preprocess"]
    G_lr = params["G_lr"]
    alpha = params["alpha"]
    alpha1 = params["alpha1"]
    set_seeds = params["set_seeds"]
    using_oracle = params["using_oracle"]
    lambda_1 = params["lambda_1"]
    lambda_2 = params["lambda_2"]
    using_Gen = params["using_Gen"]
    boor_rv_type = params["boor_rv_type"]
    wgt_decay = params["wgt_decay"]
    lambda_3 = params["lambda_3"]
    drop_out_p = params["drop_out_p"]
    M_train = params["M_train"]
    lambda_mean = params["lambda_mean"]
    mean_samples = params["mean_samples"]


    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    a_f = torch.rand((z_dim, dx))
    l1_norm_a_f = torch.linalg.vector_norm(a_f, ord=1)
    Ax = a_f / l1_norm_a_f

    a_g = torch.rand((z_dim, dy))
    l1_norm_a_g = torch.linalg.vector_norm(a_g, ord=1)
    Ay = a_g / l1_norm_a_g

    p_values = np.array([])
    test_count = 0

    if test == 'type1error':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train, lambda_mean=lambda_mean, mean_samples=mean_samples
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))

    elif test == 'power':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))
    else:
        raise ValueError("test must be 'type1error' or 'power'")

    return p_values


# =========================
# Run
# =========================
run_experiment(param)
# Out:
# --- The 1'th iteration take 0:00:38.407557 seconds ---
# The stat is 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 2'th iteration take 0:00:36.706593 seconds ---
# The stat is 0.595
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 3'th iteration take 0:00:37.666358 seconds ---
# The stat is 0.458
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 4'th iteration take 0:00:37.068035 seconds ---
# The stat is 0.414
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 5'th iteration take 0:00:37.214614 seconds ---
# The stat is 0.81
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 6'th iteration take 0:00:37.242654 seconds ---
# The stat is 0.973
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 7'th iteration take 0:00:37.765965 seconds ---
# The stat is 0.986
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 8'th iteration take 0:00:37.385159 seconds ---
# The stat is 0.743
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 9'th iteration take 0:00:37.457368 seconds ---
# The stat is 0.491
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 10'th iteration take 0:00:37.474879 seconds ---
# The stat is 0.624
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 11'th iteration take 0:00:37.416033 seconds ---
# The stat is 0.898
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 12'th iteration take 0:00:37.533421 seconds ---
# The stat is 0.271
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 13'th iteration take 0:00:37.002542 seconds ---
# The stat is 0.724
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 14'th iteration take 0:00:37.312602 seconds ---
# The stat is 0.134
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 15'th iteration take 0:00:37.907611 seconds ---
# The stat is 0.028
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 16'th iteration take 0:00:37.630809 seconds ---
# The stat is 0.498
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 17'th iteration take 0:00:37.725250 seconds ---
# The stat is 0.55
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 18'th iteration take 0:00:37.693246 seconds ---
# The stat is 0.592
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 19'th iteration take 0:00:37.535951 seconds ---
# The stat is 0.638
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.05
# --- The 20'th iteration take 0:00:37.187442 seconds ---
# The stat is 0.086
# Type 1 error: 0.1 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# --- The 21'th iteration take 0:00:37.070035 seconds ---
# The stat is 0.303
# Type 1 error: 0.09523809523809523 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.05
# --- The 22'th iteration take 0:00:37.465661 seconds ---
# The stat is 0.825
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.05
# --- The 23'th iteration take 0:00:37.724332 seconds ---
# The stat is 0.373
# Type 1 error: 0.08695652173913043 for z dimension 1 with significance level 0.1
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.05
# --- The 24'th iteration take 0:00:37.108231 seconds ---
# The stat is 0.502
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.05
# --- The 25'th iteration take 0:00:36.933085 seconds ---
# The stat is 0.298
# Type 1 error: 0.08 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# --- The 26'th iteration take 0:00:38.345511 seconds ---
# The stat is 0.401
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.1
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.05
# --- The 27'th iteration take 0:00:37.288181 seconds ---
# The stat is 0.503
# Type 1 error: 0.07407407407407407 for z dimension 1 with significance level 0.1
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.05
# --- The 28'th iteration take 0:00:36.784951 seconds ---
# The stat is 0.421
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03571428571428571 for z dimension 1 with significance level 0.05
# --- The 29'th iteration take 0:00:37.015488 seconds ---
# The stat is 0.487
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.1
# Type 1 error: 0.034482758620689655 for z dimension 1 with significance level 0.05
# --- The 30'th iteration take 0:00:36.903277 seconds ---
# The stat is 0.166
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03333333333333333 for z dimension 1 with significance level 0.05
# --- The 31'th iteration take 0:00:36.983768 seconds ---
# The stat is 0.557
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03225806451612903 for z dimension 1 with significance level 0.05
# --- The 32'th iteration take 0:00:36.796838 seconds ---
# The stat is 0.191
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03125 for z dimension 1 with significance level 0.05
# --- The 33'th iteration take 0:00:37.016576 seconds ---
# The stat is 0.704
# Type 1 error: 0.06060606060606061 for z dimension 1 with significance level 0.1
# Type 1 error: 0.030303030303030304 for z dimension 1 with significance level 0.05
# --- The 34'th iteration take 0:00:35.872612 seconds ---
# The stat is 0.848
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.1
# Type 1 error: 0.029411764705882353 for z dimension 1 with significance level 0.05
# --- The 35'th iteration take 0:00:37.073185 seconds ---
# The stat is 0.183
# Type 1 error: 0.05714285714285714 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02857142857142857 for z dimension 1 with significance level 0.05
# --- The 36'th iteration take 0:00:37.483419 seconds ---
# The stat is 0.351
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.1
# Type 1 error: 0.027777777777777776 for z dimension 1 with significance level 0.05
# --- The 37'th iteration take 0:00:37.339069 seconds ---
# The stat is 0.89
# Type 1 error: 0.05405405405405406 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02702702702702703 for z dimension 1 with significance level 0.05
# --- The 38'th iteration take 0:00:37.267000 seconds ---
# The stat is 0.157
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02631578947368421 for z dimension 1 with significance level 0.05
# --- The 39'th iteration take 0:00:37.073263 seconds ---
# The stat is 0.695
# Type 1 error: 0.05128205128205128 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02564102564102564 for z dimension 1 with significance level 0.05
# --- The 40'th iteration take 0:00:37.481734 seconds ---
# The stat is 0.817
# Type 1 error: 0.05 for z dimension 1 with significance level 0.1
# Type 1 error: 0.025 for z dimension 1 with significance level 0.05
# --- The 41'th iteration take 0:00:36.981027 seconds ---
# The stat is 0.419
# Type 1 error: 0.04878048780487805 for z dimension 1 with significance level 0.1
# Type 1 error: 0.024390243902439025 for z dimension 1 with significance level 0.05
# --- The 42'th iteration take 0:00:37.164366 seconds ---
# The stat is 0.256
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.1
# Type 1 error: 0.023809523809523808 for z dimension 1 with significance level 0.05
# --- The 43'th iteration take 0:00:37.187960 seconds ---
# The stat is 0.163
# Type 1 error: 0.046511627906976744 for z dimension 1 with significance level 0.1
# Type 1 error: 0.023255813953488372 for z dimension 1 with significance level 0.05
# --- The 44'th iteration take 0:00:36.986940 seconds ---
# The stat is 0.277
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.1
# Type 1 error: 0.022727272727272728 for z dimension 1 with significance level 0.05
# --- The 45'th iteration take 0:00:37.267492 seconds ---
# The stat is 0.479
# Type 1 error: 0.044444444444444446 for z dimension 1 with significance level 0.1
# Type 1 error: 0.022222222222222223 for z dimension 1 with significance level 0.05
# --- The 46'th iteration take 0:00:37.064763 seconds ---
# The stat is 0.757
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.1
# Type 1 error: 0.021739130434782608 for z dimension 1 with significance level 0.05
# --- The 47'th iteration take 0:00:37.125641 seconds ---
# The stat is 0.119
# Type 1 error: 0.0425531914893617 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02127659574468085 for z dimension 1 with significance level 0.05
# --- The 48'th iteration take 0:00:36.937520 seconds ---
# The stat is 0.43
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.1
# Type 1 error: 0.020833333333333332 for z dimension 1 with significance level 0.05
# --- The 49'th iteration take 0:00:37.558675 seconds ---
# The stat is 0.137
# Type 1 error: 0.04081632653061224 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02040816326530612 for z dimension 1 with significance level 0.05
# --- The 50'th iteration take 0:00:36.965653 seconds ---
# The stat is 0.341
# Type 1 error: 0.04 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02 for z dimension 1 with significance level 0.05
# --- The 51'th iteration take 0:00:37.600627 seconds ---
# The stat is 0.975
# Type 1 error: 0.0392156862745098 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0196078431372549 for z dimension 1 with significance level 0.05
# --- The 52'th iteration take 0:00:37.015800 seconds ---
# The stat is 0.123
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.1
# Type 1 error: 0.019230769230769232 for z dimension 1 with significance level 0.05
# --- The 53'th iteration take 0:00:37.117457 seconds ---
# The stat is 0.89
# Type 1 error: 0.03773584905660377 for z dimension 1 with significance level 0.1
# Type 1 error: 0.018867924528301886 for z dimension 1 with significance level 0.05
# --- The 54'th iteration take 0:00:37.420411 seconds ---
# The stat is 0.982
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.1
# Type 1 error: 0.018518518518518517 for z dimension 1 with significance level 0.05
# --- The 55'th iteration take 0:00:37.469997 seconds ---
# The stat is 0.082
# Type 1 error: 0.05454545454545454 for z dimension 1 with significance level 0.1
# Type 1 error: 0.01818181818181818 for z dimension 1 with significance level 0.05
# --- The 56'th iteration take 0:00:37.183421 seconds ---
# The stat is 0.755
# Type 1 error: 0.05357142857142857 for z dimension 1 with significance level 0.1
# Type 1 error: 0.017857142857142856 for z dimension 1 with significance level 0.05
# --- The 57'th iteration take 0:00:37.208304 seconds ---
# The stat is 0.214
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.1
# Type 1 error: 0.017543859649122806 for z dimension 1 with significance level 0.05
# --- The 58'th iteration take 0:00:35.772816 seconds ---
# The stat is 0.483
# Type 1 error: 0.05172413793103448 for z dimension 1 with significance level 0.1
# Type 1 error: 0.017241379310344827 for z dimension 1 with significance level 0.05
# --- The 59'th iteration take 0:00:31.447851 seconds ---
# The stat is 0.095
# Type 1 error: 0.06779661016949153 for z dimension 1 with significance level 0.1
# Type 1 error: 0.01694915254237288 for z dimension 1 with significance level 0.05
# --- The 60'th iteration take 0:00:31.567686 seconds ---
# The stat is 0.409
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.016666666666666666 for z dimension 1 with significance level 0.05
# --- The 61'th iteration take 0:00:34.520576 seconds ---
# The stat is 0.285
# Type 1 error: 0.06557377049180328 for z dimension 1 with significance level 0.1
# Type 1 error: 0.01639344262295082 for z dimension 1 with significance level 0.05
# --- The 62'th iteration take 0:00:31.730868 seconds ---
# The stat is 0.642
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.1
# Type 1 error: 0.016129032258064516 for z dimension 1 with significance level 0.05
# --- The 63'th iteration take 0:00:31.633800 seconds ---
# The stat is 0.03
# Type 1 error: 0.07936507936507936 for z dimension 1 with significance level 0.1
# Type 1 error: 0.031746031746031744 for z dimension 1 with significance level 0.05
# --- The 64'th iteration take 0:00:31.514678 seconds ---
# The stat is 0.152
# Type 1 error: 0.078125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03125 for z dimension 1 with significance level 0.05
# --- The 65'th iteration take 0:00:31.644131 seconds ---
# The stat is 0.701
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03076923076923077 for z dimension 1 with significance level 0.05
# --- The 66'th iteration take 0:00:31.300356 seconds ---
# The stat is 0.825
# Type 1 error: 0.07575757575757576 for z dimension 1 with significance level 0.1
# Type 1 error: 0.030303030303030304 for z dimension 1 with significance level 0.05
# --- The 67'th iteration take 0:00:31.579191 seconds ---
# The stat is 0.009
# Type 1 error: 0.08955223880597014 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04477611940298507 for z dimension 1 with significance level 0.05
# --- The 68'th iteration take 0:00:31.622753 seconds ---
# The stat is 0.4
# Type 1 error: 0.08823529411764706 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04411764705882353 for z dimension 1 with significance level 0.05
# --- The 69'th iteration take 0:00:31.361427 seconds ---
# The stat is 0.979
# Type 1 error: 0.08695652173913043 for z dimension 1 with significance level 0.1
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.05
# --- The 70'th iteration take 0:00:31.397498 seconds ---
# The stat is 0.518
# Type 1 error: 0.08571428571428572 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04285714285714286 for z dimension 1 with significance level 0.05
# --- The 71'th iteration take 0:00:31.248392 seconds ---
# The stat is 0.277
# Type 1 error: 0.08450704225352113 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04225352112676056 for z dimension 1 with significance level 0.05
# --- The 72'th iteration take 0:00:31.981419 seconds ---
# The stat is 0.243
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.05
# --- The 73'th iteration take 0:00:31.645009 seconds ---
# The stat is 0.065
# Type 1 error: 0.0958904109589041 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0410958904109589 for z dimension 1 with significance level 0.05
# --- The 74'th iteration take 0:00:31.374530 seconds ---
# The stat is 0.174
# Type 1 error: 0.0945945945945946 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04054054054054054 for z dimension 1 with significance level 0.05
# --- The 75'th iteration take 0:00:31.304364 seconds ---
# The stat is 0.915
# Type 1 error: 0.09333333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# --- The 76'th iteration take 0:00:31.429486 seconds ---
# The stat is 0.14
# Type 1 error: 0.09210526315789473 for z dimension 1 with significance level 0.1
# Type 1 error: 0.039473684210526314 for z dimension 1 with significance level 0.05
# --- The 77'th iteration take 0:00:31.341300 seconds ---
# The stat is 0.371
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03896103896103896 for z dimension 1 with significance level 0.05
# --- The 78'th iteration take 0:00:31.417722 seconds ---
# The stat is 0.835
# Type 1 error: 0.08974358974358974 for z dimension 1 with significance level 0.1
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.05
# --- The 79'th iteration take 0:00:31.346952 seconds ---
# The stat is 0.846
# Type 1 error: 0.08860759493670886 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0379746835443038 for z dimension 1 with significance level 0.05
# --- The 80'th iteration take 0:00:31.406335 seconds ---
# The stat is 0.616
# Type 1 error: 0.0875 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0375 for z dimension 1 with significance level 0.05
# --- The 81'th iteration take 0:00:31.773503 seconds ---
# The stat is 0.744
# Type 1 error: 0.08641975308641975 for z dimension 1 with significance level 0.1
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.05
# --- The 82'th iteration take 0:00:31.648445 seconds ---
# The stat is 0.325
# Type 1 error: 0.08536585365853659 for z dimension 1 with significance level 0.1
# Type 1 error: 0.036585365853658534 for z dimension 1 with significance level 0.05
# --- The 83'th iteration take 0:00:31.522010 seconds ---
# The stat is 0.66
# Type 1 error: 0.08433734939759036 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03614457831325301 for z dimension 1 with significance level 0.05
# --- The 84'th iteration take 0:00:31.340380 seconds ---
# The stat is 0.988
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03571428571428571 for z dimension 1 with significance level 0.05
# --- The 85'th iteration take 0:00:31.576270 seconds ---
# The stat is 0.133
# Type 1 error: 0.08235294117647059 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03529411764705882 for z dimension 1 with significance level 0.05
# --- The 86'th iteration take 0:00:31.264749 seconds ---
# The stat is 0.613
# Type 1 error: 0.08139534883720931 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03488372093023256 for z dimension 1 with significance level 0.05
# --- The 87'th iteration take 0:00:31.207087 seconds ---
# The stat is 0.621
# Type 1 error: 0.08045977011494253 for z dimension 1 with significance level 0.1
# Type 1 error: 0.034482758620689655 for z dimension 1 with significance level 0.05
# --- The 88'th iteration take 0:00:31.832024 seconds ---
# The stat is 0.31
# Type 1 error: 0.07954545454545454 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03409090909090909 for z dimension 1 with significance level 0.05
# --- The 89'th iteration take 0:00:31.415709 seconds ---
# The stat is 0.831
# Type 1 error: 0.07865168539325842 for z dimension 1 with significance level 0.1
# Type 1 error: 0.033707865168539325 for z dimension 1 with significance level 0.05
# --- The 90'th iteration take 0:00:31.459857 seconds ---
# The stat is 0.39
# Type 1 error: 0.07777777777777778 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03333333333333333 for z dimension 1 with significance level 0.05
# --- The 91'th iteration take 0:00:34.135227 seconds ---
# The stat is 0.901
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03296703296703297 for z dimension 1 with significance level 0.05
# --- The 92'th iteration take 0:00:35.207287 seconds ---
# The stat is 0.301
# Type 1 error: 0.07608695652173914 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03260869565217391 for z dimension 1 with significance level 0.05
# --- The 93'th iteration take 0:00:32.069803 seconds ---
# The stat is 0.162
# Type 1 error: 0.07526881720430108 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03225806451612903 for z dimension 1 with significance level 0.05
# --- The 94'th iteration take 0:00:31.542372 seconds ---
# The stat is 0.004
# Type 1 error: 0.0851063829787234 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0425531914893617 for z dimension 1 with significance level 0.05
# --- The 95'th iteration take 0:00:31.558244 seconds ---
# The stat is 0.733
# Type 1 error: 0.08421052631578947 for z dimension 1 with significance level 0.1
# Type 1 error: 0.042105263157894736 for z dimension 1 with significance level 0.05
# --- The 96'th iteration take 0:00:31.564457 seconds ---
# The stat is 0.054
# Type 1 error: 0.09375 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.05
# --- The 97'th iteration take 0:00:31.660696 seconds ---
# The stat is 0.994
# Type 1 error: 0.09278350515463918 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041237113402061855 for z dimension 1 with significance level 0.05
# --- The 98'th iteration take 0:00:31.512939 seconds ---
# The stat is 0.563
# Type 1 error: 0.09183673469387756 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04081632653061224 for z dimension 1 with significance level 0.05
# --- The 99'th iteration take 0:00:31.694132 seconds ---
# The stat is 0.623
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04040404040404041 for z dimension 1 with significance level 0.05
# --- The 100'th iteration take 0:00:31.430968 seconds ---
# The stat is 0.334
# Type 1 error: 0.09 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# array([0.1  , 0.595, 0.458, 0.414, 0.81 , 0.973, 0.986, 0.743, 0.491,
#        0.624, 0.898, 0.271, 0.724, 0.134, 0.028, 0.498, 0.55 , 0.592,
#        0.638, 0.086, 0.303, 0.825, 0.373, 0.502, 0.298, 0.401, 0.503,
#        0.421, 0.487, 0.166, 0.557, 0.191, 0.704, 0.848, 0.183, 0.351,
#        0.89 , 0.157, 0.695, 0.817, 0.419, 0.256, 0.163, 0.277, 0.479,
#        0.757, 0.119, 0.43 , 0.137, 0.341, 0.975, 0.123, 0.89 , 0.982,
#        0.082, 0.755, 0.214, 0.483, 0.095, 0.409, 0.285, 0.642, 0.03 ,
#        0.152, 0.701, 0.825, 0.009, 0.4  , 0.979, 0.518, 0.277, 0.243,
#        0.065, 0.174, 0.915, 0.14 , 0.371, 0.835, 0.846, 0.616, 0.744,
#        0.325, 0.66 , 0.988, 0.133, 0.613, 0.621, 0.31 , 0.831, 0.39 ,
#        0.901, 0.301, 0.162, 0.004, 0.733, 0.054, 0.994, 0.563, 0.623,
#        0.334])

# %%
import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools


# =========================
# Device
# =========================
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


# =========================
# Parameters
# =========================
param = {
    "test": "type1error",
    "sample_size": 1000,
    "batch_size": 256,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 200,
    "eps_std": 0.5,
    "dist_z": 'gaussian',
    "alpha_x": 0.75,
    "m_value": 100,
    "k_value": 2,
    "j_value": 1000,
    "noise_dimension": 3,
    "hidden_layer_size": 20,
    "normal_ini": False,
    "preprocess": 'None',
    "G_lr": 1e-3,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 42,
    "using_oracle": False,
    "lambda_1": 1,
    "lambda_2": 0,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-5,
    "drop_out_p": 0.2,
    "M_train": 10,

    # 你的改进
    "lambda_mean": 0.5,
    "mean_samples": 20
}



# =========================
# Data generation: binary version
# =========================
def generate_samples_random(Ax, Ay, size=1000, sType='CI', dx=1, dy=1, dz=1,
                            nstd=0.05, alpha_x=0.05,
                            preprocess="None", dist_z='gaussian'):
    """
    Binary data generator aligned with the author's pasted code.

    Output:
        X, Y, Z are all binary {0,1} tensors.
    """
    if dx != 1 or dy != 1 or dz != 1:
        raise ValueError("This binary version currently supports dx=dy=dz=1 only.")

    num = size

    if sType in ['CI', 'H0', 'type1error']:
        numbers_z = np.random.multinomial(num, [0.5, 0.5], size=1)
        number_z_zeros = numbers_z[0][0]
        number_z_ones = numbers_z[0][1]

        xy_arr = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

        xy_z_zero_index = np.random.choice(
            a=len(xy_arr), size=number_z_zeros,
            p=[0.25, 0.25, 0.25, 0.25]
        )
        xy_z_one_index = np.random.choice(
            a=len(xy_arr), size=number_z_ones,
            p=[0.25, 0.25, 0.25, 0.25]
        )

        xy_z_zero = xy_arr[xy_z_zero_index]
        xy_z_one = xy_arr[xy_z_one_index]

        xy = np.concatenate((xy_z_zero, xy_z_one), axis=0)

        x = xy[:, 0]
        y = xy[:, 1]
        z = np.concatenate((np.zeros(number_z_zeros), np.ones(number_z_ones)), axis=0)

    elif sType in ['dependent', 'H1', 'power']:
        z = np.random.binomial(1, 0.5, size=num)
        y = np.random.binomial(1, 0.5, size=num)

        delta = np.random.binomial(1, alpha_x, size=num)
        x_indep = np.random.binomial(1, 0.5, size=num)

        x = (1 - delta) * x_indep + delta * y
        x = x.astype(int)

    else:
        raise ValueError("sType must be one of ['CI','H0','type1error','dependent','H1','power']")

    indices = np.random.permutation(num)
    x, y, z = x[indices], y[indices], z[indices]

    X = x.reshape(-1, 1).astype(np.float32)
    Y = y.reshape(-1, 1).astype(np.float32)
    Z = z.reshape(-1, 1).astype(np.float32)

    if preprocess == "normalize":
        pass
    elif preprocess == "scale_Z":
        pass
    elif preprocess == "None":
        pass
    else:
        raise ValueError("preprocess must be one of ['normalize', 'scale_Z', 'None']")

    X = torch.from_numpy(X).float()
    Y = torch.from_numpy(Y).float()
    Z = torch.from_numpy(Z).float()

    return X, Y, Z


# =========================
# Statistic computation
# =========================
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                       x_torch, y_torch, z_torch,
                       sigma_w, sigma_u=1, sigma_v=1,
                       boor_rv_type="gaussian"):
    """
    Compute test statistic and bootstrap samples.
    Shapes:
        gen_x_all_torch, gen_y_all_torch: (n, M)
        x_torch, y_torch: (n, 1)
        z_torch: (n, dz)
    """
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v
        ),
        dim=2
    )
    v_mx_3 = v_mx_2.T

    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
        dim=2
    )

    for i in range(1, M):
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
            dim=2
        )
        sum2_mx = sum2_mx + temp2_add_mx

    v_mx_4 = 1.0 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n, device=device))

    stat = 1.0 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])

    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num, device=device))
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num, device=device)
    else:
        raise ValueError("boor_rv_type must be 'rademacher' or 'gaussian'")

    for bb in range(boot_num):
        random_mx = torch.matmul(
            eboot[:, bb].reshape(-1, 1),
            eboot[:, bb].reshape(-1, 1).T
        )
        bootmatrix = FF_mx * random_mx
        stat_boot = 1.0 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)

    return stat, boottemp


# =========================
# Dataset
# =========================
class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (
            self.X_real[index],
            self.Y_real[index],
            self.Z_real[index],
            self.Z_real[(self.batch_size + index) % self.sample_size]
        )


# =========================
# Noise sampler
# =========================
def sample_noise(sample_size, noise_dimension, noise_type, input_var):
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),
            input_var * torch.eye(noise_dimension).to(device)
        )
        Z = noise_generator.sample((sample_size,))
    elif noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension, device=device)
    elif noise_type == "Cauchy":
        Z = TD.Cauchy(
            torch.tensor([0.0], device=device),
            torch.tensor([1.0], device=device)
        ).sample((sample_size, noise_dimension)).squeeze(2)
    else:
        raise ValueError("noise_type must be one of ['normal', 'unif', 'Cauchy']")
    return Z


# =========================
# Generator
# =========================
class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p,
                 drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.drop_input = drop_input

        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)

        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)

        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        if self.drop_input:
            x = self.drop_out0(x)

        if self.BN_type:
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
        else:
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))

        x = self.fc_last(x)

        # Binary probability output
        x = self.sigmoid(x)

        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias).to(device)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for _ in range(m)]
        ).to(device)

    def forward(self, x):
        self.linear.weight.data *= self.mask
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)

        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0]
        )

        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for _ in range(len(self.hidden_layer_sizes))
        ])

        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        self.sigmoid = torch.nn.Sigmoid()

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)

        output = self.linear8(output)
        output = self.sigmoid(output)
        return output


# =========================
# Loss
# =========================
def find_loss(y_torch, gen_y_all_torch, z_torch, sigma_w, sigma_u, M):
    n = z_torch.shape[0]

    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    FF_mx = u_mx * w_mx * (1 - torch.eye(n, device=device))
    loss = 1.0 / n * torch.sum(FF_mx)

    return loss


# =========================
# Binary sampling helper
# =========================
def sample_binary_from_prob(prob_tensor):
    prob_tensor = torch.clamp(prob_tensor, 1e-6, 1 - 1e-6)
    return torch.bernoulli(prob_tensor)


# =========================
# Training
# =========================
def train_ver3(X, Y, Z, X_test, Y_test, Z_test, M,
               noise_dimension, noise_type, G_lr, hidden_layer_size,
               DataLoader, BN_type, ReLU_coef,
               epochs_num=10, sigma_z=1, sigma_x=1, sigma_y=1,
               normal_ini=False,
               lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
               lambda_3=0, drop_out_p=0.2, M_train=3,
               lambda_mean=0.0, mean_samples=20):

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if using_Gen == '1':
        G_zy = Generator(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    elif using_Gen == '2':
        G_zy = Generator_2(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator_2(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    else:
        raise ValueError("using_Gen must be '1' or '2'")

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))

    for epoch in range(epochs_num):
        G_zy.train()
        G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)
            Y_real = Y_real.to(device)
            Z_real = Z_real.to(device)
            Z_fake = Z_fake.to(device)

            batch_size = Z_real.shape[0]

            # =========================
            # Train G_zy
            # =========================
            G_zy_solver.zero_grad()

            Z_real_repeat_y = Z_real.repeat(M_train, 1)
            Noise_fake_y = sample_noise(
                Z_real_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            Y_fake_prob = G_zy(torch.cat((Z_real_repeat_y, Noise_fake_y), dim=1)).to(device)
            Y_fake = Y_fake_prob.reshape(batch_size, M_train)

            l1_regularization_y = 0.0
            for param in G_zy.parameters():
                l1_regularization_y += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = lambda_1 * find_loss(
                Y_real, Y_fake, Z_real, sigma_z, sigma_y, M_train
            )

            if lambda_mean > 0:
                # 这里保留你的改进：对同一个 Z 做 Monte Carlo 均值近似
                Z_mean_repeat_y = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_y = sample_noise(
                    Z_mean_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                Y_mean_fake_group = G_zy(torch.cat((Z_mean_repeat_y, Noise_mean_y), dim=1))
                Y_mean_fake = Y_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_y).mean(dim=1)

                mean_loss_y = torch.nn.functional.mse_loss(Y_mean_fake, Y_real)
            else:
                mean_loss_y = 0.0

            g_zy_error = mmd_loss_y + lambda_mean * mean_loss_y + lambda_3 * l1_regularization_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            # =========================
            # Train G_zx
            # =========================
            G_zx_solver.zero_grad()

            Z_real_repeat_x = Z_real.repeat(M_train, 1)
            Noise_fake_x = sample_noise(
                Z_real_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            X_fake_prob = G_zx(torch.cat((Z_real_repeat_x, Noise_fake_x), dim=1)).to(device)
            X_fake = X_fake_prob.reshape(batch_size, M_train)

            l1_regularization_x = 0.0
            for param in G_zx.parameters():
                l1_regularization_x += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = lambda_1 * find_loss(
                X_real, X_fake, Z_real, sigma_z, sigma_x, M_train
            )

            if lambda_mean > 0:
                Z_mean_repeat_x = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_x = sample_noise(
                    Z_mean_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                X_mean_fake_group = G_zx(torch.cat((Z_mean_repeat_x, Noise_mean_x), dim=1))
                X_mean_fake = X_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_x).mean(dim=1)

                mean_loss_x = torch.nn.functional.mse_loss(X_mean_fake, X_real)
            else:
                mean_loss_x = 0.0

            g_zx_error = mmd_loss_x + lambda_mean * mean_loss_x + lambda_3 * l1_regularization_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

    return G_zy, G_zx

# =========================
# Main experiment for one run
# =========================
def mGAN(Ax, Ay, n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_oracle=False, lambda_1=1, lambda_2=1, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2, exp_num=0,
         M_train=3, lambda_mean=0.0, mean_samples=20):


    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='CI', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='dependent', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x, sim_y, sim_z

    sigma_w_train = 1.0
    sigma_u_train = 1.0
    sigma_v_train = 1.0

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))

        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]

        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))

        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_oracle:
            G_zy, G_zx = train_ver3(
    X=X_train, Y=Y_train, Z=Z_train, M=M,
    X_test=X_test, Y_test=Y_test, Z_test=Z_test,
    noise_dimension=noise_dimension, noise_type="normal",
    G_lr=G_lr, hidden_layer_size=hidden_layer_size,
    DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
    epochs_num=epochs_num, sigma_z=sigma_w_train, sigma_x=sigma_v_train,
    sigma_y=sigma_u_train, normal_ini=normal_ini, lambda_1=lambda_1,
    lambda_2=lambda_2, using_Gen=using_Gen, wgt_decay=wgt_decay,
    lambda_3=lambda_3, drop_out_p=drop_out_p, M_train=M_train,
    lambda_mean=lambda_mean, mean_samples=mean_samples
)


        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M)
        gen_y_all = torch.zeros(test_size, M)

        z_all = torch.zeros(test_size, z_dim)
        x_all = torch.zeros(test_size, x_dims)
        y_all = torch.zeros(test_size, y_dims)

        cur_itr = 0

        if using_oracle:
            for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                z_scalar = int(z_test.item())

                fake_x = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)
                fake_y = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)

                gen_x_all[cur_itr, :] = fake_x.reshape(-1)
                gen_y_all[cur_itr, :] = fake_y.reshape(-1)

                x_all[cur_itr, :] = x_test
                y_all[cur_itr, :] = y_test
                z_all[cur_itr, :] = z_test
                cur_itr += 1
        else:
            G_zx.eval()
            G_zy.eval()

            with torch.no_grad():
                for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                    z_test_temp = z_test.repeat(M, 1).to(device)

                    noise_x = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_x_prob = G_zx(torch.cat((z_test_temp, noise_x), dim=1))
                    fake_x = sample_binary_from_prob(fake_x_prob).reshape(1, -1)

                    noise_y = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_y_prob = G_zy(torch.cat((z_test_temp, noise_y), dim=1))
                    fake_y = sample_binary_from_prob(fake_y_prob).reshape(1, -1)

                    gen_x_all[cur_itr, :] = fake_x.detach().cpu().reshape(-1)
                    gen_y_all[cur_itr, :] = fake_y.detach().cpu().reshape(-1)
                    x_all[cur_itr, :] = x_test
                    y_all[cur_itr, :] = y_test
                    z_all[cur_itr, :] = z_test
                    cur_itr += 1

        gen_x_all = gen_x_all.to(device)
        gen_y_all = gen_y_all.to(device)

        z_all = Z_test.to(device)
        x_all = X_test.to(device)
        y_all = Y_test.to(device)

        sigma_w = 1.0
        sigma_u = 1.0
        sigma_v = 1.0

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type
        )

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp).float()
        cur_k += 1

    return np.mean(torch.mean(boot_temp_all, dim=0).cpu().numpy() > torch.mean(stat_all).item())


# =========================
# Repeated experiment
# =========================
def run_experiment(params):
    test = params["test"]
    sample_size = params["sample_size"]
    batch_size = params["batch_size"]
    z_dim = params["z_dim"]
    dx = params["dx"]
    dy = params["dy"]
    n_test = params["n_test"]
    epochs_num = params["epochs_num"]
    eps_std = params["eps_std"]
    dist_z = params["dist_z"]
    alpha_x = params["alpha_x"]
    m_value = params["m_value"]
    k_value = params["k_value"]
    j_value = params["j_value"]
    noise_dimension = params["noise_dimension"]
    hidden_layer_size = params["hidden_layer_size"]
    normal_ini = params["normal_ini"]
    preprocess = params["preprocess"]
    G_lr = params["G_lr"]
    alpha = params["alpha"]
    alpha1 = params["alpha1"]
    set_seeds = params["set_seeds"]
    using_oracle = params["using_oracle"]
    lambda_1 = params["lambda_1"]
    lambda_2 = params["lambda_2"]
    using_Gen = params["using_Gen"]
    boor_rv_type = params["boor_rv_type"]
    wgt_decay = params["wgt_decay"]
    lambda_3 = params["lambda_3"]
    drop_out_p = params["drop_out_p"]
    M_train = params["M_train"]
    lambda_mean = params["lambda_mean"]
    mean_samples = params["mean_samples"]


    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    a_f = torch.rand((z_dim, dx))
    l1_norm_a_f = torch.linalg.vector_norm(a_f, ord=1)
    Ax = a_f / l1_norm_a_f

    a_g = torch.rand((z_dim, dy))
    l1_norm_a_g = torch.linalg.vector_norm(a_g, ord=1)
    Ay = a_g / l1_norm_a_g

    p_values = np.array([])
    test_count = 0

    if test == 'type1error':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train, lambda_mean=lambda_mean, mean_samples=mean_samples
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))

    elif test == 'power':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))
    else:
        raise ValueError("test must be 'type1error' or 'power'")

    return p_values


# =========================
# Run
# =========================
run_experiment(param)
# Out:
# --- The 1'th iteration take 0:01:11.065839 seconds ---
# The stat is 0.442
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 2'th iteration take 0:01:07.929794 seconds ---
# The stat is 0.29
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 3'th iteration take 0:01:08.015763 seconds ---
# The stat is 0.683
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 4'th iteration take 0:01:08.366537 seconds ---
# The stat is 0.951
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 5'th iteration take 0:01:08.059607 seconds ---
# The stat is 0.193
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 6'th iteration take 0:01:10.752541 seconds ---
# The stat is 0.208
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 7'th iteration take 0:01:11.270327 seconds ---
# The stat is 0.159
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 8'th iteration take 0:01:08.517848 seconds ---
# The stat is 0.56
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 9'th iteration take 0:01:08.697659 seconds ---
# The stat is 0.001
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 10'th iteration take 0:01:05.786471 seconds ---
# The stat is 0.253
# Type 1 error: 0.1 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 11'th iteration take 0:01:10.420355 seconds ---
# The stat is 0.148
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 12'th iteration take 0:01:10.188463 seconds ---
# The stat is 0.838
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 13'th iteration take 0:01:10.470756 seconds ---
# The stat is 0.46
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 14'th iteration take 0:01:09.680283 seconds ---
# The stat is 0.563
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 15'th iteration take 0:01:08.021362 seconds ---
# The stat is 0.055
# Type 1 error: 0.13333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 16'th iteration take 0:01:10.574575 seconds ---
# The stat is 0.198
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 17'th iteration take 0:01:11.250670 seconds ---
# The stat is 0.729
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 18'th iteration take 0:01:08.548845 seconds ---
# The stat is 0.07
# Type 1 error: 0.16666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 19'th iteration take 0:01:10.995930 seconds ---
# The stat is 0.535
# Type 1 error: 0.15789473684210525 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.05
# --- The 20'th iteration take 0:01:03.051770 seconds ---
# The stat is 0.08
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# --- The 21'th iteration take 0:00:58.770293 seconds ---
# The stat is 0.095
# Type 1 error: 0.23809523809523808 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.05
# --- The 22'th iteration take 0:01:05.711834 seconds ---
# The stat is 0.788
# Type 1 error: 0.22727272727272727 for z dimension 1 with significance level 0.1
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.05
# --- The 23'th iteration take 0:01:07.779131 seconds ---
# The stat is 0.359
# Type 1 error: 0.21739130434782608 for z dimension 1 with significance level 0.1
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.05
# --- The 24'th iteration take 0:01:05.933973 seconds ---
# The stat is 0.584
# Type 1 error: 0.20833333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.05
# --- The 25'th iteration take 0:01:08.120109 seconds ---
# The stat is 0.063
# Type 1 error: 0.24 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# --- The 26'th iteration take 0:01:03.788236 seconds ---
# The stat is 0.469
# Type 1 error: 0.23076923076923078 for z dimension 1 with significance level 0.1
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.05
# --- The 27'th iteration take 0:01:05.963740 seconds ---
# The stat is 0.465
# Type 1 error: 0.2222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.05
# --- The 28'th iteration take 0:01:07.946166 seconds ---
# The stat is 0.031
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 29'th iteration take 0:01:05.452452 seconds ---
# The stat is 0.742
# Type 1 error: 0.2413793103448276 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.05
# --- The 30'th iteration take 0:01:05.860885 seconds ---
# The stat is 0.041
# Type 1 error: 0.26666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 31'th iteration take 0:01:08.463747 seconds ---
# The stat is 0.107
# Type 1 error: 0.25806451612903225 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0967741935483871 for z dimension 1 with significance level 0.05
# --- The 32'th iteration take 0:01:05.750045 seconds ---
# The stat is 0.007
# Type 1 error: 0.28125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.125 for z dimension 1 with significance level 0.05
# --- The 33'th iteration take 0:01:07.574646 seconds ---
# The stat is 0.882
# Type 1 error: 0.2727272727272727 for z dimension 1 with significance level 0.1
# Type 1 error: 0.12121212121212122 for z dimension 1 with significance level 0.05
# --- The 34'th iteration take 0:01:05.722034 seconds ---
# The stat is 0.504
# Type 1 error: 0.2647058823529412 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.05
# --- The 35'th iteration take 0:01:07.755440 seconds ---
# The stat is 0.954
# Type 1 error: 0.2571428571428571 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11428571428571428 for z dimension 1 with significance level 0.05
# --- The 36'th iteration take 0:01:08.511814 seconds ---
# The stat is 0.905
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 37'th iteration take 0:01:07.541466 seconds ---
# The stat is 0.909
# Type 1 error: 0.24324324324324326 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10810810810810811 for z dimension 1 with significance level 0.05
# --- The 38'th iteration take 0:01:03.482193 seconds ---
# The stat is 0.076
# Type 1 error: 0.2631578947368421 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10526315789473684 for z dimension 1 with significance level 0.05
# --- The 39'th iteration take 0:01:07.839002 seconds ---
# The stat is 0.889
# Type 1 error: 0.2564102564102564 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10256410256410256 for z dimension 1 with significance level 0.05
# --- The 40'th iteration take 0:01:00.936088 seconds ---
# The stat is 0.405
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 41'th iteration take 0:01:03.526676 seconds ---
# The stat is 0.28
# Type 1 error: 0.24390243902439024 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0975609756097561 for z dimension 1 with significance level 0.05
# --- The 42'th iteration take 0:01:08.046906 seconds ---
# The stat is 0.962
# Type 1 error: 0.23809523809523808 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09523809523809523 for z dimension 1 with significance level 0.05
# --- The 43'th iteration take 0:01:14.227601 seconds ---
# The stat is 0.754
# Type 1 error: 0.23255813953488372 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09302325581395349 for z dimension 1 with significance level 0.05
# --- The 44'th iteration take 0:01:14.866352 seconds ---
# The stat is 0.753
# Type 1 error: 0.22727272727272727 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 45'th iteration take 0:01:10.242788 seconds ---
# The stat is 0.204
# Type 1 error: 0.2222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08888888888888889 for z dimension 1 with significance level 0.05
# --- The 46'th iteration take 0:01:11.887443 seconds ---
# The stat is 0.288
# Type 1 error: 0.21739130434782608 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08695652173913043 for z dimension 1 with significance level 0.05
# --- The 47'th iteration take 0:01:14.631504 seconds ---
# The stat is 0.864
# Type 1 error: 0.2127659574468085 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0851063829787234 for z dimension 1 with significance level 0.05
# --- The 48'th iteration take 0:01:13.213497 seconds ---
# The stat is 0.538
# Type 1 error: 0.20833333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 49'th iteration take 0:01:11.591949 seconds ---
# The stat is 0.781
# Type 1 error: 0.20408163265306123 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08163265306122448 for z dimension 1 with significance level 0.05
# --- The 50'th iteration take 0:01:07.604792 seconds ---
# The stat is 0.024
# Type 1 error: 0.22 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 51'th iteration take 0:01:08.116710 seconds ---
# The stat is 0.848
# Type 1 error: 0.21568627450980393 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09803921568627451 for z dimension 1 with significance level 0.05
# --- The 52'th iteration take 0:01:08.271025 seconds ---
# The stat is 0.75
# Type 1 error: 0.21153846153846154 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09615384615384616 for z dimension 1 with significance level 0.05
# --- The 53'th iteration take 0:01:08.168658 seconds ---
# The stat is 0.147
# Type 1 error: 0.20754716981132076 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09433962264150944 for z dimension 1 with significance level 0.05
# --- The 54'th iteration take 0:01:08.091092 seconds ---
# The stat is 0.062
# Type 1 error: 0.2222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09259259259259259 for z dimension 1 with significance level 0.05
# --- The 55'th iteration take 0:01:08.075159 seconds ---
# The stat is 0.599
# Type 1 error: 0.21818181818181817 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 56'th iteration take 0:01:07.806215 seconds ---
# The stat is 0.183
# Type 1 error: 0.21428571428571427 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08928571428571429 for z dimension 1 with significance level 0.05
# --- The 57'th iteration take 0:01:06.169115 seconds ---
# The stat is 0.672
# Type 1 error: 0.21052631578947367 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08771929824561403 for z dimension 1 with significance level 0.05
# --- The 58'th iteration take 0:01:08.351770 seconds ---
# The stat is 0.764
# Type 1 error: 0.20689655172413793 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08620689655172414 for z dimension 1 with significance level 0.05
# --- The 59'th iteration take 0:01:06.116751 seconds ---
# The stat is 0.57
# Type 1 error: 0.2033898305084746 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0847457627118644 for z dimension 1 with significance level 0.05
# --- The 60'th iteration take 0:01:07.867363 seconds ---
# The stat is 0.905
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 61'th iteration take 0:01:08.740394 seconds ---
# The stat is 0.385
# Type 1 error: 0.19672131147540983 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08196721311475409 for z dimension 1 with significance level 0.05
# --- The 62'th iteration take 0:01:06.071127 seconds ---
# The stat is 0.95
# Type 1 error: 0.1935483870967742 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08064516129032258 for z dimension 1 with significance level 0.05
# --- The 63'th iteration take 0:01:05.987032 seconds ---
# The stat is 0.129
# Type 1 error: 0.19047619047619047 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07936507936507936 for z dimension 1 with significance level 0.05
# --- The 64'th iteration take 0:01:08.562379 seconds ---
# The stat is 0.331
# Type 1 error: 0.1875 for z dimension 1 with significance level 0.1
# Type 1 error: 0.078125 for z dimension 1 with significance level 0.05
# --- The 65'th iteration take 0:01:08.136138 seconds ---
# The stat is 0.104
# Type 1 error: 0.18461538461538463 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 66'th iteration take 0:01:08.533116 seconds ---
# The stat is 0.792
# Type 1 error: 0.18181818181818182 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07575757575757576 for z dimension 1 with significance level 0.05
# --- The 67'th iteration take 0:01:05.988086 seconds ---
# The stat is 0.08
# Type 1 error: 0.19402985074626866 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07462686567164178 for z dimension 1 with significance level 0.05
# --- The 68'th iteration take 0:01:08.299817 seconds ---
# The stat is 0.548
# Type 1 error: 0.19117647058823528 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07352941176470588 for z dimension 1 with significance level 0.05
# --- The 69'th iteration take 0:01:08.390470 seconds ---
# The stat is 0.581
# Type 1 error: 0.18840579710144928 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07246376811594203 for z dimension 1 with significance level 0.05
# --- The 70'th iteration take 0:01:05.914633 seconds ---
# The stat is 0.138
# Type 1 error: 0.18571428571428572 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 71'th iteration take 0:01:08.358600 seconds ---
# The stat is 0.199
# Type 1 error: 0.18309859154929578 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07042253521126761 for z dimension 1 with significance level 0.05
# --- The 72'th iteration take 0:01:08.349929 seconds ---
# The stat is 0.922
# Type 1 error: 0.18055555555555555 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06944444444444445 for z dimension 1 with significance level 0.05
# --- The 73'th iteration take 0:01:03.814619 seconds ---
# The stat is 0.61
# Type 1 error: 0.1780821917808219 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0684931506849315 for z dimension 1 with significance level 0.05
# --- The 74'th iteration take 0:00:59.026223 seconds ---
# The stat is 0.254
# Type 1 error: 0.17567567567567569 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06756756756756757 for z dimension 1 with significance level 0.05
# --- The 75'th iteration take 0:00:59.163965 seconds ---
# The stat is 0.701
# Type 1 error: 0.17333333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 76'th iteration take 0:00:59.228953 seconds ---
# The stat is 0.93
# Type 1 error: 0.17105263157894737 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06578947368421052 for z dimension 1 with significance level 0.05
# --- The 77'th iteration take 0:00:58.437271 seconds ---
# The stat is 0.407
# Type 1 error: 0.16883116883116883 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06493506493506493 for z dimension 1 with significance level 0.05
# --- The 78'th iteration take 0:00:59.133447 seconds ---
# The stat is 0.538
# Type 1 error: 0.16666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0641025641025641 for z dimension 1 with significance level 0.05
# --- The 79'th iteration take 0:00:59.376951 seconds ---
# The stat is 0.313
# Type 1 error: 0.16455696202531644 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06329113924050633 for z dimension 1 with significance level 0.05
# --- The 80'th iteration take 0:00:58.313411 seconds ---
# The stat is 0.601
# Type 1 error: 0.1625 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 81'th iteration take 0:00:59.335398 seconds ---
# The stat is 0.064
# Type 1 error: 0.1728395061728395 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06172839506172839 for z dimension 1 with significance level 0.05
# --- The 82'th iteration take 0:00:59.530228 seconds ---
# The stat is 0.767
# Type 1 error: 0.17073170731707318 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06097560975609756 for z dimension 1 with significance level 0.05
# --- The 83'th iteration take 0:00:58.690242 seconds ---
# The stat is 0.697
# Type 1 error: 0.1686746987951807 for z dimension 1 with significance level 0.1
# Type 1 error: 0.060240963855421686 for z dimension 1 with significance level 0.05
# --- The 84'th iteration take 0:00:59.017094 seconds ---
# The stat is 0.244
# Type 1 error: 0.16666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05952380952380952 for z dimension 1 with significance level 0.05
# --- The 85'th iteration take 0:00:59.190273 seconds ---
# The stat is 0.606
# Type 1 error: 0.16470588235294117 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 86'th iteration take 0:00:58.999637 seconds ---
# The stat is 0.365
# Type 1 error: 0.16279069767441862 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05813953488372093 for z dimension 1 with significance level 0.05
# --- The 87'th iteration take 0:00:59.283733 seconds ---
# The stat is 0.801
# Type 1 error: 0.16091954022988506 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05747126436781609 for z dimension 1 with significance level 0.05
# --- The 88'th iteration take 0:00:58.515373 seconds ---
# The stat is 0.82
# Type 1 error: 0.1590909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.056818181818181816 for z dimension 1 with significance level 0.05
# --- The 89'th iteration take 0:00:59.004209 seconds ---
# The stat is 0.328
# Type 1 error: 0.15730337078651685 for z dimension 1 with significance level 0.1
# Type 1 error: 0.056179775280898875 for z dimension 1 with significance level 0.05
# --- The 90'th iteration take 0:00:58.642978 seconds ---
# The stat is 0.789
# Type 1 error: 0.15555555555555556 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 91'th iteration take 0:00:58.075518 seconds ---
# The stat is 0.001
# Type 1 error: 0.16483516483516483 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06593406593406594 for z dimension 1 with significance level 0.05
# --- The 92'th iteration take 0:00:58.110071 seconds ---
# The stat is 0.306
# Type 1 error: 0.16304347826086957 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06521739130434782 for z dimension 1 with significance level 0.05
# --- The 93'th iteration take 0:00:59.135689 seconds ---
# The stat is 0.488
# Type 1 error: 0.16129032258064516 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.05
# --- The 94'th iteration take 0:00:58.872259 seconds ---
# The stat is 0.179
# Type 1 error: 0.1595744680851064 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06382978723404255 for z dimension 1 with significance level 0.05
# --- The 95'th iteration take 0:00:58.614631 seconds ---
# The stat is 0.13
# Type 1 error: 0.15789473684210525 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06315789473684211 for z dimension 1 with significance level 0.05
# --- The 96'th iteration take 0:00:58.851389 seconds ---
# The stat is 0.734
# Type 1 error: 0.15625 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 97'th iteration take 0:00:59.218839 seconds ---
# The stat is 0.325
# Type 1 error: 0.15463917525773196 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061855670103092786 for z dimension 1 with significance level 0.05
# --- The 98'th iteration take 0:00:59.501491 seconds ---
# The stat is 0.847
# Type 1 error: 0.15306122448979592 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061224489795918366 for z dimension 1 with significance level 0.05
# --- The 99'th iteration take 0:01:01.210210 seconds ---
# The stat is 0.646
# Type 1 error: 0.15151515151515152 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06060606060606061 for z dimension 1 with significance level 0.05
# --- The 100'th iteration take 0:01:00.609030 seconds ---
# The stat is 0.172
# Type 1 error: 0.15 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06 for z dimension 1 with significance level 0.05
# array([0.442, 0.29 , 0.683, 0.951, 0.193, 0.208, 0.159, 0.56 , 0.001,
#        0.253, 0.148, 0.838, 0.46 , 0.563, 0.055, 0.198, 0.729, 0.07 ,
#        0.535, 0.08 , 0.095, 0.788, 0.359, 0.584, 0.063, 0.469, 0.465,
#        0.031, 0.742, 0.041, 0.107, 0.007, 0.882, 0.504, 0.954, 0.905,
#        0.909, 0.076, 0.889, 0.405, 0.28 , 0.962, 0.754, 0.753, 0.204,
#        0.288, 0.864, 0.538, 0.781, 0.024, 0.848, 0.75 , 0.147, 0.062,
#        0.599, 0.183, 0.672, 0.764, 0.57 , 0.905, 0.385, 0.95 , 0.129,
#        0.331, 0.104, 0.792, 0.08 , 0.548, 0.581, 0.138, 0.199, 0.922,
#        0.61 , 0.254, 0.701, 0.93 , 0.407, 0.538, 0.313, 0.601, 0.064,
#        0.767, 0.697, 0.244, 0.606, 0.365, 0.801, 0.82 , 0.328, 0.789,
#        0.001, 0.306, 0.488, 0.179, 0.13 , 0.734, 0.325, 0.847, 0.646,
#        0.172])
