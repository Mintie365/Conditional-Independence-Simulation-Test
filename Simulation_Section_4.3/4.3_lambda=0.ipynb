# %%
import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools


# =========================
# Device
# =========================
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


# =========================
# Parameters
# =========================
param = {
    "test": "type1error",
    "sample_size": 200,
    "batch_size": 128,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 200,
    "eps_std": 0.5,
    "dist_z": 'gaussian',
    "alpha_x": 0.75,
    "m_value": 100,
    "k_value": 2,
    "j_value": 1000,
    "noise_dimension": 3,
    "hidden_layer_size": 20,
    "normal_ini": False,
    "preprocess": 'None',
    "G_lr": 1e-3,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 42,
    "using_oracle": False,
    "lambda_1": 1,
    "lambda_2": 0,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-5,
    "drop_out_p": 0.2,
    "M_train": 10,

    "lambda_mean": 0.0,
    "mean_samples": 20
}



# =========================
# Data generation: binary version
# =========================
def generate_samples_random(Ax, Ay, size=1000, sType='CI', dx=1, dy=1, dz=1,
                            nstd=0.05, alpha_x=0.05,
                            preprocess="None", dist_z='gaussian'):
    """
    Binary data generator aligned with the author's pasted code.

    Output:
        X, Y, Z are all binary {0,1} tensors.
    """
    if dx != 1 or dy != 1 or dz != 1:
        raise ValueError("This binary version currently supports dx=dy=dz=1 only.")

    num = size

    if sType in ['CI', 'H0', 'type1error']:
        numbers_z = np.random.multinomial(num, [0.5, 0.5], size=1)
        number_z_zeros = numbers_z[0][0]
        number_z_ones = numbers_z[0][1]

        xy_arr = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

        xy_z_zero_index = np.random.choice(
            a=len(xy_arr), size=number_z_zeros,
            p=[0.25, 0.25, 0.25, 0.25]
        )
        xy_z_one_index = np.random.choice(
            a=len(xy_arr), size=number_z_ones,
            p=[0.25, 0.25, 0.25, 0.25]
        )

        xy_z_zero = xy_arr[xy_z_zero_index]
        xy_z_one = xy_arr[xy_z_one_index]

        xy = np.concatenate((xy_z_zero, xy_z_one), axis=0)

        x = xy[:, 0]
        y = xy[:, 1]
        z = np.concatenate((np.zeros(number_z_zeros), np.ones(number_z_ones)), axis=0)

    elif sType in ['dependent', 'H1', 'power']:
        z = np.random.binomial(1, 0.5, size=num)
        y = np.random.binomial(1, 0.5, size=num)

        delta = np.random.binomial(1, alpha_x, size=num)
        x_indep = np.random.binomial(1, 0.5, size=num)

        x = (1 - delta) * x_indep + delta * y
        x = x.astype(int)

    else:
        raise ValueError("sType must be one of ['CI','H0','type1error','dependent','H1','power']")

    indices = np.random.permutation(num)
    x, y, z = x[indices], y[indices], z[indices]

    X = x.reshape(-1, 1).astype(np.float32)
    Y = y.reshape(-1, 1).astype(np.float32)
    Z = z.reshape(-1, 1).astype(np.float32)

    if preprocess == "normalize":
        pass
    elif preprocess == "scale_Z":
        pass
    elif preprocess == "None":
        pass
    else:
        raise ValueError("preprocess must be one of ['normalize', 'scale_Z', 'None']")

    X = torch.from_numpy(X).float()
    Y = torch.from_numpy(Y).float()
    Z = torch.from_numpy(Z).float()

    return X, Y, Z


# =========================
# Statistic computation
# =========================
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                       x_torch, y_torch, z_torch,
                       sigma_w, sigma_u=1, sigma_v=1,
                       boor_rv_type="gaussian"):
    """
    Compute test statistic and bootstrap samples.
    Shapes:
        gen_x_all_torch, gen_y_all_torch: (n, M)
        x_torch, y_torch: (n, 1)
        z_torch: (n, dz)
    """
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v
        ),
        dim=2
    )
    v_mx_3 = v_mx_2.T

    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
        dim=2
    )

    for i in range(1, M):
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
            dim=2
        )
        sum2_mx = sum2_mx + temp2_add_mx

    v_mx_4 = 1.0 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n, device=device))

    stat = 1.0 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])

    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num, device=device))
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num, device=device)
    else:
        raise ValueError("boor_rv_type must be 'rademacher' or 'gaussian'")

    for bb in range(boot_num):
        random_mx = torch.matmul(
            eboot[:, bb].reshape(-1, 1),
            eboot[:, bb].reshape(-1, 1).T
        )
        bootmatrix = FF_mx * random_mx
        stat_boot = 1.0 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)

    return stat, boottemp


# =========================
# Dataset
# =========================
class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (
            self.X_real[index],
            self.Y_real[index],
            self.Z_real[index],
            self.Z_real[(self.batch_size + index) % self.sample_size]
        )


# =========================
# Noise sampler
# =========================
def sample_noise(sample_size, noise_dimension, noise_type, input_var):
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),
            input_var * torch.eye(noise_dimension).to(device)
        )
        Z = noise_generator.sample((sample_size,))
    elif noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension, device=device)
    elif noise_type == "Cauchy":
        Z = TD.Cauchy(
            torch.tensor([0.0], device=device),
            torch.tensor([1.0], device=device)
        ).sample((sample_size, noise_dimension)).squeeze(2)
    else:
        raise ValueError("noise_type must be one of ['normal', 'unif', 'Cauchy']")
    return Z


# =========================
# Generator
# =========================
class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p,
                 drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.drop_input = drop_input

        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)

        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)

        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        if self.drop_input:
            x = self.drop_out0(x)

        if self.BN_type:
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
        else:
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))

        x = self.fc_last(x)

        # Binary probability output
        x = self.sigmoid(x)

        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias).to(device)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for _ in range(m)]
        ).to(device)

    def forward(self, x):
        self.linear.weight.data *= self.mask
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)

        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0]
        )

        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for _ in range(len(self.hidden_layer_sizes))
        ])

        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        self.sigmoid = torch.nn.Sigmoid()

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)

        output = self.linear8(output)
        output = self.sigmoid(output)
        return output


# =========================
# Loss
# =========================
def find_loss(y_torch, gen_y_all_torch, z_torch, sigma_w, sigma_u, M):
    n = z_torch.shape[0]

    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    FF_mx = u_mx * w_mx * (1 - torch.eye(n, device=device))
    loss = 1.0 / n * torch.sum(FF_mx)

    return loss


# =========================
# Binary sampling helper
# =========================
def sample_binary_from_prob(prob_tensor):
    prob_tensor = torch.clamp(prob_tensor, 1e-6, 1 - 1e-6)
    return torch.bernoulli(prob_tensor)


# =========================
# Training
# =========================
def train_ver3(X, Y, Z, X_test, Y_test, Z_test, M,
               noise_dimension, noise_type, G_lr, hidden_layer_size,
               DataLoader, BN_type, ReLU_coef,
               epochs_num=10, sigma_z=1, sigma_x=1, sigma_y=1,
               normal_ini=False,
               lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
               lambda_3=0, drop_out_p=0.2, M_train=3,
               lambda_mean=0.0, mean_samples=20):

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if using_Gen == '1':
        G_zy = Generator(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    elif using_Gen == '2':
        G_zy = Generator_2(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator_2(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    else:
        raise ValueError("using_Gen must be '1' or '2'")

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))

    for epoch in range(epochs_num):
        G_zy.train()
        G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)
            Y_real = Y_real.to(device)
            Z_real = Z_real.to(device)
            Z_fake = Z_fake.to(device)

            batch_size = Z_real.shape[0]

            # =========================
            # Train G_zy
            # =========================
            G_zy_solver.zero_grad()

            Z_real_repeat_y = Z_real.repeat(M_train, 1)
            Noise_fake_y = sample_noise(
                Z_real_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            Y_fake_prob = G_zy(torch.cat((Z_real_repeat_y, Noise_fake_y), dim=1)).to(device)
            Y_fake = Y_fake_prob.reshape(batch_size, M_train)

            l1_regularization_y = 0.0
            for param in G_zy.parameters():
                l1_regularization_y += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = lambda_1 * find_loss(
                Y_real, Y_fake, Z_real, sigma_z, sigma_y, M_train
            )

            if lambda_mean > 0:
                # 这里保留你的改进：对同一个 Z 做 Monte Carlo 均值近似
                Z_mean_repeat_y = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_y = sample_noise(
                    Z_mean_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                Y_mean_fake_group = G_zy(torch.cat((Z_mean_repeat_y, Noise_mean_y), dim=1))
                Y_mean_fake = Y_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_y).mean(dim=1)

                mean_loss_y = torch.nn.functional.mse_loss(Y_mean_fake, Y_real)
            else:
                mean_loss_y = 0.0

            g_zy_error = mmd_loss_y + lambda_mean * mean_loss_y + lambda_3 * l1_regularization_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            # =========================
            # Train G_zx
            # =========================
            G_zx_solver.zero_grad()

            Z_real_repeat_x = Z_real.repeat(M_train, 1)
            Noise_fake_x = sample_noise(
                Z_real_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            X_fake_prob = G_zx(torch.cat((Z_real_repeat_x, Noise_fake_x), dim=1)).to(device)
            X_fake = X_fake_prob.reshape(batch_size, M_train)

            l1_regularization_x = 0.0
            for param in G_zx.parameters():
                l1_regularization_x += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = lambda_1 * find_loss(
                X_real, X_fake, Z_real, sigma_z, sigma_x, M_train
            )

            if lambda_mean > 0:
                Z_mean_repeat_x = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_x = sample_noise(
                    Z_mean_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                X_mean_fake_group = G_zx(torch.cat((Z_mean_repeat_x, Noise_mean_x), dim=1))
                X_mean_fake = X_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_x).mean(dim=1)

                mean_loss_x = torch.nn.functional.mse_loss(X_mean_fake, X_real)
            else:
                mean_loss_x = 0.0

            g_zx_error = mmd_loss_x + lambda_mean * mean_loss_x + lambda_3 * l1_regularization_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

    return G_zy, G_zx

# =========================
# Main experiment for one run
# =========================
def mGAN(Ax, Ay, n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_oracle=False, lambda_1=1, lambda_2=1, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2, exp_num=0,
         M_train=3, lambda_mean=0.0, mean_samples=20):


    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='CI', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='dependent', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x, sim_y, sim_z

    sigma_w_train = 1.0
    sigma_u_train = 1.0
    sigma_v_train = 1.0

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))

        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]

        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))

        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_oracle:
            G_zy, G_zx = train_ver3(
    X=X_train, Y=Y_train, Z=Z_train, M=M,
    X_test=X_test, Y_test=Y_test, Z_test=Z_test,
    noise_dimension=noise_dimension, noise_type="normal",
    G_lr=G_lr, hidden_layer_size=hidden_layer_size,
    DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
    epochs_num=epochs_num, sigma_z=sigma_w_train, sigma_x=sigma_v_train,
    sigma_y=sigma_u_train, normal_ini=normal_ini, lambda_1=lambda_1,
    lambda_2=lambda_2, using_Gen=using_Gen, wgt_decay=wgt_decay,
    lambda_3=lambda_3, drop_out_p=drop_out_p, M_train=M_train,
    lambda_mean=lambda_mean, mean_samples=mean_samples
)


        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M)
        gen_y_all = torch.zeros(test_size, M)

        z_all = torch.zeros(test_size, z_dim)
        x_all = torch.zeros(test_size, x_dims)
        y_all = torch.zeros(test_size, y_dims)

        cur_itr = 0

        if using_oracle:
            for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                z_scalar = int(z_test.item())

                fake_x = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)
                fake_y = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)

                gen_x_all[cur_itr, :] = fake_x.reshape(-1)
                gen_y_all[cur_itr, :] = fake_y.reshape(-1)

                x_all[cur_itr, :] = x_test
                y_all[cur_itr, :] = y_test
                z_all[cur_itr, :] = z_test
                cur_itr += 1
        else:
            G_zx.eval()
            G_zy.eval()

            with torch.no_grad():
                for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                    z_test_temp = z_test.repeat(M, 1).to(device)

                    noise_x = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_x_prob = G_zx(torch.cat((z_test_temp, noise_x), dim=1))
                    fake_x = sample_binary_from_prob(fake_x_prob).reshape(1, -1)

                    noise_y = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_y_prob = G_zy(torch.cat((z_test_temp, noise_y), dim=1))
                    fake_y = sample_binary_from_prob(fake_y_prob).reshape(1, -1)

                    gen_x_all[cur_itr, :] = fake_x.detach().cpu().reshape(-1)
                    gen_y_all[cur_itr, :] = fake_y.detach().cpu().reshape(-1)
                    x_all[cur_itr, :] = x_test
                    y_all[cur_itr, :] = y_test
                    z_all[cur_itr, :] = z_test
                    cur_itr += 1

        gen_x_all = gen_x_all.to(device)
        gen_y_all = gen_y_all.to(device)

        z_all = Z_test.to(device)
        x_all = X_test.to(device)
        y_all = Y_test.to(device)

        sigma_w = 1.0
        sigma_u = 1.0
        sigma_v = 1.0

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type
        )

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp).float()
        cur_k += 1

    return np.mean(torch.mean(boot_temp_all, dim=0).cpu().numpy() > torch.mean(stat_all).item())


# =========================
# Repeated experiment
# =========================
def run_experiment(params):
    test = params["test"]
    sample_size = params["sample_size"]
    batch_size = params["batch_size"]
    z_dim = params["z_dim"]
    dx = params["dx"]
    dy = params["dy"]
    n_test = params["n_test"]
    epochs_num = params["epochs_num"]
    eps_std = params["eps_std"]
    dist_z = params["dist_z"]
    alpha_x = params["alpha_x"]
    m_value = params["m_value"]
    k_value = params["k_value"]
    j_value = params["j_value"]
    noise_dimension = params["noise_dimension"]
    hidden_layer_size = params["hidden_layer_size"]
    normal_ini = params["normal_ini"]
    preprocess = params["preprocess"]
    G_lr = params["G_lr"]
    alpha = params["alpha"]
    alpha1 = params["alpha1"]
    set_seeds = params["set_seeds"]
    using_oracle = params["using_oracle"]
    lambda_1 = params["lambda_1"]
    lambda_2 = params["lambda_2"]
    using_Gen = params["using_Gen"]
    boor_rv_type = params["boor_rv_type"]
    wgt_decay = params["wgt_decay"]
    lambda_3 = params["lambda_3"]
    drop_out_p = params["drop_out_p"]
    M_train = params["M_train"]
    lambda_mean = params["lambda_mean"]
    mean_samples = params["mean_samples"]


    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    a_f = torch.rand((z_dim, dx))
    l1_norm_a_f = torch.linalg.vector_norm(a_f, ord=1)
    Ax = a_f / l1_norm_a_f

    a_g = torch.rand((z_dim, dy))
    l1_norm_a_g = torch.linalg.vector_norm(a_g, ord=1)
    Ay = a_g / l1_norm_a_g

    p_values = np.array([])
    test_count = 0

    if test == 'type1error':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train, lambda_mean=lambda_mean, mean_samples=mean_samples
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))

    elif test == 'power':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))
    else:
        raise ValueError("test must be 'type1error' or 'power'")

    return p_values


# =========================
# Run
# =========================
run_experiment(param)
# Out:
# --- The 1'th iteration take 0:00:06.325131 seconds ---
# The stat is 0.785
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 2'th iteration take 0:00:05.655083 seconds ---
# The stat is 0.243
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 3'th iteration take 0:00:05.657069 seconds ---
# The stat is 0.776
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 4'th iteration take 0:00:05.656538 seconds ---
# The stat is 0.34
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 5'th iteration take 0:00:05.704612 seconds ---
# The stat is 0.795
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 6'th iteration take 0:00:05.719342 seconds ---
# The stat is 0.832
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 7'th iteration take 0:00:05.731745 seconds ---
# The stat is 0.69
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 8'th iteration take 0:00:06.213878 seconds ---
# The stat is 0.88
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 9'th iteration take 0:00:05.789032 seconds ---
# The stat is 0.288
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 10'th iteration take 0:00:05.735462 seconds ---
# The stat is 0.249
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 11'th iteration take 0:00:05.711700 seconds ---
# The stat is 0.366
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 12'th iteration take 0:00:05.710010 seconds ---
# The stat is 0.599
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 13'th iteration take 0:00:05.702193 seconds ---
# The stat is 0.904
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 14'th iteration take 0:00:05.747948 seconds ---
# The stat is 0.217
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 15'th iteration take 0:00:05.705471 seconds ---
# The stat is 0.883
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 16'th iteration take 0:00:05.745515 seconds ---
# The stat is 0.965
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 17'th iteration take 0:00:05.816979 seconds ---
# The stat is 0.688
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 18'th iteration take 0:00:05.739024 seconds ---
# The stat is 0.589
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 19'th iteration take 0:00:05.769382 seconds ---
# The stat is 0.372
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 20'th iteration take 0:00:05.738504 seconds ---
# The stat is 0.981
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 21'th iteration take 0:00:05.747434 seconds ---
# The stat is 0.913
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 22'th iteration take 0:00:05.798533 seconds ---
# The stat is 0.52
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 23'th iteration take 0:00:05.713621 seconds ---
# The stat is 0.937
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 24'th iteration take 0:00:05.778043 seconds ---
# The stat is 0.626
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 25'th iteration take 0:00:05.788178 seconds ---
# The stat is 0.055
# Type 1 error: 0.04 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 26'th iteration take 0:00:05.719525 seconds ---
# The stat is 0.445
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 27'th iteration take 0:00:05.735062 seconds ---
# The stat is 0.033
# Type 1 error: 0.07407407407407407 for z dimension 1 with significance level 0.1
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.05
# --- The 28'th iteration take 0:00:05.717631 seconds ---
# The stat is 0.968
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03571428571428571 for z dimension 1 with significance level 0.05
# --- The 29'th iteration take 0:00:05.713893 seconds ---
# The stat is 0.732
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.1
# Type 1 error: 0.034482758620689655 for z dimension 1 with significance level 0.05
# --- The 30'th iteration take 0:00:07.817782 seconds ---
# The stat is 0.048
# Type 1 error: 0.1 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 31'th iteration take 0:00:05.780167 seconds ---
# The stat is 0.092
# Type 1 error: 0.12903225806451613 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.05
# --- The 32'th iteration take 0:00:05.751246 seconds ---
# The stat is 0.866
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 33'th iteration take 0:00:06.047266 seconds ---
# The stat is 0.402
# Type 1 error: 0.12121212121212122 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06060606060606061 for z dimension 1 with significance level 0.05
# --- The 34'th iteration take 0:00:05.786816 seconds ---
# The stat is 0.943
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 35'th iteration take 0:00:06.949881 seconds ---
# The stat is 0.013
# Type 1 error: 0.14285714285714285 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08571428571428572 for z dimension 1 with significance level 0.05
# --- The 36'th iteration take 0:00:08.032065 seconds ---
# The stat is 0.95
# Type 1 error: 0.1388888888888889 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 37'th iteration take 0:00:05.611933 seconds ---
# The stat is 0.008
# Type 1 error: 0.16216216216216217 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10810810810810811 for z dimension 1 with significance level 0.05
# --- The 38'th iteration take 0:00:05.629261 seconds ---
# The stat is 0.665
# Type 1 error: 0.15789473684210525 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10526315789473684 for z dimension 1 with significance level 0.05
# --- The 39'th iteration take 0:00:05.641587 seconds ---
# The stat is 0.294
# Type 1 error: 0.15384615384615385 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10256410256410256 for z dimension 1 with significance level 0.05
# --- The 40'th iteration take 0:00:05.615043 seconds ---
# The stat is 0.969
# Type 1 error: 0.15 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 41'th iteration take 0:00:05.653394 seconds ---
# The stat is 0.521
# Type 1 error: 0.14634146341463414 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0975609756097561 for z dimension 1 with significance level 0.05
# --- The 42'th iteration take 0:00:05.611174 seconds ---
# The stat is 0.018
# Type 1 error: 0.16666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11904761904761904 for z dimension 1 with significance level 0.05
# --- The 43'th iteration take 0:00:05.761887 seconds ---
# The stat is 0.76
# Type 1 error: 0.16279069767441862 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11627906976744186 for z dimension 1 with significance level 0.05
# --- The 44'th iteration take 0:00:05.982471 seconds ---
# The stat is 0.269
# Type 1 error: 0.1590909090909091 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11363636363636363 for z dimension 1 with significance level 0.05
# --- The 45'th iteration take 0:00:06.325800 seconds ---
# The stat is 0.458
# Type 1 error: 0.15555555555555556 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 46'th iteration take 0:00:05.528182 seconds ---
# The stat is 0.534
# Type 1 error: 0.15217391304347827 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10869565217391304 for z dimension 1 with significance level 0.05
# --- The 47'th iteration take 0:00:05.540378 seconds ---
# The stat is 0.35
# Type 1 error: 0.14893617021276595 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10638297872340426 for z dimension 1 with significance level 0.05
# --- The 48'th iteration take 0:00:05.602440 seconds ---
# The stat is 0.767
# Type 1 error: 0.14583333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10416666666666667 for z dimension 1 with significance level 0.05
# --- The 49'th iteration take 0:00:05.581568 seconds ---
# The stat is 0.659
# Type 1 error: 0.14285714285714285 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10204081632653061 for z dimension 1 with significance level 0.05
# --- The 50'th iteration take 0:00:05.552597 seconds ---
# The stat is 0.978
# Type 1 error: 0.14 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 51'th iteration take 0:00:05.546275 seconds ---
# The stat is 0.027
# Type 1 error: 0.1568627450980392 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.05
# --- The 52'th iteration take 0:00:05.613905 seconds ---
# The stat is 0.208
# Type 1 error: 0.15384615384615385 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11538461538461539 for z dimension 1 with significance level 0.05
# --- The 53'th iteration take 0:00:05.712257 seconds ---
# The stat is 0.867
# Type 1 error: 0.1509433962264151 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11320754716981132 for z dimension 1 with significance level 0.05
# --- The 54'th iteration take 0:00:05.610991 seconds ---
# The stat is 0.962
# Type 1 error: 0.14814814814814814 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 55'th iteration take 0:00:05.594265 seconds ---
# The stat is 0.134
# Type 1 error: 0.14545454545454545 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10909090909090909 for z dimension 1 with significance level 0.05
# --- The 56'th iteration take 0:00:05.582670 seconds ---
# The stat is 0.584
# Type 1 error: 0.14285714285714285 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10714285714285714 for z dimension 1 with significance level 0.05
# --- The 57'th iteration take 0:00:05.660524 seconds ---
# The stat is 0.195
# Type 1 error: 0.14035087719298245 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10526315789473684 for z dimension 1 with significance level 0.05
# --- The 58'th iteration take 0:00:05.560571 seconds ---
# The stat is 0.027
# Type 1 error: 0.15517241379310345 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1206896551724138 for z dimension 1 with significance level 0.05
# --- The 59'th iteration take 0:00:05.548921 seconds ---
# The stat is 0.348
# Type 1 error: 0.15254237288135594 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11864406779661017 for z dimension 1 with significance level 0.05
# --- The 60'th iteration take 0:00:05.612248 seconds ---
# The stat is 0.568
# Type 1 error: 0.15 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11666666666666667 for z dimension 1 with significance level 0.05
# --- The 61'th iteration take 0:00:05.619554 seconds ---
# The stat is 0.681
# Type 1 error: 0.14754098360655737 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11475409836065574 for z dimension 1 with significance level 0.05
# --- The 62'th iteration take 0:00:05.582301 seconds ---
# The stat is 0.695
# Type 1 error: 0.14516129032258066 for z dimension 1 with significance level 0.1
# Type 1 error: 0.11290322580645161 for z dimension 1 with significance level 0.05
# --- The 63'th iteration take 0:00:05.660697 seconds ---
# The stat is 0.939
# Type 1 error: 0.14285714285714285 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 64'th iteration take 0:00:05.578410 seconds ---
# The stat is 0.839
# Type 1 error: 0.140625 for z dimension 1 with significance level 0.1
# Type 1 error: 0.109375 for z dimension 1 with significance level 0.05
# --- The 65'th iteration take 0:00:05.581513 seconds ---
# The stat is 0.226
# Type 1 error: 0.13846153846153847 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1076923076923077 for z dimension 1 with significance level 0.05
# --- The 66'th iteration take 0:00:05.571818 seconds ---
# The stat is 0.393
# Type 1 error: 0.13636363636363635 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10606060606060606 for z dimension 1 with significance level 0.05
# --- The 67'th iteration take 0:00:05.643796 seconds ---
# The stat is 0.149
# Type 1 error: 0.13432835820895522 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1044776119402985 for z dimension 1 with significance level 0.05
# --- The 68'th iteration take 0:00:05.658186 seconds ---
# The stat is 0.664
# Type 1 error: 0.1323529411764706 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10294117647058823 for z dimension 1 with significance level 0.05
# --- The 69'th iteration take 0:00:05.564700 seconds ---
# The stat is 0.56
# Type 1 error: 0.13043478260869565 for z dimension 1 with significance level 0.1
# Type 1 error: 0.10144927536231885 for z dimension 1 with significance level 0.05
# --- The 70'th iteration take 0:00:05.608738 seconds ---
# The stat is 0.946
# Type 1 error: 0.12857142857142856 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 71'th iteration take 0:00:05.558457 seconds ---
# The stat is 0.482
# Type 1 error: 0.1267605633802817 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09859154929577464 for z dimension 1 with significance level 0.05
# --- The 72'th iteration take 0:00:05.621429 seconds ---
# The stat is 0.969
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09722222222222222 for z dimension 1 with significance level 0.05
# --- The 73'th iteration take 0:00:05.648203 seconds ---
# The stat is 0.867
# Type 1 error: 0.1232876712328767 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0958904109589041 for z dimension 1 with significance level 0.05
# --- The 74'th iteration take 0:00:05.615665 seconds ---
# The stat is 0.651
# Type 1 error: 0.12162162162162163 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0945945945945946 for z dimension 1 with significance level 0.05
# --- The 75'th iteration take 0:00:05.607227 seconds ---
# The stat is 0.552
# Type 1 error: 0.12 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09333333333333334 for z dimension 1 with significance level 0.05
# --- The 76'th iteration take 0:00:05.617004 seconds ---
# The stat is 0.595
# Type 1 error: 0.11842105263157894 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09210526315789473 for z dimension 1 with significance level 0.05
# --- The 77'th iteration take 0:00:05.605113 seconds ---
# The stat is 0.466
# Type 1 error: 0.11688311688311688 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 78'th iteration take 0:00:05.647897 seconds ---
# The stat is 0.921
# Type 1 error: 0.11538461538461539 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08974358974358974 for z dimension 1 with significance level 0.05
# --- The 79'th iteration take 0:00:05.663907 seconds ---
# The stat is 0.819
# Type 1 error: 0.11392405063291139 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08860759493670886 for z dimension 1 with significance level 0.05
# --- The 80'th iteration take 0:00:05.643440 seconds ---
# The stat is 0.05
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0875 for z dimension 1 with significance level 0.05
# --- The 81'th iteration take 0:00:05.605361 seconds ---
# The stat is 0.37
# Type 1 error: 0.12345679012345678 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08641975308641975 for z dimension 1 with significance level 0.05
# --- The 82'th iteration take 0:00:05.704621 seconds ---
# The stat is 0.342
# Type 1 error: 0.12195121951219512 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08536585365853659 for z dimension 1 with significance level 0.05
# --- The 83'th iteration take 0:00:05.845606 seconds ---
# The stat is 0.653
# Type 1 error: 0.12048192771084337 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08433734939759036 for z dimension 1 with significance level 0.05
# --- The 84'th iteration take 0:00:05.820404 seconds ---
# The stat is 0.631
# Type 1 error: 0.11904761904761904 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 85'th iteration take 0:00:05.833861 seconds ---
# The stat is 0.231
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08235294117647059 for z dimension 1 with significance level 0.05
# --- The 86'th iteration take 0:00:05.823461 seconds ---
# The stat is 0.273
# Type 1 error: 0.11627906976744186 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08139534883720931 for z dimension 1 with significance level 0.05
# --- The 87'th iteration take 0:00:05.859739 seconds ---
# The stat is 0.681
# Type 1 error: 0.11494252873563218 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08045977011494253 for z dimension 1 with significance level 0.05
# --- The 88'th iteration take 0:00:05.803424 seconds ---
# The stat is 0.284
# Type 1 error: 0.11363636363636363 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07954545454545454 for z dimension 1 with significance level 0.05
# --- The 89'th iteration take 0:00:05.874832 seconds ---
# The stat is 0.686
# Type 1 error: 0.11235955056179775 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07865168539325842 for z dimension 1 with significance level 0.05
# --- The 90'th iteration take 0:00:05.775057 seconds ---
# The stat is 0.338
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07777777777777778 for z dimension 1 with significance level 0.05
# --- The 91'th iteration take 0:00:05.814342 seconds ---
# The stat is 0.962
# Type 1 error: 0.10989010989010989 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 92'th iteration take 0:00:05.794658 seconds ---
# The stat is 0.66
# Type 1 error: 0.10869565217391304 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07608695652173914 for z dimension 1 with significance level 0.05
# --- The 93'th iteration take 0:00:05.818230 seconds ---
# The stat is 0.912
# Type 1 error: 0.10752688172043011 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07526881720430108 for z dimension 1 with significance level 0.05
# --- The 94'th iteration take 0:00:05.793701 seconds ---
# The stat is 0.325
# Type 1 error: 0.10638297872340426 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07446808510638298 for z dimension 1 with significance level 0.05
# --- The 95'th iteration take 0:00:05.787238 seconds ---
# The stat is 0.654
# Type 1 error: 0.10526315789473684 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07368421052631578 for z dimension 1 with significance level 0.05
# --- The 96'th iteration take 0:00:05.787780 seconds ---
# The stat is 0.245
# Type 1 error: 0.10416666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07291666666666667 for z dimension 1 with significance level 0.05
# --- The 97'th iteration take 0:00:05.827774 seconds ---
# The stat is 0.87
# Type 1 error: 0.10309278350515463 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07216494845360824 for z dimension 1 with significance level 0.05
# --- The 98'th iteration take 0:00:05.777907 seconds ---
# The stat is 0.102
# Type 1 error: 0.10204081632653061 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 99'th iteration take 0:00:05.824032 seconds ---
# The stat is 0.812
# Type 1 error: 0.10101010101010101 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0707070707070707 for z dimension 1 with significance level 0.05
# --- The 100'th iteration take 0:00:05.775872 seconds ---
# The stat is 0.353
# Type 1 error: 0.1 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07 for z dimension 1 with significance level 0.05
# array([0.785, 0.243, 0.776, 0.34 , 0.795, 0.832, 0.69 , 0.88 , 0.288,
#        0.249, 0.366, 0.599, 0.904, 0.217, 0.883, 0.965, 0.688, 0.589,
#        0.372, 0.981, 0.913, 0.52 , 0.937, 0.626, 0.055, 0.445, 0.033,
#        0.968, 0.732, 0.048, 0.092, 0.866, 0.402, 0.943, 0.013, 0.95 ,
#        0.008, 0.665, 0.294, 0.969, 0.521, 0.018, 0.76 , 0.269, 0.458,
#        0.534, 0.35 , 0.767, 0.659, 0.978, 0.027, 0.208, 0.867, 0.962,
#        0.134, 0.584, 0.195, 0.027, 0.348, 0.568, 0.681, 0.695, 0.939,
#        0.839, 0.226, 0.393, 0.149, 0.664, 0.56 , 0.946, 0.482, 0.969,
#        0.867, 0.651, 0.552, 0.595, 0.466, 0.921, 0.819, 0.05 , 0.37 ,
#        0.342, 0.653, 0.631, 0.231, 0.273, 0.681, 0.284, 0.686, 0.338,
#        0.962, 0.66 , 0.912, 0.325, 0.654, 0.245, 0.87 , 0.102, 0.812,
#        0.353])

# %%
import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools


# =========================
# Device
# =========================
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


# =========================
# Parameters
# =========================
param = {
    "test": "type1error",
    "sample_size": 600,
    "batch_size": 256,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 200,
    "eps_std": 0.5,
    "dist_z": 'gaussian',
    "alpha_x": 0.75,
    "m_value": 100,
    "k_value": 2,
    "j_value": 1000,
    "noise_dimension": 3,
    "hidden_layer_size": 20,
    "normal_ini": False,
    "preprocess": 'None',
    "G_lr": 1e-3,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 42,
    "using_oracle": False,
    "lambda_1": 1,
    "lambda_2": 0,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-5,
    "drop_out_p": 0.2,
    "M_train": 10,

    "lambda_mean": 0,
    "mean_samples": 20
}



# =========================
# Data generation: binary version
# =========================
def generate_samples_random(Ax, Ay, size=1000, sType='CI', dx=1, dy=1, dz=1,
                            nstd=0.05, alpha_x=0.05,
                            preprocess="None", dist_z='gaussian'):
    """
    Binary data generator aligned with the author's pasted code.

    Output:
        X, Y, Z are all binary {0,1} tensors.
    """
    if dx != 1 or dy != 1 or dz != 1:
        raise ValueError("This binary version currently supports dx=dy=dz=1 only.")

    num = size

    if sType in ['CI', 'H0', 'type1error']:
        numbers_z = np.random.multinomial(num, [0.5, 0.5], size=1)
        number_z_zeros = numbers_z[0][0]
        number_z_ones = numbers_z[0][1]

        xy_arr = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

        xy_z_zero_index = np.random.choice(
            a=len(xy_arr), size=number_z_zeros,
            p=[0.25, 0.25, 0.25, 0.25]
        )
        xy_z_one_index = np.random.choice(
            a=len(xy_arr), size=number_z_ones,
            p=[0.25, 0.25, 0.25, 0.25]
        )

        xy_z_zero = xy_arr[xy_z_zero_index]
        xy_z_one = xy_arr[xy_z_one_index]

        xy = np.concatenate((xy_z_zero, xy_z_one), axis=0)

        x = xy[:, 0]
        y = xy[:, 1]
        z = np.concatenate((np.zeros(number_z_zeros), np.ones(number_z_ones)), axis=0)

    elif sType in ['dependent', 'H1', 'power']:
        z = np.random.binomial(1, 0.5, size=num)
        y = np.random.binomial(1, 0.5, size=num)

        delta = np.random.binomial(1, alpha_x, size=num)
        x_indep = np.random.binomial(1, 0.5, size=num)

        x = (1 - delta) * x_indep + delta * y
        x = x.astype(int)

    else:
        raise ValueError("sType must be one of ['CI','H0','type1error','dependent','H1','power']")

    indices = np.random.permutation(num)
    x, y, z = x[indices], y[indices], z[indices]

    X = x.reshape(-1, 1).astype(np.float32)
    Y = y.reshape(-1, 1).astype(np.float32)
    Z = z.reshape(-1, 1).astype(np.float32)

    if preprocess == "normalize":
        pass
    elif preprocess == "scale_Z":
        pass
    elif preprocess == "None":
        pass
    else:
        raise ValueError("preprocess must be one of ['normalize', 'scale_Z', 'None']")

    X = torch.from_numpy(X).float()
    Y = torch.from_numpy(Y).float()
    Z = torch.from_numpy(Z).float()

    return X, Y, Z


# =========================
# Statistic computation
# =========================
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                       x_torch, y_torch, z_torch,
                       sigma_w, sigma_u=1, sigma_v=1,
                       boor_rv_type="gaussian"):
    """
    Compute test statistic and bootstrap samples.
    Shapes:
        gen_x_all_torch, gen_y_all_torch: (n, M)
        x_torch, y_torch: (n, 1)
        z_torch: (n, dz)
    """
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v
        ),
        dim=2
    )
    v_mx_3 = v_mx_2.T

    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
        dim=2
    )

    for i in range(1, M):
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
            dim=2
        )
        sum2_mx = sum2_mx + temp2_add_mx

    v_mx_4 = 1.0 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n, device=device))

    stat = 1.0 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])

    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num, device=device))
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num, device=device)
    else:
        raise ValueError("boor_rv_type must be 'rademacher' or 'gaussian'")

    for bb in range(boot_num):
        random_mx = torch.matmul(
            eboot[:, bb].reshape(-1, 1),
            eboot[:, bb].reshape(-1, 1).T
        )
        bootmatrix = FF_mx * random_mx
        stat_boot = 1.0 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)

    return stat, boottemp


# =========================
# Dataset
# =========================
class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (
            self.X_real[index],
            self.Y_real[index],
            self.Z_real[index],
            self.Z_real[(self.batch_size + index) % self.sample_size]
        )


# =========================
# Noise sampler
# =========================
def sample_noise(sample_size, noise_dimension, noise_type, input_var):
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),
            input_var * torch.eye(noise_dimension).to(device)
        )
        Z = noise_generator.sample((sample_size,))
    elif noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension, device=device)
    elif noise_type == "Cauchy":
        Z = TD.Cauchy(
            torch.tensor([0.0], device=device),
            torch.tensor([1.0], device=device)
        ).sample((sample_size, noise_dimension)).squeeze(2)
    else:
        raise ValueError("noise_type must be one of ['normal', 'unif', 'Cauchy']")
    return Z


# =========================
# Generator
# =========================
class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p,
                 drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.drop_input = drop_input

        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)

        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)

        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        if self.drop_input:
            x = self.drop_out0(x)

        if self.BN_type:
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
        else:
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))

        x = self.fc_last(x)

        # Binary probability output
        x = self.sigmoid(x)

        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias).to(device)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for _ in range(m)]
        ).to(device)

    def forward(self, x):
        self.linear.weight.data *= self.mask
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)

        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0]
        )

        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for _ in range(len(self.hidden_layer_sizes))
        ])

        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        self.sigmoid = torch.nn.Sigmoid()

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)

        output = self.linear8(output)
        output = self.sigmoid(output)
        return output


# =========================
# Loss
# =========================
def find_loss(y_torch, gen_y_all_torch, z_torch, sigma_w, sigma_u, M):
    n = z_torch.shape[0]

    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    FF_mx = u_mx * w_mx * (1 - torch.eye(n, device=device))
    loss = 1.0 / n * torch.sum(FF_mx)

    return loss


# =========================
# Binary sampling helper
# =========================
def sample_binary_from_prob(prob_tensor):
    prob_tensor = torch.clamp(prob_tensor, 1e-6, 1 - 1e-6)
    return torch.bernoulli(prob_tensor)


# =========================
# Training
# =========================
def train_ver3(X, Y, Z, X_test, Y_test, Z_test, M,
               noise_dimension, noise_type, G_lr, hidden_layer_size,
               DataLoader, BN_type, ReLU_coef,
               epochs_num=10, sigma_z=1, sigma_x=1, sigma_y=1,
               normal_ini=False,
               lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
               lambda_3=0, drop_out_p=0.2, M_train=3,
               lambda_mean=0.0, mean_samples=20):

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if using_Gen == '1':
        G_zy = Generator(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    elif using_Gen == '2':
        G_zy = Generator_2(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator_2(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    else:
        raise ValueError("using_Gen must be '1' or '2'")

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))

    for epoch in range(epochs_num):
        G_zy.train()
        G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)
            Y_real = Y_real.to(device)
            Z_real = Z_real.to(device)
            Z_fake = Z_fake.to(device)

            batch_size = Z_real.shape[0]

            # =========================
            # Train G_zy
            # =========================
            G_zy_solver.zero_grad()

            Z_real_repeat_y = Z_real.repeat(M_train, 1)
            Noise_fake_y = sample_noise(
                Z_real_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            Y_fake_prob = G_zy(torch.cat((Z_real_repeat_y, Noise_fake_y), dim=1)).to(device)
            Y_fake = Y_fake_prob.reshape(batch_size, M_train)

            l1_regularization_y = 0.0
            for param in G_zy.parameters():
                l1_regularization_y += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = lambda_1 * find_loss(
                Y_real, Y_fake, Z_real, sigma_z, sigma_y, M_train
            )

            if lambda_mean > 0:
                # 这里保留你的改进：对同一个 Z 做 Monte Carlo 均值近似
                Z_mean_repeat_y = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_y = sample_noise(
                    Z_mean_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                Y_mean_fake_group = G_zy(torch.cat((Z_mean_repeat_y, Noise_mean_y), dim=1))
                Y_mean_fake = Y_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_y).mean(dim=1)

                mean_loss_y = torch.nn.functional.mse_loss(Y_mean_fake, Y_real)
            else:
                mean_loss_y = 0.0

            g_zy_error = mmd_loss_y + lambda_mean * mean_loss_y + lambda_3 * l1_regularization_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            # =========================
            # Train G_zx
            # =========================
            G_zx_solver.zero_grad()

            Z_real_repeat_x = Z_real.repeat(M_train, 1)
            Noise_fake_x = sample_noise(
                Z_real_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            X_fake_prob = G_zx(torch.cat((Z_real_repeat_x, Noise_fake_x), dim=1)).to(device)
            X_fake = X_fake_prob.reshape(batch_size, M_train)

            l1_regularization_x = 0.0
            for param in G_zx.parameters():
                l1_regularization_x += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = lambda_1 * find_loss(
                X_real, X_fake, Z_real, sigma_z, sigma_x, M_train
            )

            if lambda_mean > 0:
                Z_mean_repeat_x = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_x = sample_noise(
                    Z_mean_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                X_mean_fake_group = G_zx(torch.cat((Z_mean_repeat_x, Noise_mean_x), dim=1))
                X_mean_fake = X_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_x).mean(dim=1)

                mean_loss_x = torch.nn.functional.mse_loss(X_mean_fake, X_real)
            else:
                mean_loss_x = 0.0

            g_zx_error = mmd_loss_x + lambda_mean * mean_loss_x + lambda_3 * l1_regularization_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

    return G_zy, G_zx

# =========================
# Main experiment for one run
# =========================
def mGAN(Ax, Ay, n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_oracle=False, lambda_1=1, lambda_2=1, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2, exp_num=0,
         M_train=3, lambda_mean=0.0, mean_samples=20):


    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='CI', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='dependent', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x, sim_y, sim_z

    sigma_w_train = 1.0
    sigma_u_train = 1.0
    sigma_v_train = 1.0

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))

        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]

        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))

        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_oracle:
            G_zy, G_zx = train_ver3(
    X=X_train, Y=Y_train, Z=Z_train, M=M,
    X_test=X_test, Y_test=Y_test, Z_test=Z_test,
    noise_dimension=noise_dimension, noise_type="normal",
    G_lr=G_lr, hidden_layer_size=hidden_layer_size,
    DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
    epochs_num=epochs_num, sigma_z=sigma_w_train, sigma_x=sigma_v_train,
    sigma_y=sigma_u_train, normal_ini=normal_ini, lambda_1=lambda_1,
    lambda_2=lambda_2, using_Gen=using_Gen, wgt_decay=wgt_decay,
    lambda_3=lambda_3, drop_out_p=drop_out_p, M_train=M_train,
    lambda_mean=lambda_mean, mean_samples=mean_samples
)


        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M)
        gen_y_all = torch.zeros(test_size, M)

        z_all = torch.zeros(test_size, z_dim)
        x_all = torch.zeros(test_size, x_dims)
        y_all = torch.zeros(test_size, y_dims)

        cur_itr = 0

        if using_oracle:
            for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                z_scalar = int(z_test.item())

                fake_x = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)
                fake_y = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)

                gen_x_all[cur_itr, :] = fake_x.reshape(-1)
                gen_y_all[cur_itr, :] = fake_y.reshape(-1)

                x_all[cur_itr, :] = x_test
                y_all[cur_itr, :] = y_test
                z_all[cur_itr, :] = z_test
                cur_itr += 1
        else:
            G_zx.eval()
            G_zy.eval()

            with torch.no_grad():
                for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                    z_test_temp = z_test.repeat(M, 1).to(device)

                    noise_x = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_x_prob = G_zx(torch.cat((z_test_temp, noise_x), dim=1))
                    fake_x = sample_binary_from_prob(fake_x_prob).reshape(1, -1)

                    noise_y = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_y_prob = G_zy(torch.cat((z_test_temp, noise_y), dim=1))
                    fake_y = sample_binary_from_prob(fake_y_prob).reshape(1, -1)

                    gen_x_all[cur_itr, :] = fake_x.detach().cpu().reshape(-1)
                    gen_y_all[cur_itr, :] = fake_y.detach().cpu().reshape(-1)
                    x_all[cur_itr, :] = x_test
                    y_all[cur_itr, :] = y_test
                    z_all[cur_itr, :] = z_test
                    cur_itr += 1

        gen_x_all = gen_x_all.to(device)
        gen_y_all = gen_y_all.to(device)

        z_all = Z_test.to(device)
        x_all = X_test.to(device)
        y_all = Y_test.to(device)

        sigma_w = 1.0
        sigma_u = 1.0
        sigma_v = 1.0

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type
        )

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp).float()
        cur_k += 1

    return np.mean(torch.mean(boot_temp_all, dim=0).cpu().numpy() > torch.mean(stat_all).item())


# =========================
# Repeated experiment
# =========================
def run_experiment(params):
    test = params["test"]
    sample_size = params["sample_size"]
    batch_size = params["batch_size"]
    z_dim = params["z_dim"]
    dx = params["dx"]
    dy = params["dy"]
    n_test = params["n_test"]
    epochs_num = params["epochs_num"]
    eps_std = params["eps_std"]
    dist_z = params["dist_z"]
    alpha_x = params["alpha_x"]
    m_value = params["m_value"]
    k_value = params["k_value"]
    j_value = params["j_value"]
    noise_dimension = params["noise_dimension"]
    hidden_layer_size = params["hidden_layer_size"]
    normal_ini = params["normal_ini"]
    preprocess = params["preprocess"]
    G_lr = params["G_lr"]
    alpha = params["alpha"]
    alpha1 = params["alpha1"]
    set_seeds = params["set_seeds"]
    using_oracle = params["using_oracle"]
    lambda_1 = params["lambda_1"]
    lambda_2 = params["lambda_2"]
    using_Gen = params["using_Gen"]
    boor_rv_type = params["boor_rv_type"]
    wgt_decay = params["wgt_decay"]
    lambda_3 = params["lambda_3"]
    drop_out_p = params["drop_out_p"]
    M_train = params["M_train"]
    lambda_mean = params["lambda_mean"]
    mean_samples = params["mean_samples"]


    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    a_f = torch.rand((z_dim, dx))
    l1_norm_a_f = torch.linalg.vector_norm(a_f, ord=1)
    Ax = a_f / l1_norm_a_f

    a_g = torch.rand((z_dim, dy))
    l1_norm_a_g = torch.linalg.vector_norm(a_g, ord=1)
    Ay = a_g / l1_norm_a_g

    p_values = np.array([])
    test_count = 0

    if test == 'type1error':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train, lambda_mean=lambda_mean, mean_samples=mean_samples
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))

    elif test == 'power':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))
    else:
        raise ValueError("test must be 'type1error' or 'power'")

    return p_values


# =========================
# Run
# =========================
run_experiment(param)
# Out:
# --- The 1'th iteration take 0:00:35.700511 seconds ---
# The stat is 0.535
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 2'th iteration take 0:00:41.038293 seconds ---
# The stat is 0.507
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 3'th iteration take 0:00:36.166445 seconds ---
# The stat is 0.315
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 4'th iteration take 0:00:33.103698 seconds ---
# The stat is 0.527
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 5'th iteration take 0:00:33.240099 seconds ---
# The stat is 0.755
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 6'th iteration take 0:00:33.491445 seconds ---
# The stat is 0.751
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 7'th iteration take 0:00:33.363782 seconds ---
# The stat is 0.959
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 8'th iteration take 0:00:33.672976 seconds ---
# The stat is 0.781
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 9'th iteration take 0:00:33.495070 seconds ---
# The stat is 0.418
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 10'th iteration take 0:00:33.552188 seconds ---
# The stat is 0.706
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 11'th iteration take 0:00:33.491681 seconds ---
# The stat is 0.589
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 12'th iteration take 0:00:34.096609 seconds ---
# The stat is 0.12
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 13'th iteration take 0:00:33.820933 seconds ---
# The stat is 0.105
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 14'th iteration take 0:00:33.920120 seconds ---
# The stat is 0.191
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 15'th iteration take 0:00:33.736584 seconds ---
# The stat is 0.257
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 16'th iteration take 0:00:33.385172 seconds ---
# The stat is 0.462
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 17'th iteration take 0:00:33.070278 seconds ---
# The stat is 0.34
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 18'th iteration take 0:00:33.923216 seconds ---
# The stat is 0.176
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 19'th iteration take 0:00:32.317828 seconds ---
# The stat is 0.628
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 20'th iteration take 0:00:33.641228 seconds ---
# The stat is 0.005
# Type 1 error: 0.05 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# --- The 21'th iteration take 0:00:33.218290 seconds ---
# The stat is 0.484
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.05
# --- The 22'th iteration take 0:00:34.201129 seconds ---
# The stat is 0.265
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.1
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.05
# --- The 23'th iteration take 0:00:33.829614 seconds ---
# The stat is 0.531
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.1
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.05
# --- The 24'th iteration take 0:00:33.263508 seconds ---
# The stat is 0.653
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.05
# --- The 25'th iteration take 0:00:33.543606 seconds ---
# The stat is 0.219
# Type 1 error: 0.04 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# --- The 26'th iteration take 0:00:33.123122 seconds ---
# The stat is 0.567
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.1
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.05
# --- The 27'th iteration take 0:00:33.952025 seconds ---
# The stat is 0.163
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.1
# Type 1 error: 0.037037037037037035 for z dimension 1 with significance level 0.05
# --- The 28'th iteration take 0:00:33.499052 seconds ---
# The stat is 0.674
# Type 1 error: 0.03571428571428571 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03571428571428571 for z dimension 1 with significance level 0.05
# --- The 29'th iteration take 0:00:33.975988 seconds ---
# The stat is 0.6
# Type 1 error: 0.034482758620689655 for z dimension 1 with significance level 0.1
# Type 1 error: 0.034482758620689655 for z dimension 1 with significance level 0.05
# --- The 30'th iteration take 0:00:33.865508 seconds ---
# The stat is 0.092
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03333333333333333 for z dimension 1 with significance level 0.05
# --- The 31'th iteration take 0:00:34.165257 seconds ---
# The stat is 0.64
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03225806451612903 for z dimension 1 with significance level 0.05
# --- The 32'th iteration take 0:00:33.762744 seconds ---
# The stat is 0.119
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.1
# Type 1 error: 0.03125 for z dimension 1 with significance level 0.05
# --- The 33'th iteration take 0:00:33.849838 seconds ---
# The stat is 0.41
# Type 1 error: 0.06060606060606061 for z dimension 1 with significance level 0.1
# Type 1 error: 0.030303030303030304 for z dimension 1 with significance level 0.05
# --- The 34'th iteration take 0:00:33.686880 seconds ---
# The stat is 0.739
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.1
# Type 1 error: 0.029411764705882353 for z dimension 1 with significance level 0.05
# --- The 35'th iteration take 0:00:33.248364 seconds ---
# The stat is 0.317
# Type 1 error: 0.05714285714285714 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02857142857142857 for z dimension 1 with significance level 0.05
# --- The 36'th iteration take 0:00:32.206607 seconds ---
# The stat is 0.64
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.1
# Type 1 error: 0.027777777777777776 for z dimension 1 with significance level 0.05
# --- The 37'th iteration take 0:00:33.682258 seconds ---
# The stat is 0.143
# Type 1 error: 0.05405405405405406 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02702702702702703 for z dimension 1 with significance level 0.05
# --- The 38'th iteration take 0:00:33.303039 seconds ---
# The stat is 0.459
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02631578947368421 for z dimension 1 with significance level 0.05
# --- The 39'th iteration take 0:00:25.097664 seconds ---
# The stat is 0.814
# Type 1 error: 0.05128205128205128 for z dimension 1 with significance level 0.1
# Type 1 error: 0.02564102564102564 for z dimension 1 with significance level 0.05
# --- The 40'th iteration take 0:00:25.286045 seconds ---
# The stat is 0.683
# Type 1 error: 0.05 for z dimension 1 with significance level 0.1
# Type 1 error: 0.025 for z dimension 1 with significance level 0.05
# --- The 41'th iteration take 0:00:25.633454 seconds ---
# The stat is 0.586
# Type 1 error: 0.04878048780487805 for z dimension 1 with significance level 0.1
# Type 1 error: 0.024390243902439025 for z dimension 1 with significance level 0.05
# --- The 42'th iteration take 0:00:25.326253 seconds ---
# The stat is 0.0
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.05
# --- The 43'th iteration take 0:00:25.272275 seconds ---
# The stat is 0.191
# Type 1 error: 0.06976744186046512 for z dimension 1 with significance level 0.1
# Type 1 error: 0.046511627906976744 for z dimension 1 with significance level 0.05
# --- The 44'th iteration take 0:00:25.286562 seconds ---
# The stat is 0.381
# Type 1 error: 0.06818181818181818 for z dimension 1 with significance level 0.1
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.05
# --- The 45'th iteration take 0:00:25.299385 seconds ---
# The stat is 0.267
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.044444444444444446 for z dimension 1 with significance level 0.05
# --- The 46'th iteration take 0:00:25.412622 seconds ---
# The stat is 0.618
# Type 1 error: 0.06521739130434782 for z dimension 1 with significance level 0.1
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.05
# --- The 47'th iteration take 0:00:25.266242 seconds ---
# The stat is 0.051
# Type 1 error: 0.0851063829787234 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0425531914893617 for z dimension 1 with significance level 0.05
# --- The 48'th iteration take 0:00:37.047935 seconds ---
# The stat is 0.502
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.041666666666666664 for z dimension 1 with significance level 0.05
# --- The 49'th iteration take 0:00:31.973303 seconds ---
# The stat is 0.156
# Type 1 error: 0.08163265306122448 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04081632653061224 for z dimension 1 with significance level 0.05
# --- The 50'th iteration take 0:00:33.854673 seconds ---
# The stat is 0.157
# Type 1 error: 0.08 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04 for z dimension 1 with significance level 0.05
# --- The 51'th iteration take 0:00:35.738549 seconds ---
# The stat is 0.855
# Type 1 error: 0.0784313725490196 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0392156862745098 for z dimension 1 with significance level 0.05
# --- The 52'th iteration take 0:00:35.195671 seconds ---
# The stat is 0.229
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.1
# Type 1 error: 0.038461538461538464 for z dimension 1 with significance level 0.05
# --- The 53'th iteration take 0:00:33.438709 seconds ---
# The stat is 0.015
# Type 1 error: 0.09433962264150944 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05660377358490566 for z dimension 1 with significance level 0.05
# --- The 54'th iteration take 0:00:36.285157 seconds ---
# The stat is 0.694
# Type 1 error: 0.09259259259259259 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 55'th iteration take 0:00:35.221150 seconds ---
# The stat is 0.074
# Type 1 error: 0.10909090909090909 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05454545454545454 for z dimension 1 with significance level 0.05
# --- The 56'th iteration take 0:00:39.559880 seconds ---
# The stat is 0.202
# Type 1 error: 0.10714285714285714 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05357142857142857 for z dimension 1 with significance level 0.05
# --- The 57'th iteration take 0:00:40.266185 seconds ---
# The stat is 0.158
# Type 1 error: 0.10526315789473684 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.05
# --- The 58'th iteration take 0:00:35.167916 seconds ---
# The stat is 0.438
# Type 1 error: 0.10344827586206896 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05172413793103448 for z dimension 1 with significance level 0.05
# --- The 59'th iteration take 0:00:33.014031 seconds ---
# The stat is 0.067
# Type 1 error: 0.11864406779661017 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05084745762711865 for z dimension 1 with significance level 0.05
# --- The 60'th iteration take 0:00:32.986679 seconds ---
# The stat is 0.79
# Type 1 error: 0.11666666666666667 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# --- The 61'th iteration take 0:00:34.636382 seconds ---
# The stat is 0.166
# Type 1 error: 0.11475409836065574 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04918032786885246 for z dimension 1 with significance level 0.05
# --- The 62'th iteration take 0:00:33.088267 seconds ---
# The stat is 0.776
# Type 1 error: 0.11290322580645161 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04838709677419355 for z dimension 1 with significance level 0.05
# --- The 63'th iteration take 0:00:31.953103 seconds ---
# The stat is 0.265
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.05
# --- The 64'th iteration take 0:00:49.578414 seconds ---
# The stat is 0.248
# Type 1 error: 0.109375 for z dimension 1 with significance level 0.1
# Type 1 error: 0.046875 for z dimension 1 with significance level 0.05
# --- The 65'th iteration take 0:00:44.405622 seconds ---
# The stat is 0.887
# Type 1 error: 0.1076923076923077 for z dimension 1 with significance level 0.1
# Type 1 error: 0.046153846153846156 for z dimension 1 with significance level 0.05
# --- The 66'th iteration take 0:00:37.827574 seconds ---
# The stat is 0.921
# Type 1 error: 0.10606060606060606 for z dimension 1 with significance level 0.1
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.05
# --- The 67'th iteration take 0:00:34.605578 seconds ---
# The stat is 0.026
# Type 1 error: 0.11940298507462686 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05970149253731343 for z dimension 1 with significance level 0.05
# --- The 68'th iteration take 0:00:33.705380 seconds ---
# The stat is 0.702
# Type 1 error: 0.11764705882352941 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 69'th iteration take 0:00:33.151884 seconds ---
# The stat is 0.977
# Type 1 error: 0.11594202898550725 for z dimension 1 with significance level 0.1
# Type 1 error: 0.057971014492753624 for z dimension 1 with significance level 0.05
# --- The 70'th iteration take 0:00:32.884642 seconds ---
# The stat is 0.901
# Type 1 error: 0.11428571428571428 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05714285714285714 for z dimension 1 with significance level 0.05
# --- The 71'th iteration take 0:00:32.891804 seconds ---
# The stat is 0.423
# Type 1 error: 0.11267605633802817 for z dimension 1 with significance level 0.1
# Type 1 error: 0.056338028169014086 for z dimension 1 with significance level 0.05
# --- The 72'th iteration take 0:00:31.714753 seconds ---
# The stat is 0.365
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 73'th iteration take 0:00:34.661602 seconds ---
# The stat is 0.061
# Type 1 error: 0.1232876712328767 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0547945205479452 for z dimension 1 with significance level 0.05
# --- The 74'th iteration take 0:00:33.849195 seconds ---
# The stat is 0.51
# Type 1 error: 0.12162162162162163 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05405405405405406 for z dimension 1 with significance level 0.05
# --- The 75'th iteration take 0:00:32.234652 seconds ---
# The stat is 0.915
# Type 1 error: 0.12 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05333333333333334 for z dimension 1 with significance level 0.05
# --- The 76'th iteration take 0:00:33.939221 seconds ---
# The stat is 0.423
# Type 1 error: 0.11842105263157894 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.05
# --- The 77'th iteration take 0:00:33.772832 seconds ---
# The stat is 0.188
# Type 1 error: 0.11688311688311688 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05194805194805195 for z dimension 1 with significance level 0.05
# --- The 78'th iteration take 0:00:33.675118 seconds ---
# The stat is 0.383
# Type 1 error: 0.11538461538461539 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05128205128205128 for z dimension 1 with significance level 0.05
# --- The 79'th iteration take 0:00:33.812191 seconds ---
# The stat is 0.806
# Type 1 error: 0.11392405063291139 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05063291139240506 for z dimension 1 with significance level 0.05
# --- The 80'th iteration take 0:00:33.785509 seconds ---
# The stat is 0.76
# Type 1 error: 0.1125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# --- The 81'th iteration take 0:00:32.453984 seconds ---
# The stat is 0.821
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04938271604938271 for z dimension 1 with significance level 0.05
# --- The 82'th iteration take 0:00:33.648414 seconds ---
# The stat is 0.736
# Type 1 error: 0.10975609756097561 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04878048780487805 for z dimension 1 with significance level 0.05
# --- The 83'th iteration take 0:00:34.214851 seconds ---
# The stat is 0.483
# Type 1 error: 0.10843373493975904 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04819277108433735 for z dimension 1 with significance level 0.05
# --- The 84'th iteration take 0:00:33.980537 seconds ---
# The stat is 0.058
# Type 1 error: 0.11904761904761904 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047619047619047616 for z dimension 1 with significance level 0.05
# --- The 85'th iteration take 0:00:33.978722 seconds ---
# The stat is 0.088
# Type 1 error: 0.12941176470588237 for z dimension 1 with significance level 0.1
# Type 1 error: 0.047058823529411764 for z dimension 1 with significance level 0.05
# --- The 86'th iteration take 0:00:33.946947 seconds ---
# The stat is 0.825
# Type 1 error: 0.12790697674418605 for z dimension 1 with significance level 0.1
# Type 1 error: 0.046511627906976744 for z dimension 1 with significance level 0.05
# --- The 87'th iteration take 0:00:32.350455 seconds ---
# The stat is 0.649
# Type 1 error: 0.12643678160919541 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04597701149425287 for z dimension 1 with significance level 0.05
# --- The 88'th iteration take 0:00:33.646656 seconds ---
# The stat is 0.622
# Type 1 error: 0.125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.045454545454545456 for z dimension 1 with significance level 0.05
# --- The 89'th iteration take 0:00:33.096724 seconds ---
# The stat is 0.869
# Type 1 error: 0.12359550561797752 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0449438202247191 for z dimension 1 with significance level 0.05
# --- The 90'th iteration take 0:00:33.114925 seconds ---
# The stat is 0.151
# Type 1 error: 0.12222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.044444444444444446 for z dimension 1 with significance level 0.05
# --- The 91'th iteration take 0:00:33.298648 seconds ---
# The stat is 0.671
# Type 1 error: 0.12087912087912088 for z dimension 1 with significance level 0.1
# Type 1 error: 0.04395604395604396 for z dimension 1 with significance level 0.05
# --- The 92'th iteration take 0:00:33.957959 seconds ---
# The stat is 0.406
# Type 1 error: 0.11956521739130435 for z dimension 1 with significance level 0.1
# Type 1 error: 0.043478260869565216 for z dimension 1 with significance level 0.05
# --- The 93'th iteration take 0:00:31.850962 seconds ---
# The stat is 0.027
# Type 1 error: 0.12903225806451613 for z dimension 1 with significance level 0.1
# Type 1 error: 0.053763440860215055 for z dimension 1 with significance level 0.05
# --- The 94'th iteration take 0:00:34.188047 seconds ---
# The stat is 0.05
# Type 1 error: 0.13829787234042554 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05319148936170213 for z dimension 1 with significance level 0.05
# --- The 95'th iteration take 0:00:31.882096 seconds ---
# The stat is 0.715
# Type 1 error: 0.1368421052631579 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.05
# --- The 96'th iteration take 0:00:33.502716 seconds ---
# The stat is 0.13
# Type 1 error: 0.13541666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.052083333333333336 for z dimension 1 with significance level 0.05
# --- The 97'th iteration take 0:00:31.560506 seconds ---
# The stat is 0.953
# Type 1 error: 0.13402061855670103 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05154639175257732 for z dimension 1 with significance level 0.05
# --- The 98'th iteration take 0:00:32.147249 seconds ---
# The stat is 0.847
# Type 1 error: 0.1326530612244898 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05102040816326531 for z dimension 1 with significance level 0.05
# --- The 99'th iteration take 0:00:33.712112 seconds ---
# The stat is 0.531
# Type 1 error: 0.13131313131313133 for z dimension 1 with significance level 0.1
# Type 1 error: 0.050505050505050504 for z dimension 1 with significance level 0.05
# --- The 100'th iteration take 0:00:33.425295 seconds ---
# The stat is 0.179
# Type 1 error: 0.13 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# array([0.535, 0.507, 0.315, 0.527, 0.755, 0.751, 0.959, 0.781, 0.418,
#        0.706, 0.589, 0.12 , 0.105, 0.191, 0.257, 0.462, 0.34 , 0.176,
#        0.628, 0.005, 0.484, 0.265, 0.531, 0.653, 0.219, 0.567, 0.163,
#        0.674, 0.6  , 0.092, 0.64 , 0.119, 0.41 , 0.739, 0.317, 0.64 ,
#        0.143, 0.459, 0.814, 0.683, 0.586, 0.   , 0.191, 0.381, 0.267,
#        0.618, 0.051, 0.502, 0.156, 0.157, 0.855, 0.229, 0.015, 0.694,
#        0.074, 0.202, 0.158, 0.438, 0.067, 0.79 , 0.166, 0.776, 0.265,
#        0.248, 0.887, 0.921, 0.026, 0.702, 0.977, 0.901, 0.423, 0.365,
#        0.061, 0.51 , 0.915, 0.423, 0.188, 0.383, 0.806, 0.76 , 0.821,
#        0.736, 0.483, 0.058, 0.088, 0.825, 0.649, 0.622, 0.869, 0.151,
#        0.671, 0.406, 0.027, 0.05 , 0.715, 0.13 , 0.953, 0.847, 0.531,
#        0.179])

# %%
import torch
import torch.distributions as TD
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
from datetime import datetime
import functools


# =========================
# Device
# =========================
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')


# =========================
# Parameters
# =========================
param = {
    "test": "type1error",
    "sample_size": 1000,
    "batch_size": 256,
    "z_dim": 1,
    "dx": 1,
    "dy": 1,
    "n_test": 100,
    "epochs_num": 200,
    "eps_std": 0.5,
    "dist_z": 'gaussian',
    "alpha_x": 0.75,
    "m_value": 100,
    "k_value": 2,
    "j_value": 1000,
    "noise_dimension": 3,
    "hidden_layer_size": 20,
    "normal_ini": False,
    "preprocess": 'None',
    "G_lr": 1e-3,
    "alpha": 0.1,
    "alpha1": 0.05,
    "set_seeds": 42,
    "using_oracle": False,
    "lambda_1": 1,
    "lambda_2": 0,
    "using_Gen": '1',
    "boor_rv_type": 'gaussian',
    "wgt_decay": 1e-5,
    "lambda_3": 1e-5,
    "drop_out_p": 0.2,
    "M_train": 10,

    # 你的改进
    "lambda_mean": 0.0,
    "mean_samples": 20
}



# =========================
# Data generation: binary version
# =========================
def generate_samples_random(Ax, Ay, size=1000, sType='CI', dx=1, dy=1, dz=1,
                            nstd=0.05, alpha_x=0.05,
                            preprocess="None", dist_z='gaussian'):
    """
    Binary data generator aligned with the author's pasted code.

    Output:
        X, Y, Z are all binary {0,1} tensors.
    """
    if dx != 1 or dy != 1 or dz != 1:
        raise ValueError("This binary version currently supports dx=dy=dz=1 only.")

    num = size

    if sType in ['CI', 'H0', 'type1error']:
        numbers_z = np.random.multinomial(num, [0.5, 0.5], size=1)
        number_z_zeros = numbers_z[0][0]
        number_z_ones = numbers_z[0][1]

        xy_arr = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

        xy_z_zero_index = np.random.choice(
            a=len(xy_arr), size=number_z_zeros,
            p=[0.25, 0.25, 0.25, 0.25]
        )
        xy_z_one_index = np.random.choice(
            a=len(xy_arr), size=number_z_ones,
            p=[0.25, 0.25, 0.25, 0.25]
        )

        xy_z_zero = xy_arr[xy_z_zero_index]
        xy_z_one = xy_arr[xy_z_one_index]

        xy = np.concatenate((xy_z_zero, xy_z_one), axis=0)

        x = xy[:, 0]
        y = xy[:, 1]
        z = np.concatenate((np.zeros(number_z_zeros), np.ones(number_z_ones)), axis=0)

    elif sType in ['dependent', 'H1', 'power']:
        z = np.random.binomial(1, 0.5, size=num)
        y = np.random.binomial(1, 0.5, size=num)

        delta = np.random.binomial(1, alpha_x, size=num)
        x_indep = np.random.binomial(1, 0.5, size=num)

        x = (1 - delta) * x_indep + delta * y
        x = x.astype(int)

    else:
        raise ValueError("sType must be one of ['CI','H0','type1error','dependent','H1','power']")

    indices = np.random.permutation(num)
    x, y, z = x[indices], y[indices], z[indices]

    X = x.reshape(-1, 1).astype(np.float32)
    Y = y.reshape(-1, 1).astype(np.float32)
    Z = z.reshape(-1, 1).astype(np.float32)

    if preprocess == "normalize":
        pass
    elif preprocess == "scale_Z":
        pass
    elif preprocess == "None":
        pass
    else:
        raise ValueError("preprocess must be one of ['normalize', 'scale_Z', 'None']")

    X = torch.from_numpy(X).float()
    Y = torch.from_numpy(Y).float()
    Z = torch.from_numpy(Z).float()

    return X, Y, Z


# =========================
# Statistic computation
# =========================
def get_p_value_stat_1(boot_num, M, n, gen_x_all_torch, gen_y_all_torch,
                       x_torch, y_torch, z_torch,
                       sigma_w, sigma_u=1, sigma_v=1,
                       boor_rv_type="gaussian"):
    """
    Compute test statistic and bootstrap samples.
    Shapes:
        gen_x_all_torch, gen_y_all_torch: (n, M)
        x_torch, y_torch: (n, 1)
        z_torch: (n, dz)
    """
    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    v_mx_1 = torch.exp(-torch.abs(x_torch.repeat(1, n) - x_torch.repeat(1, n).T) / sigma_v)
    v_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_x_all_torch.repeat(n, 1, 1) - x_torch.repeat(1, n).reshape(n, n, 1)) / sigma_v
        ),
        dim=2
    )
    v_mx_3 = v_mx_2.T

    gen_x_all_torch_rep = gen_x_all_torch.repeat(n, 1, 1)
    temp2_mx = gen_x_all_torch_rep[:, :, 0].T
    sum2_mx = torch.mean(
        torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
        dim=2
    )

    for i in range(1, M):
        temp2_mx = gen_x_all_torch_rep[:, :, i].T
        temp2_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_x_all_torch_rep - temp2_mx.reshape(n, n, 1)) / sigma_v),
            dim=2
        )
        sum2_mx = sum2_mx + temp2_add_mx

    v_mx_4 = 1.0 / M * sum2_mx
    v_mx = v_mx_1 - v_mx_2 - v_mx_3 + v_mx_4

    FF_mx = u_mx * v_mx * w_mx * (1 - torch.eye(n, device=device))

    stat = 1.0 / (n - 1) * torch.sum(FF_mx).item()

    boottemp = np.array([])

    if boor_rv_type == "rademacher":
        eboot = torch.sign(torch.randn(n, boot_num, device=device))
    elif boor_rv_type == "gaussian":
        eboot = torch.randn(n, boot_num, device=device)
    else:
        raise ValueError("boor_rv_type must be 'rademacher' or 'gaussian'")

    for bb in range(boot_num):
        random_mx = torch.matmul(
            eboot[:, bb].reshape(-1, 1),
            eboot[:, bb].reshape(-1, 1).T
        )
        bootmatrix = FF_mx * random_mx
        stat_boot = 1.0 / (n - 1) * torch.sum(bootmatrix).item()
        boottemp = np.append(boottemp, stat_boot)

    return stat, boottemp


# =========================
# Dataset
# =========================
class DatasetSelect(Dataset):
    def __init__(self, X, Y, Z):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return self.X_real[index], self.Y_real[index], self.Z_real[index]


class DatasetSelect_GAN(torch.utils.data.Dataset):
    def __init__(self, X, Y, Z, batch_size):
        self.X_real = X
        self.Y_real = Y
        self.Z_real = Z
        self.batch_size = batch_size
        self.sample_size = X.shape[0]

    def __len__(self):
        return self.sample_size

    def __getitem__(self, index):
        return (
            self.X_real[index],
            self.Y_real[index],
            self.Z_real[index],
            self.Z_real[(self.batch_size + index) % self.sample_size]
        )


# =========================
# Noise sampler
# =========================
def sample_noise(sample_size, noise_dimension, noise_type, input_var):
    if noise_type == "normal":
        noise_generator = TD.MultivariateNormal(
            torch.zeros(noise_dimension).to(device),
            input_var * torch.eye(noise_dimension).to(device)
        )
        Z = noise_generator.sample((sample_size,))
    elif noise_type == "unif":
        Z = torch.rand(sample_size, noise_dimension, device=device)
    elif noise_type == "Cauchy":
        Z = TD.Cauchy(
            torch.tensor([0.0], device=device),
            torch.tensor([1.0], device=device)
        ).sample((sample_size, noise_dimension)).squeeze(2)
    else:
        raise ValueError("noise_type must be one of ['normal', 'unif', 'Cauchy']")
    return Z


# =========================
# Generator
# =========================
class Generator(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef, drop_out_p,
                 drop_input=False):
        super(Generator, self).__init__()
        self.BN_type = BN_type
        self.ReLU_coef = ReLU_coef
        self.drop_input = drop_input

        self.fc1 = torch.nn.Linear(input_dimension + noise_dimension, hidden_layer_size, bias=True)
        self.fc2 = torch.nn.Linear(hidden_layer_size, hidden_layer_size, bias=True)
        self.fc_last = torch.nn.Linear(hidden_layer_size, output_dimension, bias=True)

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)
            self.BN2 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

        self.leakyReLU1 = torch.nn.LeakyReLU(ReLU_coef)

        self.drop_out0 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out1 = torch.nn.Dropout(p=drop_out_p)
        self.drop_out2 = torch.nn.Dropout(p=drop_out_p)

        self.sigmoid = torch.nn.Sigmoid()

    def forward(self, x):
        if self.drop_input:
            x = self.drop_out0(x)

        if self.BN_type:
            x = self.drop_out1(self.leakyReLU1(self.BN1(self.fc1(x))))
            x = self.drop_out2(self.leakyReLU1(self.BN2(self.fc2(x))))
        else:
            x = self.drop_out1(self.leakyReLU1(self.fc1(x)))
            x = self.drop_out2(self.leakyReLU1(self.fc2(x)))

        x = self.fc_last(x)

        # Binary probability output
        x = self.sigmoid(x)

        return x


class NonFullyConnected_1(torch.nn.Module):
    def __init__(self, size_in, size_out, m, bias=True):
        super(NonFullyConnected_1, self).__init__()
        self.linear = torch.nn.Linear(m * size_in, m * size_out, bias=bias).to(device)
        self.mask = functools.reduce(
            torch.block_diag,
            [torch.ones(size_out, size_in) for _ in range(m)]
        ).to(device)

    def forward(self, x):
        self.linear.weight.data *= self.mask
        return self.linear(x)


class Generator_2(torch.nn.Module):
    def __init__(self, input_dimension, output_dimension, noise_dimension,
                 hidden_layer_size, BN_type, ReLU_coef,
                 hidden_layer_depth=1, ntargets_k=5):
        super(Generator_2, self).__init__()
        self.input_dimension = input_dimension + noise_dimension
        self.output_dimension = output_dimension
        self.ntargets_k = ntargets_k
        self.hidden_layer_sizes = [hidden_layer_size] * hidden_layer_depth
        self.BN_type = BN_type
        self.leakyrelu = torch.nn.LeakyReLU(ReLU_coef)

        self.linear_layers_from_input = torch.nn.Linear(
            self.input_dimension, ntargets_k * self.hidden_layer_sizes[0]
        )

        self.linear_layers_between = torch.nn.ModuleList([
            NonFullyConnected_1(self.hidden_layer_sizes[0], self.hidden_layer_sizes[0], ntargets_k)
            for _ in range(len(self.hidden_layer_sizes))
        ])

        self.linear8 = torch.nn.Linear(self.hidden_layer_sizes[0] * ntargets_k, self.output_dimension)
        self.sigmoid = torch.nn.Sigmoid()

        if BN_type:
            self.BN1 = torch.nn.BatchNorm1d(hidden_layer_size, 0.8, affine=False)

    def forward(self, input):
        if self.BN_type:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(self.BN1(output))
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(self.BN1(output))
        else:
            output = self.linear_layers_from_input(input)
            output = self.leakyrelu(output)
            for linear_layers_between in self.linear_layers_between:
                output = linear_layers_between(output)
                output = self.leakyrelu(output)

        output = self.linear8(output)
        output = self.sigmoid(output)
        return output


# =========================
# Loss
# =========================
def find_loss(y_torch, gen_y_all_torch, z_torch, sigma_w, sigma_u, M):
    n = z_torch.shape[0]

    w_mx = torch.linalg.vector_norm(
        z_torch.repeat(n, 1, 1) - torch.swapaxes(z_torch.repeat(n, 1, 1), 0, 1),
        ord=1, dim=2
    )
    w_mx = torch.exp(-w_mx / sigma_w)

    u_mx_1 = torch.exp(-torch.abs(y_torch.repeat(1, n) - y_torch.repeat(1, n).T) / sigma_u)
    u_mx_2 = torch.mean(
        torch.exp(
            -torch.abs(gen_y_all_torch.repeat(n, 1, 1) - y_torch.repeat(1, n).reshape(n, n, 1)) / sigma_u
        ),
        dim=2
    )
    u_mx_3 = u_mx_2.T

    gen_y_all_torch_rep = gen_y_all_torch.repeat(n, 1, 1)
    temp_mx = gen_y_all_torch_rep[:, :, 0].T
    sum_mx = torch.mean(
        torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
        dim=2
    )

    for i in range(1, M):
        temp_mx = gen_y_all_torch_rep[:, :, i].T
        temp_add_mx = torch.mean(
            torch.exp(-torch.abs(gen_y_all_torch_rep - temp_mx.reshape(n, n, 1)) / sigma_u),
            dim=2
        )
        sum_mx = sum_mx + temp_add_mx

    u_mx_4 = 1.0 / M * sum_mx
    u_mx = u_mx_1 - u_mx_2 - u_mx_3 + u_mx_4

    FF_mx = u_mx * w_mx * (1 - torch.eye(n, device=device))
    loss = 1.0 / n * torch.sum(FF_mx)

    return loss


# =========================
# Binary sampling helper
# =========================
def sample_binary_from_prob(prob_tensor):
    prob_tensor = torch.clamp(prob_tensor, 1e-6, 1 - 1e-6)
    return torch.bernoulli(prob_tensor)


# =========================
# Training
# =========================
def train_ver3(X, Y, Z, X_test, Y_test, Z_test, M,
               noise_dimension, noise_type, G_lr, hidden_layer_size,
               DataLoader, BN_type, ReLU_coef,
               epochs_num=10, sigma_z=1, sigma_x=1, sigma_y=1,
               normal_ini=False,
               lambda_1=1, lambda_2=1, using_Gen='1', wgt_decay=0,
               lambda_3=0, drop_out_p=0.2, M_train=3,
               lambda_mean=0.0, mean_samples=20):

    input_dimension = Z.shape[1]
    output_dimension_y = Y.shape[1]
    output_dimension_x = X.shape[1]

    if using_Gen == '1':
        G_zy = Generator(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef, drop_out_p
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

    elif using_Gen == '2':
        G_zy = Generator_2(
            input_dimension, output_dimension_y, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zy_solver = optim.Adam(G_zy.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)

        G_zx = Generator_2(
            input_dimension, output_dimension_x, noise_dimension,
            hidden_layer_size, BN_type, ReLU_coef
        ).to(device)
        G_zx_solver = optim.Adam(G_zx.parameters(), lr=G_lr, betas=(0.5, 0.999), weight_decay=wgt_decay)
    else:
        raise ValueError("using_Gen must be '1' or '2'")

    if normal_ini:
        for p in G_zy.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))
        for p in G_zx.parameters():
            p.data = torch.randn(p.shape, device=device, dtype=torch.float32) / np.sqrt(float(hidden_layer_size * 2))

    for epoch in range(epochs_num):
        G_zy.train()
        G_zx.train()

        for X_real, Y_real, Z_real, Z_fake in DataLoader:
            X_real = X_real.to(device)
            Y_real = Y_real.to(device)
            Z_real = Z_real.to(device)
            Z_fake = Z_fake.to(device)

            batch_size = Z_real.shape[0]

            # =========================
            # Train G_zy
            # =========================
            G_zy_solver.zero_grad()

            Z_real_repeat_y = Z_real.repeat(M_train, 1)
            Noise_fake_y = sample_noise(
                Z_real_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            Y_fake_prob = G_zy(torch.cat((Z_real_repeat_y, Noise_fake_y), dim=1)).to(device)
            Y_fake = Y_fake_prob.reshape(batch_size, M_train)

            l1_regularization_y = 0.0
            for param in G_zy.parameters():
                l1_regularization_y += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_y = lambda_1 * find_loss(
                Y_real, Y_fake, Z_real, sigma_z, sigma_y, M_train
            )

            if lambda_mean > 0:
                # 这里保留你的改进：对同一个 Z 做 Monte Carlo 均值近似
                Z_mean_repeat_y = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_y = sample_noise(
                    Z_mean_repeat_y.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                Y_mean_fake_group = G_zy(torch.cat((Z_mean_repeat_y, Noise_mean_y), dim=1))
                Y_mean_fake = Y_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_y).mean(dim=1)

                mean_loss_y = torch.nn.functional.mse_loss(Y_mean_fake, Y_real)
            else:
                mean_loss_y = 0.0

            g_zy_error = mmd_loss_y + lambda_mean * mean_loss_y + lambda_3 * l1_regularization_y
            g_zy_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zy.parameters(), max_norm=0.5)
            G_zy_solver.step()

            # =========================
            # Train G_zx
            # =========================
            G_zx_solver.zero_grad()

            Z_real_repeat_x = Z_real.repeat(M_train, 1)
            Noise_fake_x = sample_noise(
                Z_real_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
            ).to(device)

            X_fake_prob = G_zx(torch.cat((Z_real_repeat_x, Noise_fake_x), dim=1)).to(device)
            X_fake = X_fake_prob.reshape(batch_size, M_train)

            l1_regularization_x = 0.0
            for param in G_zx.parameters():
                l1_regularization_x += torch.linalg.vector_norm(param, ord=1)

            mmd_loss_x = lambda_1 * find_loss(
                X_real, X_fake, Z_real, sigma_z, sigma_x, M_train
            )

            if lambda_mean > 0:
                Z_mean_repeat_x = Z_real.repeat_interleave(mean_samples, dim=0)
                Noise_mean_x = sample_noise(
                    Z_mean_repeat_x.shape[0], noise_dimension, noise_type, input_var=1.0 / 3.0
                ).to(device)

                X_mean_fake_group = G_zx(torch.cat((Z_mean_repeat_x, Noise_mean_x), dim=1))
                X_mean_fake = X_mean_fake_group.reshape(batch_size, mean_samples, output_dimension_x).mean(dim=1)

                mean_loss_x = torch.nn.functional.mse_loss(X_mean_fake, X_real)
            else:
                mean_loss_x = 0.0

            g_zx_error = mmd_loss_x + lambda_mean * mean_loss_x + lambda_3 * l1_regularization_x
            g_zx_error.backward()
            torch.nn.utils.clip_grad_norm_(G_zx.parameters(), max_norm=0.5)
            G_zx_solver.step()

    return G_zy, G_zx

# =========================
# Main experiment for one run
# =========================
def mGAN(Ax, Ay, n=500, z_dim=1, simulation='type1error', batch_size=64, epochs_num=1000,
         nstd=1.0, z_dist='gaussian', x_dims=1, y_dims=1, a_x=0.05, M=500, k=2, boot_num=1000,
         noise_dimension=10, hidden_layer_size=512, normal_ini=False, preprocess='normalize',
         G_lr=1e-5, using_oracle=False, lambda_1=1, lambda_2=1, using_Gen='1',
         boor_rv_type="gaussian", wgt_decay=0, lambda_3=1, drop_out_p=0.2, exp_num=0,
         M_train=3, lambda_mean=0.0, mean_samples=20):


    if simulation == 'type1error':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='CI', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    elif simulation == 'power':
        sim_x, sim_y, sim_z = generate_samples_random(
            Ax, Ay, size=n, sType='dependent', dx=x_dims, dy=y_dims, dz=z_dim,
            nstd=nstd, alpha_x=a_x, dist_z=z_dist, preprocess=preprocess
        )
    else:
        raise ValueError('Test does not exist.')

    x, y, z = sim_x, sim_y, sim_z

    sigma_w_train = 1.0
    sigma_u_train = 1.0
    sigma_v_train = 1.0

    test_size = int(n / k)
    stat_all = torch.zeros(k, 1)
    boot_temp_all = torch.zeros(k, boot_num)
    cur_k = 0

    for k_fold in range(k):
        k_fold_start = int(n / k * k_fold)
        k_fold_end = int(n / k * (k_fold + 1))

        X_test = x[k_fold_start:k_fold_end]
        Y_test = y[k_fold_start:k_fold_end]
        Z_test = z[k_fold_start:k_fold_end]

        X_train = torch.cat((x[0:k_fold_start], x[k_fold_end:]))
        Y_train = torch.cat((y[0:k_fold_start], y[k_fold_end:]))
        Z_train = torch.cat((z[0:k_fold_start], z[k_fold_end:]))

        if k == 1:
            X_train, Y_train, Z_train = X_test, Y_test, Z_test

        train_xyz = DatasetSelect_GAN(X_train, Y_train, Z_train, batch_size)
        DataLoader_xyz = torch.utils.data.DataLoader(train_xyz, batch_size=batch_size, shuffle=True)

        if not using_oracle:
            G_zy, G_zx = train_ver3(
    X=X_train, Y=Y_train, Z=Z_train, M=M,
    X_test=X_test, Y_test=Y_test, Z_test=Z_test,
    noise_dimension=noise_dimension, noise_type="normal",
    G_lr=G_lr, hidden_layer_size=hidden_layer_size,
    DataLoader=DataLoader_xyz, BN_type=False, ReLU_coef=0.1,
    epochs_num=epochs_num, sigma_z=sigma_w_train, sigma_x=sigma_v_train,
    sigma_y=sigma_u_train, normal_ini=normal_ini, lambda_1=lambda_1,
    lambda_2=lambda_2, using_Gen=using_Gen, wgt_decay=wgt_decay,
    lambda_3=lambda_3, drop_out_p=drop_out_p, M_train=M_train,
    lambda_mean=lambda_mean, mean_samples=mean_samples
)


        dataset_test = DatasetSelect(X_test, Y_test, Z_test)
        dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=True)

        gen_x_all = torch.zeros(test_size, M)
        gen_y_all = torch.zeros(test_size, M)

        z_all = torch.zeros(test_size, z_dim)
        x_all = torch.zeros(test_size, x_dims)
        y_all = torch.zeros(test_size, y_dims)

        cur_itr = 0

        if using_oracle:
            for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                z_scalar = int(z_test.item())

                fake_x = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)
                fake_y = torch.bernoulli(0.5 * torch.ones(M)).reshape(1, -1)

                gen_x_all[cur_itr, :] = fake_x.reshape(-1)
                gen_y_all[cur_itr, :] = fake_y.reshape(-1)

                x_all[cur_itr, :] = x_test
                y_all[cur_itr, :] = y_test
                z_all[cur_itr, :] = z_test
                cur_itr += 1
        else:
            G_zx.eval()
            G_zy.eval()

            with torch.no_grad():
                for i, (x_test, y_test, z_test) in enumerate(dataloader_test):
                    z_test_temp = z_test.repeat(M, 1).to(device)

                    noise_x = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_x_prob = G_zx(torch.cat((z_test_temp, noise_x), dim=1))
                    fake_x = sample_binary_from_prob(fake_x_prob).reshape(1, -1)

                    noise_y = sample_noise(
                        z_test_temp.size(0), noise_dimension, "normal", input_var=1.0 / 3.0
                    ).to(device)
                    fake_y_prob = G_zy(torch.cat((z_test_temp, noise_y), dim=1))
                    fake_y = sample_binary_from_prob(fake_y_prob).reshape(1, -1)

                    gen_x_all[cur_itr, :] = fake_x.detach().cpu().reshape(-1)
                    gen_y_all[cur_itr, :] = fake_y.detach().cpu().reshape(-1)
                    x_all[cur_itr, :] = x_test
                    y_all[cur_itr, :] = y_test
                    z_all[cur_itr, :] = z_test
                    cur_itr += 1

        gen_x_all = gen_x_all.to(device)
        gen_y_all = gen_y_all.to(device)

        z_all = Z_test.to(device)
        x_all = X_test.to(device)
        y_all = Y_test.to(device)

        sigma_w = 1.0
        sigma_u = 1.0
        sigma_v = 1.0

        cur_stat, cur_boot_temp = get_p_value_stat_1(
            boot_num, M, test_size,
            gen_x_all.to(device), gen_y_all.to(device),
            x_all.to(device), y_all.to(device), z_all.to(device),
            sigma_w, sigma_u, sigma_v, boor_rv_type
        )

        stat_all[cur_k, :] = cur_stat
        boot_temp_all[cur_k, :] = torch.from_numpy(cur_boot_temp).float()
        cur_k += 1

    return np.mean(torch.mean(boot_temp_all, dim=0).cpu().numpy() > torch.mean(stat_all).item())


# =========================
# Repeated experiment
# =========================
def run_experiment(params):
    test = params["test"]
    sample_size = params["sample_size"]
    batch_size = params["batch_size"]
    z_dim = params["z_dim"]
    dx = params["dx"]
    dy = params["dy"]
    n_test = params["n_test"]
    epochs_num = params["epochs_num"]
    eps_std = params["eps_std"]
    dist_z = params["dist_z"]
    alpha_x = params["alpha_x"]
    m_value = params["m_value"]
    k_value = params["k_value"]
    j_value = params["j_value"]
    noise_dimension = params["noise_dimension"]
    hidden_layer_size = params["hidden_layer_size"]
    normal_ini = params["normal_ini"]
    preprocess = params["preprocess"]
    G_lr = params["G_lr"]
    alpha = params["alpha"]
    alpha1 = params["alpha1"]
    set_seeds = params["set_seeds"]
    using_oracle = params["using_oracle"]
    lambda_1 = params["lambda_1"]
    lambda_2 = params["lambda_2"]
    using_Gen = params["using_Gen"]
    boor_rv_type = params["boor_rv_type"]
    wgt_decay = params["wgt_decay"]
    lambda_3 = params["lambda_3"]
    drop_out_p = params["drop_out_p"]
    M_train = params["M_train"]
    lambda_mean = params["lambda_mean"]
    mean_samples = params["mean_samples"]


    np.random.seed(set_seeds)
    torch.manual_seed(set_seeds)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(set_seeds)

    a_f = torch.rand((z_dim, dx))
    l1_norm_a_f = torch.linalg.vector_norm(a_f, ord=1)
    Ax = a_f / l1_norm_a_f

    a_g = torch.rand((z_dim, dy))
    l1_norm_a_g = torch.linalg.vector_norm(a_g, ord=1)
    Ay = a_g / l1_norm_a_g

    p_values = np.array([])
    test_count = 0

    if test == 'type1error':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train, lambda_mean=lambda_mean, mean_samples=mean_samples
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Type 1 error: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))

    elif test == 'power':
        for n_iter in range(n_test):
            start_time = datetime.now()

            p_value = mGAN(
                Ax=Ax, Ay=Ay, n=sample_size, z_dim=z_dim, simulation=test,
                batch_size=batch_size, epochs_num=epochs_num,
                nstd=eps_std, z_dist=dist_z, x_dims=dx, y_dims=dy,
                a_x=alpha_x, M=m_value, k=k_value, boot_num=j_value,
                noise_dimension=noise_dimension, hidden_layer_size=hidden_layer_size,
                normal_ini=normal_ini, preprocess=preprocess, G_lr=G_lr,
                using_oracle=using_oracle, lambda_1=lambda_1, lambda_2=lambda_2,
                using_Gen=using_Gen, boor_rv_type=boor_rv_type, wgt_decay=wgt_decay,
                lambda_3=lambda_3, drop_out_p=drop_out_p, exp_num=n_iter + 1,
                M_train=M_train
            )

            test_count += 1
            print("--- The %d'th iteration take %s seconds ---" %
                  (test_count, (datetime.now() - start_time)))

            p_values = np.append(p_values, p_value)

            fp = [pval < alpha for pval in p_values]
            final_result = np.mean(fp)

            fp1 = [pval < alpha1 for pval in p_values]
            final_result1 = np.mean(fp1)

            print('The stat is {}'.format(p_value))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result, z_dim, alpha))
            print('Power: {} for z dimension {} with significance level {}'.format(
                final_result1, z_dim, alpha1))
    else:
        raise ValueError("test must be 'type1error' or 'power'")

    return p_values


# =========================
# Run
# =========================
run_experiment(param)
# Out:
# --- The 1'th iteration take 0:06:28.688622 seconds ---
# The stat is 0.925
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 2'th iteration take 0:06:21.986235 seconds ---
# The stat is 0.898
# Type 1 error: 0.0 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 3'th iteration take 0:06:31.922636 seconds ---
# The stat is 0.089
# Type 1 error: 0.3333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 4'th iteration take 0:06:16.859341 seconds ---
# The stat is 0.969
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 5'th iteration take 0:06:32.967046 seconds ---
# The stat is 0.262
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 6'th iteration take 0:07:18.414460 seconds ---
# The stat is 0.071
# Type 1 error: 0.3333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 7'th iteration take 0:06:55.598276 seconds ---
# The stat is 0.147
# Type 1 error: 0.2857142857142857 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 8'th iteration take 0:06:41.782222 seconds ---
# The stat is 0.346
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0 for z dimension 1 with significance level 0.05
# --- The 9'th iteration take 0:06:27.657094 seconds ---
# The stat is 0.002
# Type 1 error: 0.3333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1111111111111111 for z dimension 1 with significance level 0.05
# --- The 10'th iteration take 0:06:43.160536 seconds ---
# The stat is 0.095
# Type 1 error: 0.4 for z dimension 1 with significance level 0.1
# Type 1 error: 0.1 for z dimension 1 with significance level 0.05
# --- The 11'th iteration take 0:06:42.286783 seconds ---
# The stat is 0.166
# Type 1 error: 0.36363636363636365 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 12'th iteration take 0:07:40.781437 seconds ---
# The stat is 0.995
# Type 1 error: 0.3333333333333333 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 13'th iteration take 0:06:55.562880 seconds ---
# The stat is 0.255
# Type 1 error: 0.3076923076923077 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 14'th iteration take 0:06:24.524681 seconds ---
# The stat is 0.355
# Type 1 error: 0.2857142857142857 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 15'th iteration take 0:06:50.950222 seconds ---
# The stat is 0.147
# Type 1 error: 0.26666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 16'th iteration take 0:06:23.829115 seconds ---
# The stat is 0.438
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 17'th iteration take 0:06:01.322567 seconds ---
# The stat is 0.844
# Type 1 error: 0.23529411764705882 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 18'th iteration take 0:06:21.953252 seconds ---
# The stat is 0.185
# Type 1 error: 0.2222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 19'th iteration take 0:06:11.335382 seconds ---
# The stat is 0.924
# Type 1 error: 0.21052631578947367 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05263157894736842 for z dimension 1 with significance level 0.05
# --- The 20'th iteration take 0:06:18.829385 seconds ---
# The stat is 0.1
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05 for z dimension 1 with significance level 0.05
# --- The 21'th iteration take 0:06:12.843903 seconds ---
# The stat is 0.006
# Type 1 error: 0.23809523809523808 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09523809523809523 for z dimension 1 with significance level 0.05
# --- The 22'th iteration take 0:06:15.517364 seconds ---
# The stat is 0.775
# Type 1 error: 0.22727272727272727 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 23'th iteration take 0:06:23.085261 seconds ---
# The stat is 0.441
# Type 1 error: 0.21739130434782608 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08695652173913043 for z dimension 1 with significance level 0.05
# --- The 24'th iteration take 0:06:34.970243 seconds ---
# The stat is 0.529
# Type 1 error: 0.20833333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 25'th iteration take 0:06:11.516230 seconds ---
# The stat is 0.478
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08 for z dimension 1 with significance level 0.05
# --- The 26'th iteration take 0:06:18.037566 seconds ---
# The stat is 0.812
# Type 1 error: 0.19230769230769232 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 27'th iteration take 0:06:17.088254 seconds ---
# The stat is 0.423
# Type 1 error: 0.18518518518518517 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07407407407407407 for z dimension 1 with significance level 0.05
# --- The 28'th iteration take 0:06:17.117011 seconds ---
# The stat is 0.05
# Type 1 error: 0.21428571428571427 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 29'th iteration take 0:06:21.055517 seconds ---
# The stat is 0.866
# Type 1 error: 0.20689655172413793 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.05
# --- The 30'th iteration take 0:06:48.844786 seconds ---
# The stat is 0.081
# Type 1 error: 0.23333333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 31'th iteration take 0:06:15.116789 seconds ---
# The stat is 0.519
# Type 1 error: 0.22580645161290322 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.05
# --- The 32'th iteration take 0:06:23.264365 seconds ---
# The stat is 0.012
# Type 1 error: 0.25 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09375 for z dimension 1 with significance level 0.05
# --- The 33'th iteration take 0:06:25.379239 seconds ---
# The stat is 0.876
# Type 1 error: 0.24242424242424243 for z dimension 1 with significance level 0.1
# Type 1 error: 0.09090909090909091 for z dimension 1 with significance level 0.05
# --- The 34'th iteration take 0:06:08.814544 seconds ---
# The stat is 0.708
# Type 1 error: 0.23529411764705882 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08823529411764706 for z dimension 1 with significance level 0.05
# --- The 35'th iteration take 0:06:13.374035 seconds ---
# The stat is 0.978
# Type 1 error: 0.22857142857142856 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08571428571428572 for z dimension 1 with significance level 0.05
# --- The 36'th iteration take 0:07:03.432855 seconds ---
# The stat is 0.33
# Type 1 error: 0.2222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08333333333333333 for z dimension 1 with significance level 0.05
# --- The 37'th iteration take 0:06:09.356311 seconds ---
# The stat is 0.817
# Type 1 error: 0.21621621621621623 for z dimension 1 with significance level 0.1
# Type 1 error: 0.08108108108108109 for z dimension 1 with significance level 0.05
# --- The 38'th iteration take 0:06:09.432757 seconds ---
# The stat is 0.21
# Type 1 error: 0.21052631578947367 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07894736842105263 for z dimension 1 with significance level 0.05
# --- The 39'th iteration take 0:06:16.479789 seconds ---
# The stat is 0.814
# Type 1 error: 0.20512820512820512 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 40'th iteration take 0:06:19.593466 seconds ---
# The stat is 0.539
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.075 for z dimension 1 with significance level 0.05
# --- The 41'th iteration take 0:06:16.995741 seconds ---
# The stat is 0.771
# Type 1 error: 0.1951219512195122 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07317073170731707 for z dimension 1 with significance level 0.05
# --- The 42'th iteration take 0:06:20.335876 seconds ---
# The stat is 0.863
# Type 1 error: 0.19047619047619047 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 43'th iteration take 0:06:29.408873 seconds ---
# The stat is 0.613
# Type 1 error: 0.18604651162790697 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06976744186046512 for z dimension 1 with significance level 0.05
# --- The 44'th iteration take 0:06:13.955888 seconds ---
# The stat is 0.567
# Type 1 error: 0.18181818181818182 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06818181818181818 for z dimension 1 with significance level 0.05
# --- The 45'th iteration take 0:06:20.692967 seconds ---
# The stat is 0.403
# Type 1 error: 0.17777777777777778 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 46'th iteration take 0:06:16.495812 seconds ---
# The stat is 0.364
# Type 1 error: 0.17391304347826086 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06521739130434782 for z dimension 1 with significance level 0.05
# --- The 47'th iteration take 0:06:05.534177 seconds ---
# The stat is 0.422
# Type 1 error: 0.1702127659574468 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06382978723404255 for z dimension 1 with significance level 0.05
# --- The 48'th iteration take 0:06:15.845566 seconds ---
# The stat is 0.818
# Type 1 error: 0.16666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 49'th iteration take 0:06:11.773210 seconds ---
# The stat is 0.705
# Type 1 error: 0.16326530612244897 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061224489795918366 for z dimension 1 with significance level 0.05
# --- The 50'th iteration take 0:06:22.211972 seconds ---
# The stat is 0.275
# Type 1 error: 0.16 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06 for z dimension 1 with significance level 0.05
# --- The 51'th iteration take 0:06:11.802139 seconds ---
# The stat is 0.696
# Type 1 error: 0.1568627450980392 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 52'th iteration take 0:06:30.073631 seconds ---
# The stat is 0.587
# Type 1 error: 0.15384615384615385 for z dimension 1 with significance level 0.1
# Type 1 error: 0.057692307692307696 for z dimension 1 with significance level 0.05
# --- The 53'th iteration take 0:06:07.967435 seconds ---
# The stat is 0.332
# Type 1 error: 0.1509433962264151 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05660377358490566 for z dimension 1 with significance level 0.05
# --- The 54'th iteration take 0:06:30.914562 seconds ---
# The stat is 0.053
# Type 1 error: 0.16666666666666666 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 55'th iteration take 0:06:21.097868 seconds ---
# The stat is 0.627
# Type 1 error: 0.16363636363636364 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05454545454545454 for z dimension 1 with significance level 0.05
# --- The 56'th iteration take 0:06:14.449285 seconds ---
# The stat is 0.097
# Type 1 error: 0.17857142857142858 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05357142857142857 for z dimension 1 with significance level 0.05
# --- The 57'th iteration take 0:06:22.374990 seconds ---
# The stat is 0.026
# Type 1 error: 0.19298245614035087 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07017543859649122 for z dimension 1 with significance level 0.05
# --- The 58'th iteration take 0:06:18.029757 seconds ---
# The stat is 0.735
# Type 1 error: 0.1896551724137931 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06896551724137931 for z dimension 1 with significance level 0.05
# --- The 59'th iteration take 0:06:14.954140 seconds ---
# The stat is 0.85
# Type 1 error: 0.1864406779661017 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06779661016949153 for z dimension 1 with significance level 0.05
# --- The 60'th iteration take 0:06:17.670350 seconds ---
# The stat is 0.591
# Type 1 error: 0.18333333333333332 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 61'th iteration take 0:06:36.744414 seconds ---
# The stat is 0.619
# Type 1 error: 0.18032786885245902 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06557377049180328 for z dimension 1 with significance level 0.05
# --- The 62'th iteration take 0:06:19.527157 seconds ---
# The stat is 0.972
# Type 1 error: 0.1774193548387097 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.05
# --- The 63'th iteration take 0:06:20.880481 seconds ---
# The stat is 0.082
# Type 1 error: 0.19047619047619047 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06349206349206349 for z dimension 1 with significance level 0.05
# --- The 64'th iteration take 0:06:20.238265 seconds ---
# The stat is 0.045
# Type 1 error: 0.203125 for z dimension 1 with significance level 0.1
# Type 1 error: 0.078125 for z dimension 1 with significance level 0.05
# --- The 65'th iteration take 0:06:18.190829 seconds ---
# The stat is 0.05
# Type 1 error: 0.2153846153846154 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07692307692307693 for z dimension 1 with significance level 0.05
# --- The 66'th iteration take 0:06:22.644508 seconds ---
# The stat is 0.747
# Type 1 error: 0.21212121212121213 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07575757575757576 for z dimension 1 with significance level 0.05
# --- The 67'th iteration take 0:06:19.381746 seconds ---
# The stat is 0.097
# Type 1 error: 0.22388059701492538 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07462686567164178 for z dimension 1 with significance level 0.05
# --- The 68'th iteration take 0:06:18.540727 seconds ---
# The stat is 0.506
# Type 1 error: 0.22058823529411764 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07352941176470588 for z dimension 1 with significance level 0.05
# --- The 69'th iteration take 0:06:18.407639 seconds ---
# The stat is 0.059
# Type 1 error: 0.2318840579710145 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07246376811594203 for z dimension 1 with significance level 0.05
# --- The 70'th iteration take 0:06:30.739318 seconds ---
# The stat is 0.514
# Type 1 error: 0.22857142857142856 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07142857142857142 for z dimension 1 with significance level 0.05
# --- The 71'th iteration take 0:06:29.434947 seconds ---
# The stat is 0.469
# Type 1 error: 0.22535211267605634 for z dimension 1 with significance level 0.1
# Type 1 error: 0.07042253521126761 for z dimension 1 with significance level 0.05
# --- The 72'th iteration take 0:06:19.254003 seconds ---
# The stat is 0.787
# Type 1 error: 0.2222222222222222 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06944444444444445 for z dimension 1 with significance level 0.05
# --- The 73'th iteration take 0:06:44.407115 seconds ---
# The stat is 0.454
# Type 1 error: 0.2191780821917808 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0684931506849315 for z dimension 1 with significance level 0.05
# --- The 74'th iteration take 0:06:26.069171 seconds ---
# The stat is 0.377
# Type 1 error: 0.21621621621621623 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06756756756756757 for z dimension 1 with significance level 0.05
# --- The 75'th iteration take 0:06:31.687738 seconds ---
# The stat is 0.522
# Type 1 error: 0.21333333333333335 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06666666666666667 for z dimension 1 with significance level 0.05
# --- The 76'th iteration take 0:06:37.246770 seconds ---
# The stat is 0.396
# Type 1 error: 0.21052631578947367 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06578947368421052 for z dimension 1 with significance level 0.05
# --- The 77'th iteration take 0:06:46.018121 seconds ---
# The stat is 0.458
# Type 1 error: 0.2077922077922078 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06493506493506493 for z dimension 1 with significance level 0.05
# --- The 78'th iteration take 0:06:30.925466 seconds ---
# The stat is 0.392
# Type 1 error: 0.20512820512820512 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0641025641025641 for z dimension 1 with significance level 0.05
# --- The 79'th iteration take 0:06:25.666550 seconds ---
# The stat is 0.443
# Type 1 error: 0.20253164556962025 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06329113924050633 for z dimension 1 with significance level 0.05
# --- The 80'th iteration take 0:06:27.204428 seconds ---
# The stat is 0.934
# Type 1 error: 0.2 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 81'th iteration take 0:06:27.535485 seconds ---
# The stat is 0.213
# Type 1 error: 0.19753086419753085 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06172839506172839 for z dimension 1 with significance level 0.05
# --- The 82'th iteration take 0:06:28.157885 seconds ---
# The stat is 0.74
# Type 1 error: 0.1951219512195122 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06097560975609756 for z dimension 1 with significance level 0.05
# --- The 83'th iteration take 0:06:31.944184 seconds ---
# The stat is 0.67
# Type 1 error: 0.1927710843373494 for z dimension 1 with significance level 0.1
# Type 1 error: 0.060240963855421686 for z dimension 1 with significance level 0.05
# --- The 84'th iteration take 0:06:31.440258 seconds ---
# The stat is 0.131
# Type 1 error: 0.19047619047619047 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05952380952380952 for z dimension 1 with significance level 0.05
# --- The 85'th iteration take 0:06:22.182472 seconds ---
# The stat is 0.342
# Type 1 error: 0.18823529411764706 for z dimension 1 with significance level 0.1
# Type 1 error: 0.058823529411764705 for z dimension 1 with significance level 0.05
# --- The 86'th iteration take 0:06:34.408150 seconds ---
# The stat is 0.508
# Type 1 error: 0.18604651162790697 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05813953488372093 for z dimension 1 with significance level 0.05
# --- The 87'th iteration take 0:06:39.504344 seconds ---
# The stat is 0.605
# Type 1 error: 0.1839080459770115 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05747126436781609 for z dimension 1 with significance level 0.05
# --- The 88'th iteration take 0:06:56.386835 seconds ---
# The stat is 0.483
# Type 1 error: 0.18181818181818182 for z dimension 1 with significance level 0.1
# Type 1 error: 0.056818181818181816 for z dimension 1 with significance level 0.05
# --- The 89'th iteration take 0:06:42.238028 seconds ---
# The stat is 0.454
# Type 1 error: 0.1797752808988764 for z dimension 1 with significance level 0.1
# Type 1 error: 0.056179775280898875 for z dimension 1 with significance level 0.05
# --- The 90'th iteration take 0:06:36.517113 seconds ---
# The stat is 0.617
# Type 1 error: 0.17777777777777778 for z dimension 1 with significance level 0.1
# Type 1 error: 0.05555555555555555 for z dimension 1 with significance level 0.05
# --- The 91'th iteration take 0:06:29.004016 seconds ---
# The stat is 0.02
# Type 1 error: 0.18681318681318682 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06593406593406594 for z dimension 1 with significance level 0.05
# --- The 92'th iteration take 0:06:42.955753 seconds ---
# The stat is 0.468
# Type 1 error: 0.18478260869565216 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06521739130434782 for z dimension 1 with significance level 0.05
# --- The 93'th iteration take 0:06:34.897443 seconds ---
# The stat is 0.364
# Type 1 error: 0.1827956989247312 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06451612903225806 for z dimension 1 with significance level 0.05
# --- The 94'th iteration take 0:06:29.322236 seconds ---
# The stat is 0.431
# Type 1 error: 0.18085106382978725 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06382978723404255 for z dimension 1 with significance level 0.05
# --- The 95'th iteration take 0:06:50.432683 seconds ---
# The stat is 0.191
# Type 1 error: 0.17894736842105263 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06315789473684211 for z dimension 1 with significance level 0.05
# --- The 96'th iteration take 0:06:33.654163 seconds ---
# The stat is 0.597
# Type 1 error: 0.17708333333333334 for z dimension 1 with significance level 0.1
# Type 1 error: 0.0625 for z dimension 1 with significance level 0.05
# --- The 97'th iteration take 0:06:32.015129 seconds ---
# The stat is 0.462
# Type 1 error: 0.17525773195876287 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061855670103092786 for z dimension 1 with significance level 0.05
# --- The 98'th iteration take 0:06:38.931316 seconds ---
# The stat is 0.903
# Type 1 error: 0.17346938775510204 for z dimension 1 with significance level 0.1
# Type 1 error: 0.061224489795918366 for z dimension 1 with significance level 0.05
# --- The 99'th iteration take 0:06:27.548934 seconds ---
# The stat is 0.601
# Type 1 error: 0.1717171717171717 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06060606060606061 for z dimension 1 with significance level 0.05
# --- The 100'th iteration take 0:06:52.622282 seconds ---
# The stat is 0.285
# Type 1 error: 0.17 for z dimension 1 with significance level 0.1
# Type 1 error: 0.06 for z dimension 1 with significance level 0.05
# array([0.925, 0.898, 0.089, 0.969, 0.262, 0.071, 0.147, 0.346, 0.002,
#        0.095, 0.166, 0.995, 0.255, 0.355, 0.147, 0.438, 0.844, 0.185,
#        0.924, 0.1  , 0.006, 0.775, 0.441, 0.529, 0.478, 0.812, 0.423,
#        0.05 , 0.866, 0.081, 0.519, 0.012, 0.876, 0.708, 0.978, 0.33 ,
#        0.817, 0.21 , 0.814, 0.539, 0.771, 0.863, 0.613, 0.567, 0.403,
#        0.364, 0.422, 0.818, 0.705, 0.275, 0.696, 0.587, 0.332, 0.053,
#        0.627, 0.097, 0.026, 0.735, 0.85 , 0.591, 0.619, 0.972, 0.082,
#        0.045, 0.05 , 0.747, 0.097, 0.506, 0.059, 0.514, 0.469, 0.787,
#        0.454, 0.377, 0.522, 0.396, 0.458, 0.392, 0.443, 0.934, 0.213,
#        0.74 , 0.67 , 0.131, 0.342, 0.508, 0.605, 0.483, 0.454, 0.617,
#        0.02 , 0.468, 0.364, 0.431, 0.191, 0.597, 0.462, 0.903, 0.601,
#        0.285])
